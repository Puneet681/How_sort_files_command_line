# %%
import os
import time
import pandas as pd
def cr_date(path):
    os.chdir(path)
    a = os.listdir()
    l=[]
    for i in range(len(a)-1):
        cr_T=(os.path.getctime(a[i]))
        cr_time = time.ctime(cr_T)
        cr_t_obj = time.strptime(cr_time)
        cr_date = time.strftime("%Y-%m-%d", cr_t_obj)
        l.append({cr_date:a[i]})
    return(l)

# %%
(cr_date("D:\\python scripts\\testing-codes"))
# Out:
# [{'2022-07-18': '.git'},
#  {'2022-09-30': 'convert.ipynb'},
#  {'2022-10-05': 'Day 2- Class statistics Part 2(year 2022).ipynb'},
#  {'2022-10-05': 'Day 2- Class statistics Part 2(year 2022).pdf'},
#  {'2022-10-01': 'day1-Live Class Statistics(year 2022).pdf'},
#  {'2022-08-29': 'debug.py'},
#  {'2022-07-19': 'iNeuron video 6 (list mauplation).ipynb'},
#  {'2022-07-24': 'iNeuron video 7(tupel, set , dictionery).ipynb'},
#  {'2022-08-05': 'merge(docx).py'},
#  {'2022-07-31': 'Modules'},
#  {'2022-10-01': 'module_1.py'},
#  {'2022-08-20': 'OReilly.Hands-On.Machine.Learning.with.Scikit-Learn.Keras.and.TensorFlow.2nd.Edition.1492032646.pdf'},
#  {'2022-09-30': 'pars.py'},
#  {'2022-07-18': 'puneet foer loop codes.ipynb'},
#  {'2022-07-18': 'puneet_while.ipynb'},
#  {'2022-07-18': 'README.md'},
#  {'2022-10-04': 'Screenshot.png'},
#  {'2022-07-18': 'string function code practices.ipynb'},
#  {'2022-08-20': 'test.h5'},
#  {'2022-08-03': 'test_V_12.txt'},
#  {'2022-07-18': 'Untitled.ipynb'},
#  {'2022-07-29': 'video_10(Logging and debugging).ipynb'},
#  {'2022-07-30': 'Video_11(Modules and Exception).ipynb'},
#  {'2022-08-01': 'video_12( OOPs, Classes Objects).ipynb'},
#  {'2022-08-05': 'video_13(OOPS, Abstraction Inheritance).ipynb'},
#  {'2022-08-05': 'video_14( Inheritance, Polymorphism Intro to Databases).ipynb'},
#  {'2022-08-08': 'video_15(Working with SQL Python).ipynb'},
#  {'2022-08-10': 'Video_16(MongoDBtest).py'},
#  {'2022-08-09': 'video_16(SQL Continued, MongoDB installation Working with MongoDB).ipynb'},
#  {'2022-08-13': 'video_17(Working with Cassandra Python).ipynb'},
#  {'2022-08-18': 'video_18(Introduction to Pandas).ipynb'},
#  {'2022-08-20': 'video_19(20,21,23(Pandas)).ipynb'},
#  {'2022-08-20': 'video_19(prctice).ipynb'},
#  {'2022-08-23': 'video_22( Introduction to Numpy).ipynb'},
#  {'2022-08-27': 'video_23((Working with Matplotlib).ipynb'},
#  {'2022-09-02': 'video_24(Working with Plotly).ipynb'},
#  {'2022-09-21': 'video_25(Working with Seaborn).ipynb'},
#  {'2022-09-22': 'video_26(EDA).ipynb'},
#  {'2022-09-05': 'video_27,28(Rest API, Flask Working with Postmani,Working with Flask Debugging Calculator Application).ipynb'},
#  {'2022-09-27': 'video_29(Django Introduction Working with Django).ipynb'},
#  {'2022-07-27': 'video_8(Working with Functions).ipynb'},
#  {'2022-07-27': 'video_9(Functions, Generators File Handling).ipynb'}]

# %%
import os
import time
def cr_date(path):
    os.chdir(path)
    a = os.listdir()
    cr_date={}
    for i in range(len(a)-1):
        cr_T=(os.path.getctime(a[i]))
        cr_time = time.ctime(cr_T)
        cr_t_obj = time.strptime(cr_time)
        date = time.strftime("%Y-%m-%d", cr_t_obj)
        if date in cr_date.keys():
            cr_date[date].append(a[i])
        else:
            cr_date[date]=[a[i]]
    return(cr_date)

# %%
for i in cr_date.keys():
    f_list = cr_date[i]
    print(f_list)
    a =str(cr_date.keys()).strip("dict_keys(['")
    fol_name = a.rstrip("'])")
    print(fol_name)
    if fol_name in os.listdir():
        for j in range(len(f_list)-1):
            file_name = f_list[j]
            print(file_name)
        if file_name.endswith('.mp4'):
            pass
            # move the file_name in fol_name\\video
        else:
            pass
            # move the file_name in fol_name//img
    else:
        os.mkdir(fol_name)
        for j in range(len(f_list)-1):
            if file_name.endswith('.mp4'):
                pass
                # move the file_name in fol_name//video
            else:
                pass
                # move the file_name in fol_name//img
# Out:
# ['DSC_3572.JPG', 'DSC_3573.JPG', 'DSC_3574.JPG', 'DSC_3575.JPG', 'DSC_3576.JPG', 'DSC_3577.JPG', 'DSC_3578.JPG', 'DSC_3579.JPG', 'DSC_3580.JPG', 'DSC_3581.JPG', 'DSC_3582.JPG', 'DSC_3583.JPG', 'DSC_3584.JPG', 'DSC_3585.JPG', 'DSC_3586.JPG', 'DSC_3587.JPG', 'DSC_3588.JPG', 'DSC_3589.JPG', 'DSC_3590.JPG', 'DSC_3591.JPG', 'DSC_3592.JPG', 'DSC_3593.JPG', 'DSC_3594.JPG', 'DSC_3595.JPG', 'DSC_3596.JPG', 'DSC_3597.JPG', 'DSC_3598.JPG', 'DSC_3599.JPG', 'DSC_3600.JPG', 'DSC_3601.JPG', 'DSC_3602.JPG', 'DSC_3603.JPG', 'DSC_3604.JPG', 'DSC_3605.JPG', 'DSC_3606.JPG']
# 2022-08-16
# DSC_3572.JPG
# DSC_3573.JPG
# DSC_3574.JPG
# DSC_3575.JPG
# DSC_3576.JPG
# DSC_3577.JPG
# DSC_3578.JPG
# DSC_3579.JPG
# DSC_3580.JPG
# DSC_3581.JPG
# DSC_3582.JPG
# DSC_3583.JPG
# DSC_3584.JPG
# DSC_3585.JPG
# DSC_3586.JPG
# DSC_3587.JPG
# DSC_3588.JPG
# DSC_3589.JPG
# DSC_3590.JPG
# DSC_3591.JPG
# DSC_3592.JPG
# DSC_3593.JPG
# DSC_3594.JPG
# DSC_3595.JPG
# DSC_3596.JPG
# DSC_3597.JPG
# DSC_3598.JPG
# DSC_3599.JPG
# DSC_3600.JPG
# DSC_3601.JPG
# DSC_3602.JPG
# DSC_3603.JPG
# DSC_3604.JPG
# DSC_3605.JPG

# %%
import shutil
for i in cr_date.keys():
    f_list = cr_date[i]
    print(f_list)
    a =str(cr_date.keys()).strip("dict_keys(['")
    fol_name = a.rstrip("'])")
    print(fol_name)
    if fol_name in os.listdir():
        for j in range(len(f_list)-1):
            file_name = f_list[j]
            print(file_name)
        if file_name.endswith('.mp4'):
            pass
            v_copy_path=fol_name+"//video"
            # if path exist copy the file
            if v_copy_path in os.listdir:
                shutil.copyfile(file_name,v_copy_path)
            # if path does not exist make the path then copy
            else:
                os.mkdir(fol_name+"//video")
                shutil.copyfile(file_name,v_copy_path)
            # move the file_name in fol_name//video
        else:
            pass
            i_copy_path=fol_name+"//img"
            #  if path exist then copy
            if i_copy_path in os.listdir:
                shutil.copyfile(file_name,i_copy_path)
            #  if path do not exist then make path and them copy
            else:
                os.mkdir(fol_name+"//img")
                shutil.copyfile(file_name,i_copy_path)
            # move the file_name in fol_name//img
    else:
        os.mkdir(fol_name)
        for j in range(len(f_list)-1):
            file_name = f_list[j]
            print(file_name)
        if file_name.endswith('.mp4'):
            pass
            v_copy_path=fol_name+"//video"
            # if path exist copy the file
            if v_copy_path in os.listdir:
                shutil.copyfile(file_name,v_copy_path)
            # if path does not exist make the path then copy
            else:
                os.mkdir(fol_name+"//video")
                shutil.copyfile(file_name,v_copy_path)
            # move the file_name in fol_name//video
        else:
            pass
            i_copy_path=fol_name+"//img"
            #  if path exist then copy
            if i_copy_path in os.listdir:
                shutil.copyfile(file_name,i_copy_path)
            #  if path do not exist then make path and them copy
            else:
                os.mkdir(fol_name+"//img")
                shutil.copyfile(file_name,i_copy_path)
            # move the file_name in fol_name//img

# %%
import os
import time
import shutil

def cr_date(path):
    os.chdir(path)
    a = os.listdir()
    cr_date={}
    for i in range(len(a)-1):
        cr_T=(os.path.getmtime(a[i]))
        cr_time = time.ctime(cr_T)
        cr_t_obj = time.strptime(cr_time)
        date = time.strftime("%Y-%m-%d", cr_t_obj)
        if date in cr_date.keys():
            cr_date[date].append(a[i])
        else:
            cr_date[date]=[a[i]]
    return(cr_date)

# %%
import os
import time
import shutil

def cr_date(path):
    os.chdir(path)
    a = os.listdir()
    cr_date={}
    for i in range(len(a)-1):
        cr_T=(os.path.getmtime(a[i]))
        cr_time = time.ctime(cr_T)
        cr_t_obj = time.strptime(cr_time)
        date = time.strftime("%Y-%m-%d", cr_t_obj)
        file_path = path + "//" + a[i]
        if date in cr_date.keys():
            cr_date[date].append(file_path)
        else:
            cr_date[date]=[file_path]
    return(cr_date)

# %%
# data = cr_date("path")
def copy_file(dictionery = data):
    cr_date = dictionery
    fol_name = list(cr_date.keys())
    for i in cr_date.keys():
        f_list = cr_date[i]
        # print(f_list)
        current_directory = os.getcwd()
        v_format=(
'.264', '.3g2', '.3gp', '.3gp2', '.3gpp', '.3gpp2', '.3mm', '.3p2', '.60d', '.787', '.89', '.aaf', '.aec', '.aep', '.aepx',
'.aet', '.aetx', '.ajp', '.ale', '.am', '.amc', '.amv', '.amx', '.anim', '.aqt', '.arcut', '.arf', '.asf', '.asx', '.avb',
'.avc', '.avd', '.avi', '.avp', '.avs', '.avs', '.avv', '.axm', '.bdm', '.bdmv', '.bdt2', '.bdt3', '.bik', '.bin', '.bix',
'.bmk', '.bnp', '.box', '.bs4', '.bsf', '.bvr', '.byu', '.camproj', '.camrec', '.camv', '.ced', '.cel', '.cine', '.cip',
'.clpi', '.cmmp', '.cmmtpl', '.cmproj', '.cmrec', '.cpi', '.cst', '.cvc', '.cx3', '.d2v', '.d3v', '.dat', '.dav', '.dce',
'.dck', '.dcr', '.dcr', '.ddat', '.dif', '.dir', '.divx', '.dlx', '.dmb', '.dmsd', '.dmsd3d', '.dmsm', '.dmsm3d', '.dmss',
'.dmx', '.dnc', '.dpa', '.dpg', '.dream', '.dsy', '.dv', '.dv-avi', '.dv4', '.dvdmedia', '.dvr', '.dvr-ms', '.dvx', '.dxr',
'.dzm', '.dzp', '.dzt', '.edl', '.evo', '.eye', '.ezt', '.f4p', '.f4v', '.fbr', '.fbr', '.fbz', '.fcp', '.fcproject',
'.ffd', '.flc', '.flh', '.fli', '.flv', '.flx', '.gfp', '.gl', '.gom', '.grasp', '.gts', '.gvi', '.gvp', '.h264', '.hdmov',
'.hkm', '.ifo', '.imovieproj', '.imovieproject', '.ircp', '.irf', '.ism', '.ismc', '.ismv', '.iva', '.ivf', '.ivr', '.ivs',
'.izz', '.izzy', '.jss', '.jts', '.jtv', '.k3g', '.kmv', '.ktn', '.lrec', '.lsf', '.lsx', '.m15', '.m1pg', '.m1v', '.m21',
'.m21', '.m2a', '.m2p', '.m2t', '.m2ts', '.m2v', '.m4e', '.m4u', '.m4v', '.m75', '.mani', '.meta', '.mgv', '.mj2', '.mjp',
'.mjpg', '.mk3d', '.mkv', '.mmv', '.mnv', '.mob', '.mod', '.modd', '.moff', '.moi', '.moov', '.mov', '.movie', '.mp21',
'.mp21', '.mp2v', '.mp4', '.mp4v', '.mpe', '.mpeg', '.mpeg1', '.mpeg4', '.mpf', '.mpg', '.mpg2', '.mpgindex', '.mpl',
'.mpl', '.mpls', '.mpsub', '.mpv', '.mpv2', '.mqv', '.msdvd', '.mse', '.msh', '.mswmm', '.mts', '.mtv', '.mvb', '.mvc',
'.mvd', '.mve', '.mvex', '.mvp', '.mvp', '.mvy', '.mxf', '.mxv', '.mys', '.ncor', '.nsv', '.nut', '.nuv', '.nvc', '.ogm',
'.ogv', '.ogx', '.osp', '.otrkey', '.pac', '.par', '.pds', '.pgi', '.photoshow', '.piv', '.pjs', '.playlist', '.plproj',
'.pmf', '.pmv', '.pns', '.ppj', '.prel', '.pro', '.prproj', '.prtl', '.psb', '.psh', '.pssd', '.pva', '.pvr', '.pxv',
'.qt', '.qtch', '.qtindex', '.qtl', '.qtm', '.qtz', '.r3d', '.rcd', '.rcproject', '.rdb', '.rec', '.rm', '.rmd', '.rmd',
'.rmp', '.rms', '.rmv', '.rmvb', '.roq', '.rp', '.rsx', '.rts', '.rts', '.rum', '.rv', '.rvid', '.rvl', '.sbk', '.sbt',
'.scc', '.scm', '.scm', '.scn', '.screenflow', '.sec', '.sedprj', '.seq', '.sfd', '.sfvidcap', '.siv', '.smi', '.smi',
'.smil', '.smk', '.sml', '.smv', '.spl', '.sqz', '.srt', '.ssf', '.ssm', '.stl', '.str', '.stx', '.svi', '.swf', '.swi',
'.swt', '.tda3mt', '.tdx', '.thp', '.tivo', '.tix', '.tod', '.tp', '.tp0', '.tpd', '.tpr', '.trp', '.ts', '.tsp', '.ttxt',
'.tvs', '.usf', '.usm', '.vc1', '.vcpf', '.vcr', '.vcv', '.vdo', '.vdr', '.vdx', '.veg','.vem', '.vep', '.vf', '.vft',
'.vfw', '.vfz', '.vgz', '.vid', '.video', '.viewlet', '.viv', '.vivo', '.vlab', '.vob', '.vp3', '.vp6', '.vp7', '.vpj',
'.vro', '.vs4', '.vse', '.vsp', '.w32', '.wcp', '.webm', '.wlmp', '.wm', '.wmd', '.wmmp', '.wmv', '.wmx', '.wot', '.wp3',
'.wpl', '.wtv', '.wve', '.wvx', '.xej', '.xel', '.xesc', '.xfl', '.xlmv', '.xmv', '.xvid', '.y4m', '.yog', '.yuv', '.zeg',
'.zm1', '.zm2', '.zm3', '.zmv'  )
        if fol_name in os.listdir():
            for j in range(len(f_list)-1):
                file_name = f_list[j]
                print(file_name)
                if file_name.endswith(v_format):
                    v_copy_path=i+"//video"
                    # if path exist copy the file
                    if v_copy_path in os.listdir:
                        shutil.copyfile(file_name,v_copy_path)
                        print("v_copy_done")
                # if path does not exist make the path then copy
                    else:
                        os.makedirs(i+"//video")
                        shutil.copyfile(file_name,v_copy_path)
                        print("v_fol_md_cpy_dn")
                        print("v_cpy_dn")
                # move the file_name in fol_name//video
                else:
                    i_copy_path=i+"//img"
                    #  if path exist then copy
                    if i_copy_path in os.listdir:
                        shutil.copyfile(file_name,i_copy_path)
                        print("i_cpy_dn")
                    #  if path do not exist then make path and them copy
                    else:
                        os.mkdir(i+"//img")
                        shutil.copyfile(file_name,i_copy_path)
                        print("i_fol_md_cpy_dn")
                        print("i_cpy_dn")
                    # move the file_name in fol_name//img
        else:
            print(i)
            os.makedirs(i,exist_ok=True)
            print("nw_fol", i, " md")
            for j in range(len(f_list)):
                print("in")
                file_name = f_list[j]
                print(file_name)
                if file_name.endswith(v_format):
                    v_copy_path=i+"//video"
                    # if path exist copy the file
                    dir_list=os.listdir()
                    if v_copy_path in dir_list:
                        shutil.copyfile(file_name,v_copy_path)
                        print("v_copy_done")
                # if path does not exist make the path then copy
                    else:
                        os.makedirs(i+"//video",exist_ok=True)
                        shutil.copy(file_name,v_copy_path)
                        print("v_fol_md_cpy_dn")
                        print("v_cpy_dn")
                    # move the file_name in fol_name//video
                else:
                    i_copy_path=i+"//img"
                    #  if path exist then copy
                    if i_copy_path in os.listdir():
                        shutil.copyfile(file_name,i_copy_path)
                        print("i_cpy_dn")
                    #  if path do not exist then make path and them copy
                    else:
                        os.makedirs(i+"//img",exist_ok=True)
                        shutil.copy(file_name,i_copy_path)
                        print("i_fol_md_cpy_dn")
                        print("i_cpy_dn")
                        # move the file_name in fol_name//img

# %%
copy_file()

# %%
def copy_file(data):
    cr_date = data
    fol_name = list(cr_date.keys())
    for i in cr_date.keys():
        f_list = cr_date[i]
        # print(f_list)
        current_directory = os.getcwd()
        v_format=(
'.264', '.3g2', '.3gp', '.3gp2', '.3gpp', '.3gpp2', '.3mm', '.3p2', '.60d', '.787', '.89', '.aaf', '.aec', '.aep', '.aepx',
'.aet', '.aetx', '.ajp', '.ale', '.am', '.amc', '.amv', '.amx', '.anim', '.aqt', '.arcut', '.arf', '.asf', '.asx', '.avb',
'.avc', '.avd', '.avi', '.avp', '.avs', '.avs', '.avv', '.axm', '.bdm', '.bdmv', '.bdt2', '.bdt3', '.bik', '.bin', '.bix',
'.bmk', '.bnp', '.box', '.bs4', '.bsf', '.bvr', '.byu', '.camproj', '.camrec', '.camv', '.ced', '.cel', '.cine', '.cip',
'.clpi', '.cmmp', '.cmmtpl', '.cmproj', '.cmrec', '.cpi', '.cst', '.cvc', '.cx3', '.d2v', '.d3v', '.dat', '.dav', '.dce',
'.dck', '.dcr', '.dcr', '.ddat', '.dif', '.dir', '.divx', '.dlx', '.dmb', '.dmsd', '.dmsd3d', '.dmsm', '.dmsm3d', '.dmss',
'.dmx', '.dnc', '.dpa', '.dpg', '.dream', '.dsy', '.dv', '.dv-avi', '.dv4', '.dvdmedia', '.dvr', '.dvr-ms', '.dvx', '.dxr',
'.dzm', '.dzp', '.dzt', '.edl', '.evo', '.eye', '.ezt', '.f4p', '.f4v', '.fbr', '.fbr', '.fbz', '.fcp', '.fcproject',
'.ffd', '.flc', '.flh', '.fli', '.flv', '.flx', '.gfp', '.gl', '.gom', '.grasp', '.gts', '.gvi', '.gvp', '.h264', '.hdmov',
'.hkm', '.ifo', '.imovieproj', '.imovieproject', '.ircp', '.irf', '.ism', '.ismc', '.ismv', '.iva', '.ivf', '.ivr', '.ivs',
'.izz', '.izzy', '.jss', '.jts', '.jtv', '.k3g', '.kmv', '.ktn', '.lrec', '.lsf', '.lsx', '.m15', '.m1pg', '.m1v', '.m21',
'.m21', '.m2a', '.m2p', '.m2t', '.m2ts', '.m2v', '.m4e', '.m4u', '.m4v', '.m75', '.mani', '.meta', '.mgv', '.mj2', '.mjp',
'.mjpg', '.mk3d', '.mkv', '.mmv', '.mnv', '.mob', '.mod', '.modd', '.moff', '.moi', '.moov', '.mov', '.movie', '.mp21',
'.mp21', '.mp2v', '.mp4', '.mp4v', '.mpe', '.mpeg', '.mpeg1', '.mpeg4', '.mpf', '.mpg', '.mpg2', '.mpgindex', '.mpl',
'.mpl', '.mpls', '.mpsub', '.mpv', '.mpv2', '.mqv', '.msdvd', '.mse', '.msh', '.mswmm', '.mts', '.mtv', '.mvb', '.mvc',
'.mvd', '.mve', '.mvex', '.mvp', '.mvp', '.mvy', '.mxf', '.mxv', '.mys', '.ncor', '.nsv', '.nut', '.nuv', '.nvc', '.ogm',
'.ogv', '.ogx', '.osp', '.otrkey', '.pac', '.par', '.pds', '.pgi', '.photoshow', '.piv', '.pjs', '.playlist', '.plproj',
'.pmf', '.pmv', '.pns', '.ppj', '.prel', '.pro', '.prproj', '.prtl', '.psb', '.psh', '.pssd', '.pva', '.pvr', '.pxv',
'.qt', '.qtch', '.qtindex', '.qtl', '.qtm', '.qtz', '.r3d', '.rcd', '.rcproject', '.rdb', '.rec', '.rm', '.rmd', '.rmd',
'.rmp', '.rms', '.rmv', '.rmvb', '.roq', '.rp', '.rsx', '.rts', '.rts', '.rum', '.rv', '.rvid', '.rvl', '.sbk', '.sbt',
'.scc', '.scm', '.scm', '.scn', '.screenflow', '.sec', '.sedprj', '.seq', '.sfd', '.sfvidcap', '.siv', '.smi', '.smi',
'.smil', '.smk', '.sml', '.smv', '.spl', '.sqz', '.srt', '.ssf', '.ssm', '.stl', '.str', '.stx', '.svi', '.swf', '.swi',
'.swt', '.tda3mt', '.tdx', '.thp', '.tivo', '.tix', '.tod', '.tp', '.tp0', '.tpd', '.tpr', '.trp', '.ts', '.tsp', '.ttxt',
'.tvs', '.usf', '.usm', '.vc1', '.vcpf', '.vcr', '.vcv', '.vdo', '.vdr', '.vdx', '.veg','.vem', '.vep', '.vf', '.vft',
'.vfw', '.vfz', '.vgz', '.vid', '.video', '.viewlet', '.viv', '.vivo', '.vlab', '.vob', '.vp3', '.vp6', '.vp7', '.vpj',
'.vro', '.vs4', '.vse', '.vsp', '.w32', '.wcp', '.webm', '.wlmp', '.wm', '.wmd', '.wmmp', '.wmv', '.wmx', '.wot', '.wp3',
'.wpl', '.wtv', '.wve', '.wvx', '.xej', '.xel', '.xesc', '.xfl', '.xlmv', '.xmv', '.xvid', '.y4m', '.yog', '.yuv', '.zeg',
'.zm1', '.zm2', '.zm3', '.zmv'  )
        if fol_name in os.listdir():
            for j in range(len(f_list)-1):
                file_name = f_list[j]
                print(file_name)
                if file_name.endswith(v_format):
                    v_copy_path=i+"//video"
                    # if path exist copy the file
                    if v_copy_path in os.listdir:
                        shutil.copyfile(file_name,v_copy_path)
                        print("v_copy_done")
                # if path does not exist make the path then copy
                    else:
                        os.makedirs(i+"//video")
                        shutil.copyfile(file_name,v_copy_path)
                        print("v_fol_md_cpy_dn")
                        print("v_cpy_dn")
                # move the file_name in fol_name//video
                else:
                    i_copy_path=i+"//img"
                    #  if path exist then copy
                    if i_copy_path in os.listdir:
                        shutil.copyfile(file_name,i_copy_path)
                        print("i_cpy_dn")
                    #  if path do not exist then make path and them copy
                    else:
                        os.mkdir(i+"//img")
                        shutil.copyfile(file_name,i_copy_path)
                        print("i_fol_md_cpy_dn")
                        print("i_cpy_dn")
                    # move the file_name in fol_name//img
        else:
            print(i)
            os.makedirs(i,exist_ok=True)
            print("nw_fol", i, " md")
            for j in range(len(f_list)):
                print("in")
                file_name = f_list[j]
                print(file_name)
                if file_name.endswith(v_format):
                    v_copy_path=i+"//video"
                    # if path exist copy the file
                    dir_list=os.listdir()
                    if v_copy_path in dir_list:
                        shutil.copyfile(file_name,v_copy_path)
                        print("v_copy_done")
                # if path does not exist make the path then copy
                    else:
                        os.makedirs(i+"//video",exist_ok=True)
                        shutil.copy(file_name,v_copy_path)
                        print("v_fol_md_cpy_dn")
                        print("v_cpy_dn")
                    # move the file_name in fol_name//video
                else:
                    i_copy_path=i+"//img"
                    #  if path exist then copy
                    if i_copy_path in os.listdir():
                        shutil.copyfile(file_name,i_copy_path)
                        print("i_cpy_dn")
                    #  if path do not exist then make path and them copy
                    else:
                        os.makedirs(i+"//img",exist_ok=True)
                        shutil.copy(file_name,i_copy_path)
                        print("i_fol_md_cpy_dn")
                        print("i_cpy_dn")
                        # move the file_name in fol_name//img
# Out:
# True

# %%
def file_sort(path):
    data = []
    dir_list = os.listdir(path)
    for i in range(len(dir_list)-1)
        if os.path.isdir(path+"\\"+i):
            new_path = path+"\\"+i
            data.append(cr_date(new_path))
        elif os.path.isfile(path+"\\"+i):
            data.append(cr_date(path))

    for i in range(len(data)-1):
        copy_file(data[i])

# %%
import os
import time
import shutil


# Fuction to make dir with date and file path 
def cr_date(path):
    os.chdir(path)
    a = os.listdir()
    cr_date={}
    for i in range(len(a)-1):
        cr_T=(os.path.getmtime(a[i]))
        cr_time = time.ctime(cr_T)
        cr_t_obj = time.strptime(cr_time)
        date = time.strftime("%Y-%m-%d", cr_t_obj)
        file_path = path + "//" + a[i]
        if date in cr_date.keys():
            cr_date[date].append(file_path)
        else:
            cr_date[date]=[file_path]
    return(cr_date)

#  Fuction to copy files in the proper place using dir made in cr_date Fuction
def copy_file(data):
    cr_date = data
    fol_name = list(cr_date.keys())
    for i in cr_date.keys():
        f_list = cr_date[i]
        # print(f_list)
        current_directory = os.getcwd()
        v_format=(
'.264', '.3g2', '.3gp', '.3gp2', '.3gpp', '.3gpp2', '.3mm', '.3p2', '.60d', '.787', '.89', '.aaf', '.aec', '.aep', '.aepx',
'.aet', '.aetx', '.ajp', '.ale', '.am', '.amc', '.amv', '.amx', '.anim', '.aqt', '.arcut', '.arf', '.asf', '.asx', '.avb',
'.avc', '.avd', '.avi', '.avp', '.avs', '.avs', '.avv', '.axm', '.bdm', '.bdmv', '.bdt2', '.bdt3', '.bik', '.bin', '.bix',
'.bmk', '.bnp', '.box', '.bs4', '.bsf', '.bvr', '.byu', '.camproj', '.camrec', '.camv', '.ced', '.cel', '.cine', '.cip',
'.clpi', '.cmmp', '.cmmtpl', '.cmproj', '.cmrec', '.cpi', '.cst', '.cvc', '.cx3', '.d2v', '.d3v', '.dat', '.dav', '.dce',
'.dck', '.dcr', '.dcr', '.ddat', '.dif', '.dir', '.divx', '.dlx', '.dmb', '.dmsd', '.dmsd3d', '.dmsm', '.dmsm3d', '.dmss',
'.dmx', '.dnc', '.dpa', '.dpg', '.dream', '.dsy', '.dv', '.dv-avi', '.dv4', '.dvdmedia', '.dvr', '.dvr-ms', '.dvx', '.dxr',
'.dzm', '.dzp', '.dzt', '.edl', '.evo', '.eye', '.ezt', '.f4p', '.f4v', '.fbr', '.fbr', '.fbz', '.fcp', '.fcproject',
'.ffd', '.flc', '.flh', '.fli', '.flv', '.flx', '.gfp', '.gl', '.gom', '.grasp', '.gts', '.gvi', '.gvp', '.h264', '.hdmov',
'.hkm', '.ifo', '.imovieproj', '.imovieproject', '.ircp', '.irf', '.ism', '.ismc', '.ismv', '.iva', '.ivf', '.ivr', '.ivs',
'.izz', '.izzy', '.jss', '.jts', '.jtv', '.k3g', '.kmv', '.ktn', '.lrec', '.lsf', '.lsx', '.m15', '.m1pg', '.m1v', '.m21',
'.m21', '.m2a', '.m2p', '.m2t', '.m2ts', '.m2v', '.m4e', '.m4u', '.m4v', '.m75', '.mani', '.meta', '.mgv', '.mj2', '.mjp',
'.mjpg', '.mk3d', '.mkv', '.mmv', '.mnv', '.mob', '.mod', '.modd', '.moff', '.moi', '.moov', '.mov', '.movie', '.mp21',
'.mp21', '.mp2v', '.mp4', '.mp4v', '.mpe', '.mpeg', '.mpeg1', '.mpeg4', '.mpf', '.mpg', '.mpg2', '.mpgindex', '.mpl',
'.mpl', '.mpls', '.mpsub', '.mpv', '.mpv2', '.mqv', '.msdvd', '.mse', '.msh', '.mswmm', '.mts', '.mtv', '.mvb', '.mvc',
'.mvd', '.mve', '.mvex', '.mvp', '.mvp', '.mvy', '.mxf', '.mxv', '.mys', '.ncor', '.nsv', '.nut', '.nuv', '.nvc', '.ogm',
'.ogv', '.ogx', '.osp', '.otrkey', '.pac', '.par', '.pds', '.pgi', '.photoshow', '.piv', '.pjs', '.playlist', '.plproj',
'.pmf', '.pmv', '.pns', '.ppj', '.prel', '.pro', '.prproj', '.prtl', '.psb', '.psh', '.pssd', '.pva', '.pvr', '.pxv',
'.qt', '.qtch', '.qtindex', '.qtl', '.qtm', '.qtz', '.r3d', '.rcd', '.rcproject', '.rdb', '.rec', '.rm', '.rmd', '.rmd',
'.rmp', '.rms', '.rmv', '.rmvb', '.roq', '.rp', '.rsx', '.rts', '.rts', '.rum', '.rv', '.rvid', '.rvl', '.sbk', '.sbt',
'.scc', '.scm', '.scm', '.scn', '.screenflow', '.sec', '.sedprj', '.seq', '.sfd', '.sfvidcap', '.siv', '.smi', '.smi',
'.smil', '.smk', '.sml', '.smv', '.spl', '.sqz', '.srt', '.ssf', '.ssm', '.stl', '.str', '.stx', '.svi', '.swf', '.swi',
'.swt', '.tda3mt', '.tdx', '.thp', '.tivo', '.tix', '.tod', '.tp', '.tp0', '.tpd', '.tpr', '.trp', '.ts', '.tsp', '.ttxt',
'.tvs', '.usf', '.usm', '.vc1', '.vcpf', '.vcr', '.vcv', '.vdo', '.vdr', '.vdx', '.veg','.vem', '.vep', '.vf', '.vft',
'.vfw', '.vfz', '.vgz', '.vid', '.video', '.viewlet', '.viv', '.vivo', '.vlab', '.vob', '.vp3', '.vp6', '.vp7', '.vpj',
'.vro', '.vs4', '.vse', '.vsp', '.w32', '.wcp', '.webm', '.wlmp', '.wm', '.wmd', '.wmmp', '.wmv', '.wmx', '.wot', '.wp3',
'.wpl', '.wtv', '.wve', '.wvx', '.xej', '.xel', '.xesc', '.xfl', '.xlmv', '.xmv', '.xvid', '.y4m', '.yog', '.yuv', '.zeg',
'.zm1', '.zm2', '.zm3', '.zmv'  )
        if fol_name in os.listdir():
            for j in range(len(f_list)-1):
                file_name = f_list[j]
                print(file_name)
                if os.path.isdir(file_name):
                    pass
                elif os.path.isfile(file_name):
                    if file_name.endswith(v_format):
                        v_copy_path=i+"//video"
                        # if path exist copy the file
                        if v_copy_path in os.listdir:
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_copy_done")
                    # if path does not exist make the path then copy
                        else:
                            os.makedirs(i+"//video")
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_fol_md_cpy_dn")
                            print("v_cpy_dn")
                    # move the file_name in fol_name//video
                    else:
                        i_copy_path=i+"//img"
                        #  if path exist then copy
                        if i_copy_path in os.listdir:
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_cpy_dn")
                        #  if path do not exist then make path and them copy
                        else:
                            os.mkdir(i+"//img")
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_fol_md_cpy_dn")
                            print("i_cpy_dn")
                        # move the file_name in fol_name//img
        else:
            print(i)
            os.makedirs(i,exist_ok=True)
            print("nw_fol", i, " md")
            for j in range(len(f_list)):
                print("in")
                file_name = f_list[j]
                print(file_name)
                if os.path.isdir(file_name):
                    pass
                else:    
                    if file_name.endswith(v_format):
                        v_copy_path=i+"//video"
                        # if path exist copy the file
                        dir_list=os.listdir()
                        if v_copy_path in dir_list:
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_copy_done")
                    # if path does not exist make the path then copy
                        else:
                            os.makedirs(i+"//video",exist_ok=True)
                            shutil.copy(file_name,v_copy_path)
                            print("v_fol_md_cpy_dn")
                            print("v_cpy_dn")
                        # move the file_name in fol_name//video
                    else:
                        i_copy_path=i+"//img"
                        #  if path exist then copy
                        if i_copy_path in os.listdir():
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_cpy_dn")
                        #  if path do not exist then make path and them copy
                        else:
                            os.makedirs(i+"//img",exist_ok=True)
                            shutil.copy(file_name,i_copy_path)
                            print("i_fol_md_cpy_dn")
                            print("i_cpy_dn")
                            # move the file_name in fol_name//img



# Fuction to call above both fuctions
def file_sort(path):
    data = []
    dir_list = os.listdir(path)
    for i in range(len(dir_list)-1):
        if os.path.isdir(path+"\\"+dir_list[i]):
            new_path = path+"\\"+dir_list[i]
            data.append(cr_date(new_path))
        elif os.path.isfile(path+"\\"+dir_list[i]):
            data.append(cr_date(path))

    print(data)
    # for i in range(len(data)-1):
    #     copy_file(data[i])

file_sort("D:\\test")

# %%
# Done

import os
import time
import shutil


# Fuction to make dir with date and file path 
def cr_date(path):
    os.chdir(path)
    a = os.listdir()
    cr_date={}
    for i in range(len(a)):
        cr_T=(os.path.getmtime(a[i]))
        cr_time = time.ctime(cr_T)
        cr_t_obj = time.strptime(cr_time)
        date = time.strftime("%Y-%m-%d", cr_t_obj)
        file_path = path + "\\" + a[i]
        if date in cr_date.keys():
            cr_date[date].append(file_path)
        else:
            cr_date[date]=[file_path]
    return(cr_date)

#  Fuction to copy files in the proper place using dir made in cr_date Fuction
def copy_file(data, copy_path):
    os.chdir(copy_path)
    cr_date = data
    fol_name = list(cr_date.keys())
    for i in cr_date.keys():
        f_list = cr_date[i]
        # print(f_list)
        current_directory = os.getcwd()
        v_format=(
'.264', '.3g2', '.3gp', '.3gp2', '.3gpp', '.3gpp2', '.3mm', '.3p2', '.60d', '.787', '.89', '.aaf', '.aec', '.aep', '.aepx',
'.aet', '.aetx', '.ajp', '.ale', '.am', '.amc', '.amv', '.amx', '.anim', '.aqt', '.arcut', '.arf', '.asf', '.asx', '.avb',
'.avc', '.avd', '.avi', '.avp', '.avs', '.avs', '.avv', '.axm', '.bdm', '.bdmv', '.bdt2', '.bdt3', '.bik', '.bin', '.bix',
'.bmk', '.bnp', '.box', '.bs4', '.bsf', '.bvr', '.byu', '.camproj', '.camrec', '.camv', '.ced', '.cel', '.cine', '.cip',
'.clpi', '.cmmp', '.cmmtpl', '.cmproj', '.cmrec', '.cpi', '.cst', '.cvc', '.cx3', '.d2v', '.d3v', '.dat', '.dav', '.dce',
'.dck', '.dcr', '.dcr', '.ddat', '.dif', '.dir', '.divx', '.dlx', '.dmb', '.dmsd', '.dmsd3d', '.dmsm', '.dmsm3d', '.dmss',
'.dmx', '.dnc', '.dpa', '.dpg', '.dream', '.dsy', '.dv', '.dv-avi', '.dv4', '.dvdmedia', '.dvr', '.dvr-ms', '.dvx', '.dxr',
'.dzm', '.dzp', '.dzt', '.edl', '.evo', '.eye', '.ezt', '.f4p', '.f4v', '.fbr', '.fbr', '.fbz', '.fcp', '.fcproject',
'.ffd', '.flc', '.flh', '.fli', '.flv', '.flx', '.gfp', '.gl', '.gom', '.grasp', '.gts', '.gvi', '.gvp', '.h264', '.hdmov',
'.hkm', '.ifo', '.imovieproj', '.imovieproject', '.ircp', '.irf', '.ism', '.ismc', '.ismv', '.iva', '.ivf', '.ivr', '.ivs',
'.izz', '.izzy', '.jss', '.jts', '.jtv', '.k3g', '.kmv', '.ktn', '.lrec', '.lsf', '.lsx', '.m15', '.m1pg', '.m1v', '.m21',
'.m21', '.m2a', '.m2p', '.m2t', '.m2ts', '.m2v', '.m4e', '.m4u', '.m4v', '.m75', '.mani', '.meta', '.mgv', '.mj2', '.mjp',
'.mjpg', '.mk3d', '.mkv', '.mmv', '.mnv', '.mob', '.mod', '.modd', '.moff', '.moi', '.moov', '.mov', '.movie', '.mp21',
'.mp21', '.mp2v', '.mp4', '.mp4v', '.mpe', '.mpeg', '.mpeg1', '.mpeg4', '.mpf', '.mpg', '.mpg2', '.mpgindex', '.mpl',
'.mpl', '.mpls', '.mpsub', '.mpv', '.mpv2', '.mqv', '.msdvd', '.mse', '.msh', '.mswmm', '.mts', '.mtv', '.mvb', '.mvc',
'.mvd', '.mve', '.mvex', '.mvp', '.mvp', '.mvy', '.mxf', '.mxv', '.mys', '.ncor', '.nsv', '.nut', '.nuv', '.nvc', '.ogm',
'.ogv', '.ogx', '.osp', '.otrkey', '.pac', '.par', '.pds', '.pgi', '.photoshow', '.piv', '.pjs', '.playlist', '.plproj',
'.pmf', '.pmv', '.pns', '.ppj', '.prel', '.pro', '.prproj', '.prtl', '.psb', '.psh', '.pssd', '.pva', '.pvr', '.pxv',
'.qt', '.qtch', '.qtindex', '.qtl', '.qtm', '.qtz', '.r3d', '.rcd', '.rcproject', '.rdb', '.rec', '.rm', '.rmd', '.rmd',
'.rmp', '.rms', '.rmv', '.rmvb', '.roq', '.rp', '.rsx', '.rts', '.rts', '.rum', '.rv', '.rvid', '.rvl', '.sbk', '.sbt',
'.scc', '.scm', '.scm', '.scn', '.screenflow', '.sec', '.sedprj', '.seq', '.sfd', '.sfvidcap', '.siv', '.smi', '.smi',
'.smil', '.smk', '.sml', '.smv', '.spl', '.sqz', '.srt', '.ssf', '.ssm', '.stl', '.str', '.stx', '.svi', '.swf', '.swi',
'.swt', '.tda3mt', '.tdx', '.thp', '.tivo', '.tix', '.tod', '.tp', '.tp0', '.tpd', '.tpr', '.trp', '.ts', '.tsp', '.ttxt',
'.tvs', '.usf', '.usm', '.vc1', '.vcpf', '.vcr', '.vcv', '.vdo', '.vdr', '.vdx', '.veg','.vem', '.vep', '.vf', '.vft',
'.vfw', '.vfz', '.vgz', '.vid', '.video', '.viewlet', '.viv', '.vivo', '.vlab', '.vob', '.vp3', '.vp6', '.vp7', '.vpj',
'.vro', '.vs4', '.vse', '.vsp', '.w32', '.wcp', '.webm', '.wlmp', '.wm', '.wmd', '.wmmp', '.wmv', '.wmx', '.wot', '.wp3',
'.wpl', '.wtv', '.wve', '.wvx', '.xej', '.xel', '.xesc', '.xfl', '.xlmv', '.xmv', '.xvid', '.y4m', '.yog', '.yuv', '.zeg',
'.zm1', '.zm2', '.zm3', '.zmv'  )
        if fol_name in os.listdir():
            for j in range(len(f_list)):
                file_name = f_list[j]
                print(file_name)
                if os.path.isdir(file_name):
                    pass
                else:
                    if file_name.endswith(v_format):
                        v_copy_path=copy_path + "\\"+ i+"\\video"
                        # if path exist copy the file
                        if v_copy_path in os.listdir:
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_copy_done")
                    # if path does not exist make the path then copy
                        else:
                            os.makedirs(i+"\\video")
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_fol_md_cpy_dn")
                            print("v_cpy_dn")
                    # move the file_name in fol_name\\video
                    else:
                        i_copy_path=copy_path + "\\"+ i+"\\img"
                        #  if path exist then copy
                        if i_copy_path in os.listdir:
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_cpy_dn")
                        #  if path do not exist then make path and them copy
                        else:
                            os.mkdir(i+"\\img")
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_fol_md_cpy_dn")
                            print("i_cpy_dn")
                        # move the file_name in fol_name\\img
        else:
            print(i)
            os.makedirs(i,exist_ok=True)
            print("nw_fol", i, " md")
            for j in range(len(f_list)):
                print("in")
                file_name = f_list[j]
                print(file_name)
                if os.path.isdir(file_name):
                    pass
                else:    
                    if file_name.endswith(v_format):
                        v_copy_path=copy_path + "\\"+i+"\\video"
                        # if path exist copy the file
                        dir_list=os.listdir()
                        if v_copy_path in dir_list:
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_copy_done")
                    # if path does not exist make the path then copy
                        else:
                            os.makedirs(i+"\\video",exist_ok=True)
                            shutil.copy(file_name,v_copy_path)
                            print("v_fol_md_cpy_dn")
                            print("v_cpy_dn")
                        # move the file_name in fol_name\\video
                    else:
                        i_copy_path=copy_path + "\\"+i+"\\img"
                        #  if path exist then copy
                        if i_copy_path in os.listdir():
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_cpy_dn")
                        #  if path do not exist then make path and them copy
                        else:
                            os.makedirs(i+"\\img",exist_ok=True)
                            shutil.copy(file_name,i_copy_path)
                            print("i_fol_md_cpy_dn")
                            print("i_cpy_dn")
                            # move the file_name in fol_name\\img



# Fuction to call above both fuctions
def file_sort(scr_path,copy_path):
    data = []
    dir_list = os.listdir(scr_path)
    for i in range(len(dir_list)):
        if os.path.isfile(scr_path+"\\"+dir_list[i]):
            pass
        if os.path.isdir(scr_path+"\\"+dir_list[i]):
            new_path = scr_path+"\\"+dir_list[i]
            data.append(cr_date(new_path))
    data.append(cr_date(scr_path))
    print("mapping done")
    print(data)
    for i in range(len(data)):
        print(i)
        copy_file(data[i],copy_path=copy_path)

file_sort(scr_path="D:\\test",copy_path="D:\\copy path test")

# %%
# Done

import os
import time
import shutil


# Fuction to make dir with date and file path 
def mapping(path):
    os.chdir(path)
    a = os.listdir()
    cr_date={}
    name = {}
    for i in range(len(a)):
        if os.path.isdir(a[i]):
            new_path = path+"\\"+a[i]
            mapping(new_path)
        else:
            os.chdir(path)
            cr_T=(os.path.getmtime(a[i]))
            cr_time = time.ctime(cr_T)
            cr_t_obj = time.strptime(cr_time)
            date = time.strftime("%Y-%m-%d", cr_t_obj)
            file_path = path + "\\" + a[i]
            if date in cr_date.keys():
                cr_date[date].append(file_path)
                name[date].append(a[i])
            else:
                cr_date[date]=[file_path]
                name[date]=[a[i]]
    return(cr_date,name)

#  Fuction to copy files in the proper place using dir made in cr_date Fuction
def copy_file(data, copy_path,name):
    os.chdir(copy_path)
    cr_date = data
    fol_name = list(cr_date.keys())
    for i in cr_date.keys():
        f_list = cr_date[i]
        # print(f_list)
        current_directory = os.getcwd()
        v_format=(
'.264', '.3g2', '.3gp', '.3gp2', '.3gpp', '.3gpp2', '.3mm', '.3p2', '.60d', '.787', '.89', '.aaf', '.aec', '.aep', '.aepx',
'.aet', '.aetx', '.ajp', '.ale', '.am', '.amc', '.amv', '.amx', '.anim', '.aqt', '.arcut', '.arf', '.asf', '.asx', '.avb',
'.avc', '.avd', '.avi', '.avp', '.avs', '.avs', '.avv', '.axm', '.bdm', '.bdmv', '.bdt2', '.bdt3', '.bik', '.bin', '.bix',
'.bmk', '.bnp', '.box', '.bs4', '.bsf', '.bvr', '.byu', '.camproj', '.camrec', '.camv', '.ced', '.cel', '.cine', '.cip',
'.clpi', '.cmmp', '.cmmtpl', '.cmproj', '.cmrec', '.cpi', '.cst', '.cvc', '.cx3', '.d2v', '.d3v', '.dat', '.dav', '.dce',
'.dck', '.dcr', '.dcr', '.ddat', '.dif', '.dir', '.divx', '.dlx', '.dmb', '.dmsd', '.dmsd3d', '.dmsm', '.dmsm3d', '.dmss',
'.dmx', '.dnc', '.dpa', '.dpg', '.dream', '.dsy', '.dv', '.dv-avi', '.dv4', '.dvdmedia', '.dvr', '.dvr-ms', '.dvx', '.dxr',
'.dzm', '.dzp', '.dzt', '.edl', '.evo', '.eye', '.ezt', '.f4p', '.f4v', '.fbr', '.fbr', '.fbz', '.fcp', '.fcproject',
'.ffd', '.flc', '.flh', '.fli', '.flv', '.flx', '.gfp', '.gl', '.gom', '.grasp', '.gts', '.gvi', '.gvp', '.h264', '.hdmov',
'.hkm', '.ifo', '.imovieproj', '.imovieproject', '.ircp', '.irf', '.ism', '.ismc', '.ismv', '.iva', '.ivf', '.ivr', '.ivs',
'.izz', '.izzy', '.jss', '.jts', '.jtv', '.k3g', '.kmv', '.ktn', '.lrec', '.lsf', '.lsx', '.m15', '.m1pg', '.m1v', '.m21',
'.m21', '.m2a', '.m2p', '.m2t', '.m2ts', '.m2v', '.m4e', '.m4u', '.m4v', '.m75', '.mani', '.meta', '.mgv', '.mj2', '.mjp',
'.mjpg', '.mk3d', '.mkv', '.mmv', '.mnv', '.mob', '.mod', '.modd', '.moff', '.moi', '.moov', '.mov', '.movie', '.mp21',
'.mp21', '.mp2v', '.mp4', '.mp4v', '.mpe', '.mpeg', '.mpeg1', '.mpeg4', '.mpf', '.mpg', '.mpg2', '.mpgindex', '.mpl',
'.mpl', '.mpls', '.mpsub', '.mpv', '.mpv2', '.mqv', '.msdvd', '.mse', '.msh', '.mswmm', '.mts', '.mtv', '.mvb', '.mvc',
'.mvd', '.mve', '.mvex', '.mvp', '.mvp', '.mvy', '.mxf', '.mxv', '.mys', '.ncor', '.nsv', '.nut', '.nuv', '.nvc', '.ogm',
'.ogv', '.ogx', '.osp', '.otrkey', '.pac', '.par', '.pds', '.pgi', '.photoshow', '.piv', '.pjs', '.playlist', '.plproj',
'.pmf', '.pmv', '.pns', '.ppj', '.prel', '.pro', '.prproj', '.prtl', '.psb', '.psh', '.pssd', '.pva', '.pvr', '.pxv',
'.qt', '.qtch', '.qtindex', '.qtl', '.qtm', '.qtz', '.r3d', '.rcd', '.rcproject', '.rdb', '.rec', '.rm', '.rmd', '.rmd',
'.rmp', '.rms', '.rmv', '.rmvb', '.roq', '.rp', '.rsx', '.rts', '.rts', '.rum', '.rv', '.rvid', '.rvl', '.sbk', '.sbt',
'.scc', '.scm', '.scm', '.scn', '.screenflow', '.sec', '.sedprj', '.seq', '.sfd', '.sfvidcap', '.siv', '.smi', '.smi',
'.smil', '.smk', '.sml', '.smv', '.spl', '.sqz', '.srt', '.ssf', '.ssm', '.stl', '.str', '.stx', '.svi', '.swf', '.swi',
'.swt', '.tda3mt', '.tdx', '.thp', '.tivo', '.tix', '.tod', '.tp', '.tp0', '.tpd', '.tpr', '.trp', '.ts', '.tsp', '.ttxt',
'.tvs', '.usf', '.usm', '.vc1', '.vcpf', '.vcr', '.vcv', '.vdo', '.vdr', '.vdx', '.veg','.vem', '.vep', '.vf', '.vft',
'.vfw', '.vfz', '.vgz', '.vid', '.video', '.viewlet', '.viv', '.vivo', '.vlab', '.vob', '.vp3', '.vp6', '.vp7', '.vpj',
'.vro', '.vs4', '.vse', '.vsp', '.w32', '.wcp', '.webm', '.wlmp', '.wm', '.wmd', '.wmmp', '.wmv', '.wmx', '.wot', '.wp3',
'.wpl', '.wtv', '.wve', '.wvx', '.xej', '.xel', '.xesc', '.xfl', '.xlmv', '.xmv', '.xvid', '.y4m', '.yog', '.yuv', '.zeg',
'.zm1', '.zm2', '.zm3', '.zmv'  )
        if fol_name in os.listdir():
            for j in range(len(f_list)):
                file_name = f_list[j]
                print(file_name)
                if os.path.isdir(file_name):
                    pass
                else:
                    if file_name.endswith(v_format):
                        v_copy_path=copy_path + "\\"+ i+"\\video"
                        # if path exist copy the file
                        if v_copy_path in os.listdir:
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_copy_done")
                            if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+name[i][j]).st_size:
                                print(True)
                    # if path does not exist make the path then copy
                        else:
                            os.makedirs(i+"\\video")
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_fol_md_cpy_dn")
                            print("v_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+name[i][j]).st_size:
                                print(True)
                    # move the file_name in fol_name\\video
                    else:
                        i_copy_path=copy_path + "\\"+ i+"\\img"
                        #  if path exist then copy
                        if i_copy_path in os.listdir:
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+name[i][j]).st_size:
                                print(True)
                        #  if path do not exist then make path and them copy
                        else:
                            os.mkdir(i+"\\img")
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_fol_md_cpy_dn")
                            print("i_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+name[i][j]).st_size:
                                print(True)
                        # move the file_name in fol_name\\img
        else:
            print(i)
            os.makedirs(i,exist_ok=True)
            print("nw_fol", i, " md")
            for j in range(len(f_list)):
                print("in")
                file_name = f_list[j]
                print(file_name)
                if os.path.isdir(file_name):
                    pass
                else:    
                    if file_name.endswith(v_format):
                        v_copy_path=copy_path + "\\"+i+"\\video"
                        # if path exist copy the file
                        dir_list=os.listdir()
                        if v_copy_path in dir_list:
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_copy_done")
                            if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+name[i][j]).st_size:
                                print(True)
                    # if path does not exist make the path then copy
                        else:
                            os.makedirs(i+"\\video",exist_ok=True)
                            shutil.copy(file_name,v_copy_path)
                            print("v_fol_md_cpy_dn")
                            print("v_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+name[i][j]).st_size:
                                print(True)
                        # move the file_name in fol_name\\video
                    else:
                        i_copy_path=copy_path + "\\"+i+"\\img"
                        #  if path exist then copy
                        if i_copy_path in os.listdir():
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+name[i][j]).st_size:
                                print(True)
                        #  if path do not exist then make path and them copy
                        else:
                            os.makedirs(i+"\\img",exist_ok=True)
                            shutil.copy(file_name,i_copy_path)
                            print("i_fol_md_cpy_dn")
                            print("i_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+name[i][j]).st_size:
                                print(True)
                            # move the file_name in fol_name\\img



# Fuction to call above both fuctions
# def file_sort(scr_path,copy_path):
#     data = []
#     dir_list = os.listdir(scr_path)
#     for i in range(len(dir_list)):
#         if os.path.isdir(scr_path+"\\"+dir_list[i]):
#             new_path = scr_path+"\\"+dir_list[i]
#             data.append(mapping(new_path))
#     data.append(mapping(scr_path))
#     print("mapping done")
#     print(data)
#     for i in range(len(data)):
#         print(i)
#         copy_file(data[i][0],copy_path=copy_path,name=data[i][1])
# file_sort(scr_path="D:\\test",copy_path="D:\\copy path test")
mapping("D:\\test")
# Out:
# ({'2023-01-27': ['D:\\test\\2021-09-22',
#    'D:\\test\\2022-10-15',
#    'D:\\test\\2022-11-07',
#    'D:\\test\\2022-11-28',
#    'D:\\test\\2022-12-02',
#    'D:\\test\\2022-12-14',
#    'D:\\test\\2022-12-16',
#    'D:\\test\\2022-12-19',
#    'D:\\test\\2022-12-21',
#    'D:\\test\\2022-12-23',
#    'D:\\test\\2022-12-25',
#    'D:\\test\\2022-12-28',
#    'D:\\test\\2022-12-30',
#    'D:\\test\\2023-01-02',
#    'D:\\test\\2023-01-06',
#    'D:\\test\\2023-01-20']},
#  {'2023-01-27': ['2021-09-22',
#    '2022-10-15',
#    '2022-11-07',
#    '2022-11-28',
#    '2022-12-02',
#    '2022-12-14',
#    '2022-12-16',
#    '2022-12-19',
#    '2022-12-21',
#    '2022-12-23',
#    '2022-12-25',
#    '2022-12-28',
#    '2022-12-30',
#    '2023-01-02',
#    '2023-01-06',
#    '2023-01-20']})

# %%
import os
os.stat("D:\\backup\\VID_20221231_160153410.mp4")
# Out:
# os.stat_result(st_mode=33206, st_ino=562949953426237, st_dev=2451681399, st_nlink=1, st_uid=0, st_gid=0, st_size=4080195166, st_atime=1674897460, st_mtime=1672483640, st_ctime=1674241543)

# %%
# Done

import os
import time
import shutil


# Fuction to make dir with date and file path 
def cr_date(path):
    os.chdir(path)
    a = os.listdir()
    cr_date={}
    name = {}
    for i in range(len(a)):
        cr_T=(os.path.getmtime(a[i]))
        cr_time = time.ctime(cr_T)
        cr_t_obj = time.strptime(cr_time)
        date = time.strftime("%Y-%m-%d", cr_t_obj)
        file_path = path + "\\" + a[i]
        if date in cr_date.keys():
            cr_date[date].append(file_path)
            name[date].append(a[i])
        else:
            cr_date[date]=[file_path]
            name[date]=[a[i]]
    return(cr_date,name)

#  Fuction to copy files in the proper place using dir made in cr_date Fuction
def copy_file(data, copy_path,name):
    os.chdir(copy_path)
    cr_date = data
    fol_name = list(cr_date.keys())
    for i in cr_date.keys():
        f_list = cr_date[i]
        # print(f_list)
        current_directory = os.getcwd()
        v_format=(
'.264', '.3g2', '.3gp', '.3gp2', '.3gpp', '.3gpp2', '.3mm', '.3p2', '.60d', '.787', '.89', '.aaf', '.aec', '.aep', '.aepx',
'.aet', '.aetx', '.ajp', '.ale', '.am', '.amc', '.amv', '.amx', '.anim', '.aqt', '.arcut', '.arf', '.asf', '.asx', '.avb',
'.avc', '.avd', '.avi', '.avp', '.avs', '.avs', '.avv', '.axm', '.bdm', '.bdmv', '.bdt2', '.bdt3', '.bik', '.bin', '.bix',
'.bmk', '.bnp', '.box', '.bs4', '.bsf', '.bvr', '.byu', '.camproj', '.camrec', '.camv', '.ced', '.cel', '.cine', '.cip',
'.clpi', '.cmmp', '.cmmtpl', '.cmproj', '.cmrec', '.cpi', '.cst', '.cvc', '.cx3', '.d2v', '.d3v', '.dat', '.dav', '.dce',
'.dck', '.dcr', '.dcr', '.ddat', '.dif', '.dir', '.divx', '.dlx', '.dmb', '.dmsd', '.dmsd3d', '.dmsm', '.dmsm3d', '.dmss',
'.dmx', '.dnc', '.dpa', '.dpg', '.dream', '.dsy', '.dv', '.dv-avi', '.dv4', '.dvdmedia', '.dvr', '.dvr-ms', '.dvx', '.dxr',
'.dzm', '.dzp', '.dzt', '.edl', '.evo', '.eye', '.ezt', '.f4p', '.f4v', '.fbr', '.fbr', '.fbz', '.fcp', '.fcproject',
'.ffd', '.flc', '.flh', '.fli', '.flv', '.flx', '.gfp', '.gl', '.gom', '.grasp', '.gts', '.gvi', '.gvp', '.h264', '.hdmov',
'.hkm', '.ifo', '.imovieproj', '.imovieproject', '.ircp', '.irf', '.ism', '.ismc', '.ismv', '.iva', '.ivf', '.ivr', '.ivs',
'.izz', '.izzy', '.jss', '.jts', '.jtv', '.k3g', '.kmv', '.ktn', '.lrec', '.lsf', '.lsx', '.m15', '.m1pg', '.m1v', '.m21',
'.m21', '.m2a', '.m2p', '.m2t', '.m2ts', '.m2v', '.m4e', '.m4u', '.m4v', '.m75', '.mani', '.meta', '.mgv', '.mj2', '.mjp',
'.mjpg', '.mk3d', '.mkv', '.mmv', '.mnv', '.mob', '.mod', '.modd', '.moff', '.moi', '.moov', '.mov', '.movie', '.mp21',
'.mp21', '.mp2v', '.mp4', '.mp4v', '.mpe', '.mpeg', '.mpeg1', '.mpeg4', '.mpf', '.mpg', '.mpg2', '.mpgindex', '.mpl',
'.mpl', '.mpls', '.mpsub', '.mpv', '.mpv2', '.mqv', '.msdvd', '.mse', '.msh', '.mswmm', '.mts', '.mtv', '.mvb', '.mvc',
'.mvd', '.mve', '.mvex', '.mvp', '.mvp', '.mvy', '.mxf', '.mxv', '.mys', '.ncor', '.nsv', '.nut', '.nuv', '.nvc', '.ogm',
'.ogv', '.ogx', '.osp', '.otrkey', '.pac', '.par', '.pds', '.pgi', '.photoshow', '.piv', '.pjs', '.playlist', '.plproj',
'.pmf', '.pmv', '.pns', '.ppj', '.prel', '.pro', '.prproj', '.prtl', '.psb', '.psh', '.pssd', '.pva', '.pvr', '.pxv',
'.qt', '.qtch', '.qtindex', '.qtl', '.qtm', '.qtz', '.r3d', '.rcd', '.rcproject', '.rdb', '.rec', '.rm', '.rmd', '.rmd',
'.rmp', '.rms', '.rmv', '.rmvb', '.roq', '.rp', '.rsx', '.rts', '.rts', '.rum', '.rv', '.rvid', '.rvl', '.sbk', '.sbt',
'.scc', '.scm', '.scm', '.scn', '.screenflow', '.sec', '.sedprj', '.seq', '.sfd', '.sfvidcap', '.siv', '.smi', '.smi',
'.smil', '.smk', '.sml', '.smv', '.spl', '.sqz', '.srt', '.ssf', '.ssm', '.stl', '.str', '.stx', '.svi', '.swf', '.swi',
'.swt', '.tda3mt', '.tdx', '.thp', '.tivo', '.tix', '.tod', '.tp', '.tp0', '.tpd', '.tpr', '.trp', '.ts', '.tsp', '.ttxt',
'.tvs', '.usf', '.usm', '.vc1', '.vcpf', '.vcr', '.vcv', '.vdo', '.vdr', '.vdx', '.veg','.vem', '.vep', '.vf', '.vft',
'.vfw', '.vfz', '.vgz', '.vid', '.video', '.viewlet', '.viv', '.vivo', '.vlab', '.vob', '.vp3', '.vp6', '.vp7', '.vpj',
'.vro', '.vs4', '.vse', '.vsp', '.w32', '.wcp', '.webm', '.wlmp', '.wm', '.wmd', '.wmmp', '.wmv', '.wmx', '.wot', '.wp3',
'.wpl', '.wtv', '.wve', '.wvx', '.xej', '.xel', '.xesc', '.xfl', '.xlmv', '.xmv', '.xvid', '.y4m', '.yog', '.yuv', '.zeg',
'.zm1', '.zm2', '.zm3', '.zmv'  )
        if fol_name in os.listdir():
            for j in range(len(f_list)):
                file_name = f_list[j]
                print(file_name)
                if os.path.isdir(file_name):
                    pass
                else:
                    if file_name.endswith(v_format):
                        v_copy_path=copy_path + "\\"+ i+"\\video"
                        # if path exist copy the file
                        if v_copy_path in os.listdir:
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_copy_done")
                            if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                    # if path does not exist make the path then copy
                        else:
                            os.makedirs(i+"\\video")
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_fol_md_cpy_dn")
                            print("v_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                    # move the file_name in fol_name\\video
                    else:
                        i_copy_path=copy_path + "\\"+ i+"\\img"
                        #  if path exist then copy
                        if i_copy_path in os.listdir:
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                        #  if path do not exist then make path and them copy
                        else:
                            os.mkdir(i+"\\img")
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_fol_md_cpy_dn")
                            print("i_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                        # move the file_name in fol_name\\img
        else:
            print(i)
            os.makedirs(i,exist_ok=True)
            print("nw_fol", i, " md")
            for j in range(len(f_list)):
                print("in")
                file_name = f_list[j]
                print(file_name)
                if os.path.isdir(file_name):
                    pass
                else:    
                    if file_name.endswith(v_format):
                        v_copy_path=copy_path + "\\"+i+"\\video"
                        # if path exist copy the file
                        dir_list=os.listdir()
                        if v_copy_path in dir_list:
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_copy_done")
                            if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                    # if path does not exist make the path then copy
                        else:
                            os.makedirs(i+"\\video",exist_ok=True)
                            shutil.copy(file_name,v_copy_path)
                            print("v_fol_md_cpy_dn")
                            print("v_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                        # move the file_name in fol_name\\video
                    else:
                        i_copy_path=copy_path + "\\"+i+"\\img"
                        #  if path exist then copy
                        if i_copy_path in os.listdir():
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                        #  if path do not exist then make path and them copy
                        else:
                            os.makedirs(i+"\\img",exist_ok=True)
                            shutil.copy(file_name,i_copy_path)
                            print("i_fol_md_cpy_dn")
                            print("i_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                            # move the file_name in fol_name\\img



# Fuction to call above both fuctions
def file_sort(scr_path,copy_path):
    data = []
    dir_list = os.listdir(scr_path)
    for i in range(len(dir_list)):
        if os.path.isfile(scr_path+"\\"+dir_list[i]):
            pass
        if os.path.isdir(scr_path+"\\"+dir_list[i]):
            new_path = scr_path+"\\"+dir_list[i]
            data.append(cr_date(new_path))
    data.append(cr_date(scr_path))
    print("mapping done")
    print(data)
    for i in range(len(data)):
        print(i)
        copy_file(data[i][0],copy_path=copy_path,name=data[i][1])

file_sort(scr_path="D:\\test",copy_path="D:\\copy path test")

# %%
dirs ={}
def find_dirs(path):
    dirs[path] = []
    for i in os.listdir(path):
        if os.path.isdir(path+"\\"+i):
            dirs[path].append(path+"\\"+i)
        else:
            pass
    if path in dirs:
        for i in dirs[path]:
            find_dirs(i)
    else:
        pass
    return list(dirs.keys())

find_dirs("D:\\test")
# Out:
# ['D:\\test',
#  'D:\\test\\2021-03-28',
#  'D:\\test\\2021-03-28\\img',
#  'D:\\test\\2021-09-22',
#  'D:\\test\\2021-09-22\\img',
#  'D:\\test\\2022-10-09',
#  'D:\\test\\2022-10-09\\img',
#  'D:\\test\\2022-10-15',
#  'D:\\test\\2022-10-15\\img',
#  'D:\\test\\2022-10-26',
#  'D:\\test\\2022-10-26\\img',
#  'D:\\test\\2022-11-07',
#  'D:\\test\\2022-11-07\\img',
#  'D:\\test\\2022-11-08',
#  'D:\\test\\2022-11-08\\img',
#  'D:\\test\\2022-11-28',
#  'D:\\test\\2022-11-28\\img',
#  'D:\\test\\2022-12-01',
#  'D:\\test\\2022-12-01\\img',
#  'D:\\test\\2022-12-02',
#  'D:\\test\\2022-12-02\\img',
#  'D:\\test\\2022-12-13',
#  'D:\\test\\2022-12-13\\img',
#  'D:\\test\\2022-12-14',
#  'D:\\test\\2022-12-14\\img',
#  'D:\\test\\2022-12-15',
#  'D:\\test\\2022-12-15\\img',
#  'D:\\test\\2022-12-16',
#  'D:\\test\\2022-12-16\\video',
#  'D:\\test\\2022-12-18',
#  'D:\\test\\2022-12-18\\video',
#  'D:\\test\\2022-12-19',
#  'D:\\test\\2022-12-19\\img',
#  'D:\\test\\2022-12-20',
#  'D:\\test\\2022-12-20\\img',
#  'D:\\test\\2022-12-20\\video',
#  'D:\\test\\2022-12-21',
#  'D:\\test\\2022-12-21\\img',
#  'D:\\test\\2022-12-22',
#  'D:\\test\\2022-12-22\\img',
#  'D:\\test\\2022-12-23',
#  'D:\\test\\2022-12-23\\img',
#  'D:\\test\\2022-12-23\\video',
#  'D:\\test\\2022-12-24',
#  'D:\\test\\2022-12-24\\img',
#  'D:\\test\\2022-12-25',
#  'D:\\test\\2022-12-25\\img',
#  'D:\\test\\2022-12-26',
#  'D:\\test\\2022-12-26\\img',
#  'D:\\test\\2022-12-28',
#  'D:\\test\\2022-12-28\\video',
#  'D:\\test\\2022-12-29',
#  'D:\\test\\2022-12-29\\img',
#  'D:\\test\\2022-12-29\\video',
#  'D:\\test\\2022-12-30',
#  'D:\\test\\2022-12-30\\video',
#  'D:\\test\\2023-01-01',
#  'D:\\test\\2023-01-01\\video',
#  'D:\\test\\2023-01-02',
#  'D:\\test\\2023-01-02\\img',
#  'D:\\test\\2023-01-02\\video',
#  'D:\\test\\2023-01-03',
#  'D:\\test\\2023-01-03\\video',
#  'D:\\test\\2023-01-06',
#  'D:\\test\\2023-01-06\\video',
#  'D:\\test\\2023-01-08',
#  'D:\\test\\2023-01-08\\video',
#  'D:\\test\\2023-01-20',
#  'D:\\test\\2023-01-20\\img']

# %%
import os
import time
import shutil


dirs ={}
def find_dirs(path):
    dirs[path] = []
    for i in os.listdir(path):
        if os.path.isdir(path+"\\"+i):
            dirs[path].append(path+"\\"+i)
        else:
            pass
    if path in dirs:
        for i in dirs[path]:
            find_dirs(i)
    else:
        pass
    return list(dirs.keys())

# Fuction to make dir with date and file path 
def mapping(path):
    cr_date={}
    name = {}
    for i in find_dirs(path):
        os.chdir(i)
        a = os.listdir()
        for i in range(len(a)):
            if os.path.isfile(a[i]):
                cr_T=(os.path.getmtime(a[i]))
                cr_time = time.ctime(cr_T)
                cr_t_obj = time.strptime(cr_time)
                date = time.strftime("%Y-%m-%d", cr_t_obj)
                file_path = path + "\\" + a[i]
                if date in cr_date.keys():
                    cr_date[date].append(file_path)
                    name[date].append(a[i])
                else:
                    cr_date[date]=[file_path]
                    name[date]=[a[i]]
    return(cr_date,name)

mapping("D:\\test")


# fuction to copy files


def copy_file(data, copy_path,name):
    os.chdir(copy_path)
    cr_date = data
    fol_name = list(cr_date.keys())
    for i in cr_date.keys():
        f_list = cr_date[i]
        # print(f_list)
        current_directory = os.getcwd()
        v_format=(
'.264', '.3g2', '.3gp', '.3gp2', '.3gpp', '.3gpp2', '.3mm', '.3p2', '.60d', '.787', '.89', '.aaf', '.aec', '.aep', '.aepx',
'.aet', '.aetx', '.ajp', '.ale', '.am', '.amc', '.amv', '.amx', '.anim', '.aqt', '.arcut', '.arf', '.asf', '.asx', '.avb',
'.avc', '.avd', '.avi', '.avp', '.avs', '.avs', '.avv', '.axm', '.bdm', '.bdmv', '.bdt2', '.bdt3', '.bik', '.bin', '.bix',
'.bmk', '.bnp', '.box', '.bs4', '.bsf', '.bvr', '.byu', '.camproj', '.camrec', '.camv', '.ced', '.cel', '.cine', '.cip',
'.clpi', '.cmmp', '.cmmtpl', '.cmproj', '.cmrec', '.cpi', '.cst', '.cvc', '.cx3', '.d2v', '.d3v', '.dat', '.dav', '.dce',
'.dck', '.dcr', '.dcr', '.ddat', '.dif', '.dir', '.divx', '.dlx', '.dmb', '.dmsd', '.dmsd3d', '.dmsm', '.dmsm3d', '.dmss',
'.dmx', '.dnc', '.dpa', '.dpg', '.dream', '.dsy', '.dv', '.dv-avi', '.dv4', '.dvdmedia', '.dvr', '.dvr-ms', '.dvx', '.dxr',
'.dzm', '.dzp', '.dzt', '.edl', '.evo', '.eye', '.ezt', '.f4p', '.f4v', '.fbr', '.fbr', '.fbz', '.fcp', '.fcproject',
'.ffd', '.flc', '.flh', '.fli', '.flv', '.flx', '.gfp', '.gl', '.gom', '.grasp', '.gts', '.gvi', '.gvp', '.h264', '.hdmov',
'.hkm', '.ifo', '.imovieproj', '.imovieproject', '.ircp', '.irf', '.ism', '.ismc', '.ismv', '.iva', '.ivf', '.ivr', '.ivs',
'.izz', '.izzy', '.jss', '.jts', '.jtv', '.k3g', '.kmv', '.ktn', '.lrec', '.lsf', '.lsx', '.m15', '.m1pg', '.m1v', '.m21',
'.m21', '.m2a', '.m2p', '.m2t', '.m2ts', '.m2v', '.m4e', '.m4u', '.m4v', '.m75', '.mani', '.meta', '.mgv', '.mj2', '.mjp',
'.mjpg', '.mk3d', '.mkv', '.mmv', '.mnv', '.mob', '.mod', '.modd', '.moff', '.moi', '.moov', '.mov', '.movie', '.mp21',
'.mp21', '.mp2v', '.mp4', '.mp4v', '.mpe', '.mpeg', '.mpeg1', '.mpeg4', '.mpf', '.mpg', '.mpg2', '.mpgindex', '.mpl',
'.mpl', '.mpls', '.mpsub', '.mpv', '.mpv2', '.mqv', '.msdvd', '.mse', '.msh', '.mswmm', '.mts', '.mtv', '.mvb', '.mvc',
'.mvd', '.mve', '.mvex', '.mvp', '.mvp', '.mvy', '.mxf', '.mxv', '.mys', '.ncor', '.nsv', '.nut', '.nuv', '.nvc', '.ogm',
'.ogv', '.ogx', '.osp', '.otrkey', '.pac', '.par', '.pds', '.pgi', '.photoshow', '.piv', '.pjs', '.playlist', '.plproj',
'.pmf', '.pmv', '.pns', '.ppj', '.prel', '.pro', '.prproj', '.prtl', '.psb', '.psh', '.pssd', '.pva', '.pvr', '.pxv',
'.qt', '.qtch', '.qtindex', '.qtl', '.qtm', '.qtz', '.r3d', '.rcd', '.rcproject', '.rdb', '.rec', '.rm', '.rmd', '.rmd',
'.rmp', '.rms', '.rmv', '.rmvb', '.roq', '.rp', '.rsx', '.rts', '.rts', '.rum', '.rv', '.rvid', '.rvl', '.sbk', '.sbt',
'.scc', '.scm', '.scm', '.scn', '.screenflow', '.sec', '.sedprj', '.seq', '.sfd', '.sfvidcap', '.siv', '.smi', '.smi',
'.smil', '.smk', '.sml', '.smv', '.spl', '.sqz', '.srt', '.ssf', '.ssm', '.stl', '.str', '.stx', '.svi', '.swf', '.swi',
'.swt', '.tda3mt', '.tdx', '.thp', '.tivo', '.tix', '.tod', '.tp', '.tp0', '.tpd', '.tpr', '.trp', '.ts', '.tsp', '.ttxt',
'.tvs', '.usf', '.usm', '.vc1', '.vcpf', '.vcr', '.vcv', '.vdo', '.vdr', '.vdx', '.veg','.vem', '.vep', '.vf', '.vft',
'.vfw', '.vfz', '.vgz', '.vid', '.video', '.viewlet', '.viv', '.vivo', '.vlab', '.vob', '.vp3', '.vp6', '.vp7', '.vpj',
'.vro', '.vs4', '.vse', '.vsp', '.w32', '.wcp', '.webm', '.wlmp', '.wm', '.wmd', '.wmmp', '.wmv', '.wmx', '.wot', '.wp3',
'.wpl', '.wtv', '.wve', '.wvx', '.xej', '.xel', '.xesc', '.xfl', '.xlmv', '.xmv', '.xvid', '.y4m', '.yog', '.yuv', '.zeg',
'.zm1', '.zm2', '.zm3', '.zmv'  )
        if fol_name in os.listdir():
            for j in range(len(f_list)):
                file_name = f_list[j]
                print(file_name)
                if os.path.isdir(file_name):
                    pass
                else:
                    if file_name.endswith(v_format):
                        v_copy_path=copy_path + "\\"+ i+"\\video"
                        # if path exist copy the file
                        if v_copy_path in os.listdir:
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_copy_done")
                            if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                    # if path does not exist make the path then copy
                        else:
                            os.makedirs(i+"\\video")
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_fol_md_cpy_dn")
                            print("v_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                    # move the file_name in fol_name\\video
                    else:
                        i_copy_path=copy_path + "\\"+ i+"\\img"
                        #  if path exist then copy
                        if i_copy_path in os.listdir:
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                        #  if path do not exist then make path and them copy
                        else:
                            os.mkdir(i+"\\img")
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_fol_md_cpy_dn")
                            print("i_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                        # move the file_name in fol_name\\img
        else:
            print(i)
            os.makedirs(i,exist_ok=True)
            print("nw_fol", i, " md")
            for j in range(len(f_list)):
                print("in")
                file_name = f_list[j]
                print(file_name)
                if os.path.isdir(file_name):
                    pass
                else:    
                    if file_name.endswith(v_format):
                        v_copy_path=copy_path + "\\"+i+"\\video"
                        # if path exist copy the file
                        dir_list=os.listdir()
                        if v_copy_path in dir_list:
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_copy_done")
                            if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                    # if path does not exist make the path then copy
                        else:
                            os.makedirs(i+"\\video",exist_ok=True)
                            shutil.copy(file_name,v_copy_path)
                            print("v_fol_md_cpy_dn")
                            print("v_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                        # move the file_name in fol_name\\video
                    else:
                        i_copy_path=copy_path + "\\"+i+"\\img"
                        #  if path exist then copy
                        if i_copy_path in os.listdir():
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                        #  if path do not exist then make path and them copy
                        else:
                            os.makedirs(i+"\\img",exist_ok=True)
                            shutil.copy(file_name,i_copy_path)
                            print("i_fol_md_cpy_dn")
                            print("i_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                            # move the file_name in fol_name\\img



# Fuction to call above both fuctions
def file_sort(scr_path,copy_path):
    data = []
    dir_list = os.listdir(scr_path)
    for i in range(len(dir_list)):
        if os.path.isfile(scr_path+"\\"+dir_list[i]):
            pass
        if os.path.isdir(scr_path+"\\"+dir_list[i]):
            new_path = scr_path+"\\"+dir_list[i]
            data.append(mapping(new_path))
    data.append(mapping(scr_path))
    print("mapping done")
    print(data)
    for i in range(len(data)):
        print(i)
        copy_file(data[i][0],copy_path=copy_path,name=data[i][1])

file_sort(scr_path="D:\\test",copy_path="D:\\copy path test")
# Out:
# ({'2023-01-28': ['D:\\test\\PXL_20210328_131901320.PORTRAIT.jpg',
#    'D:\\test\\PXL_20210328_131941073.PORTRAIT.jpg',
#    'D:\\test\\PXL_20210328_131959994.PORTRAIT.jpg',
#    'D:\\test\\PXL_20210328_132012224.PORTRAIT.jpg',
#    'D:\\test\\PXL_20210328_132035918.PORTRAIT.jpg',
#    'D:\\test\\PXL_20210328_132046110.PORTRAIT.jpg',
#    'D:\\test\\PXL_20210328_132115255.PORTRAIT.jpg',
#    'D:\\test\\PXL_20210922_211207980.jpg',
#    'D:\\test\\PXL_20210922_211218978.jpg',
#    'D:\\test\\PXL_20210922_211221656.jpg',
#    'D:\\test\\PXL_20210922_211246377.jpg',
#    'D:\\test\\PXL_20210922_211250744.jpg',
#    'D:\\test\\PXL_20210922_211326511.jpg',
#    'D:\\test\\PXL_20210922_211329209.jpg',
#    'D:\\test\\PXL_20210922_211357945.jpg',
#    'D:\\test\\PXL_20210922_211359809.jpg',
#    'D:\\test\\PXL_20210922_211420846.jpg',
#    'D:\\test\\PXL_20210922_211422659.jpg',
#    'D:\\test\\PXL_20210922_211433143.jpg',
#    'D:\\test\\IMG_20221009_234547876_HDR.jpg',
#    'D:\\test\\IMG_20221015_100030068.jpg',
#    'D:\\test\\IMG_20221015_100043788.jpg',
#    'D:\\test\\IMG_20221015_100101990_HDR.jpg',
#    'D:\\test\\IMG_20221015_100111024_HDR.jpg',
#    'D:\\test\\IMG_20221015_100207140_HDR.jpg',
#    'D:\\test\\IMG_20221015_100236361_PORTRAIT.jpg',
#    'D:\\test\\IMG_20221015_100431155_PORTRAIT.jpg',
#    'D:\\test\\IMG_20221015_100541110_PORTRAIT.jpg',
#    'D:\\test\\IMG_20221015_100636289_PORTRAIT.jpg',
#    'D:\\test\\IMG_20221015_100638834_PORTRAIT.jpg',
#    'D:\\test\\IMG_20221015_100652874_PORTRAIT.jpg',
#    'D:\\test\\IMG_20221015_100652874_PORTRAIT~2.jpg',
#    'D:\\test\\PXL_20221015_100325400.PORTRAIT.jpg',
#    'D:\\test\\PXL_20221015_100400600.PORTRAIT.jpg',
#    'D:\\test\\IMG_20221026_025821230_HDR.jpg',
#    'D:\\test\\IMG_20221107_183244782.jpg',
#    'D:\\test\\IMG_20221107_183246679.jpg',
#    'D:\\test\\IMG_20221107_183249282.jpg',
#    'D:\\test\\IMG_20221107_183527416.jpg',
#    'D:\\test\\PXL_20221108_124258781.jpg',
#    'D:\\test\\PXL_20221128_185925940.jpg',
#    'D:\\test\\PXL_20221128_185940691.jpg',
#    'D:\\test\\PXL_20221201_170334935.jpg',
#    'D:\\test\\PXL_20221201_170406851.jpg',
#    'D:\\test\\PXL_20221202_120623966.PHOTOSPHERE.jpg',
#    'D:\\test\\PXL_20221213_072845728.PORTRAIT.jpg',
#    'D:\\test\\PXL_20221213_072845728.PORTRAIT~2.jpg',
#    'D:\\test\\PXL_20221214_193845303.jpg',
#    'D:\\test\\PXL_20221215_112248323.jpg',
#    'D:\\test\\PXL_20221215_112307209.jpg',
#    'D:\\test\\PXL_20221215_112445868.jpg',
#    'D:\\test\\PXL_20221215_112445868~2.jpg',
#    'D:\\test\\PXL_20221215_112702452.jpg',
#    'D:\\test\\PXL_20221215_112724685.jpg',
#    'D:\\test\\PXL_20221215_115931734.PHOTOSPHERE.jpg',
#    'D:\\test\\PXL_20221215_120258346.PHOTOSPHERE.jpg',
#    'D:\\test\\lv_0_20221216112535.mp4',
#    'D:\\test\\lv_0_20221216114125.mp4',
#    'D:\\test\\lv_0_20221216122315.mp4',
#    'D:\\test\\lv_0_20221218124713.mp4',
#    'D:\\test\\lv_0_20221218134026.mp4',
#    'D:\\test\\IMG_20221219_112213072_HDR.jpg',
#    'D:\\test\\IMG_20221220_091149194_HDR.jpg',
#    'D:\\test\\IMG_20221220_152116612.jpg',
#    'D:\\test\\IMG_20221220_213513541.jpg',
#    'D:\\test\\lv_0_20221220123925.mp4',
#    'D:\\test\\lv_0_20221220124235.mp4',
#    'D:\\test\\lv_0_20221220152916.mp4',
#    'D:\\test\\IMG_20221221_081222560_HDR.jpg',
#    'D:\\test\\IMG_20221221_082413621_HDR.jpg',
#    'D:\\test\\IMG_20221221_083616416_HDR.jpg',
#    'D:\\test\\IMG_20221221_083616416_HDR~2.jpg',
#    'D:\\test\\IMG_20221221_083645319_HDR.jpg',
#    'D:\\test\\IMG_20221221_083645319_HDR~2.jpg',
#    'D:\\test\\IMG_20221221_120646715.jpg',
#    'D:\\test\\IMG_20221222_161419107.jpg',
#    'D:\\test\\IMG_20221222_172730467.jpg',
#    'D:\\test\\IMG_20221223_160150697.jpg',
#    'D:\\test\\lv_0_20221223174147.mp4',
#    'D:\\test\\IMG_20221224_160819770_BURST001.jpg',
#    'D:\\test\\IMG_20221224_160821700_BURST001.jpg',
#    'D:\\test\\IMG_20221224_215219441~2.jpg',
#    'D:\\test\\IMG_20221224_215529247.jpg',
#    'D:\\test\\IMG_20221225_155031825.dng',
#    'D:\\test\\IMG_20221225_155031825.jpg',
#    'D:\\test\\IMG_20221225_155121525.dng',
#    'D:\\test\\IMG_20221225_155121525.jpg',
#    'D:\\test\\IMG_20221225_155207059.dng',
#    'D:\\test\\IMG_20221225_155207059.jpg',
#    'D:\\test\\IMG_20221225_155758514.dng',
#    'D:\\test\\IMG_20221225_155758514.jpg',
#    'D:\\test\\IMG_20221225_160152124.jpg',
#    'D:\\test\\IMG_20221225_160152124~2.jpg',
#    'D:\\test\\IMG_20221225_162906046_HDR.jpg',
#    'D:\\test\\IMG_20221225_164221271.jpg',
#    'D:\\test\\IMG_20221225_164251971_HDR.jpg',
#    'D:\\test\\IMG_20221226_081540727_BURST000_COVER_COMP.jpg',
#    'D:\\test\\IMG_20221226_081540727_BURST001.jpg',
#    'D:\\test\\IMG_20221226_081911355_HDR.jpg',
#    'D:\\test\\IMG_20221226_085723039_HDR.jpg',
#    'D:\\test\\IMG_20221226_085757505_HDR.jpg',
#    'D:\\test\\IMG_20221226_090120519_HDR.jpg',
#    'D:\\test\\lv_0_20221228001003.mp4',
#    'D:\\test\\lv_0_20221229101751_exported_0.jpg',
#    'D:\\test\\lv_0_20221229103102.mp4',
#    'D:\\test\\lv_0_20221229160911.mp4',
#    'D:\\test\\lv_0_20221229183826.mp4',
#    'D:\\test\\lv_0_20221230082031.mp4',
#    'D:\\test\\lv_0_20230101204031.mp4',
#    'D:\\test\\PXL_20221108_124258781~2.jpg',
#    'D:\\test\\lv_0_20230102210859.mp4',
#    'D:\\test\\lv_0_20230103105528.mp4',
#    'D:\\test\\lv_0_20230103205436.mp4',
#    'D:\\test\\lv_0_20230106124841.mp4',
#    'D:\\test\\lv_0_20230106125329.mp4',
#    'D:\\test\\lv_0_20230106223727.mp4',
#    'D:\\test\\lv_0_20230106224501.mp4',
#    'D:\\test\\lv_0_20230108194824.mp4',
#    'D:\\test\\IMG_20230120_212432679_MP.jpg',
#    'D:\\test\\IMG_20230120_212436693_MP.jpg',
#    'D:\\test\\IMG_20230120_212437974_MP.jpg',
#    'D:\\test\\IMG_20230120_212438931_MP.jpg']},
#  {'2023-01-28': ['PXL_20210328_131901320.PORTRAIT.jpg',
#    'PXL_20210328_131941073.PORTRAIT.jpg',
#    'PXL_20210328_131959994.PORTRAIT.jpg',
#    'PXL_20210328_132012224.PORTRAIT.jpg',
#    'PXL_20210328_132035918.PORTRAIT.jpg',
#    'PXL_20210328_132046110.PORTRAIT.jpg',
#    'PXL_20210328_132115255.PORTRAIT.jpg',
#    'PXL_20210922_211207980.jpg',
#    'PXL_20210922_211218978.jpg',
#    'PXL_20210922_211221656.jpg',
#    'PXL_20210922_211246377.jpg',
#    'PXL_20210922_211250744.jpg',
#    'PXL_20210922_211326511.jpg',
#    'PXL_20210922_211329209.jpg',
#    'PXL_20210922_211357945.jpg',
#    'PXL_20210922_211359809.jpg',
#    'PXL_20210922_211420846.jpg',
#    'PXL_20210922_211422659.jpg',
#    'PXL_20210922_211433143.jpg',
#    'IMG_20221009_234547876_HDR.jpg',
#    'IMG_20221015_100030068.jpg',
#    'IMG_20221015_100043788.jpg',
#    'IMG_20221015_100101990_HDR.jpg',
#    'IMG_20221015_100111024_HDR.jpg',
#    'IMG_20221015_100207140_HDR.jpg',
#    'IMG_20221015_100236361_PORTRAIT.jpg',
#    'IMG_20221015_100431155_PORTRAIT.jpg',
#    'IMG_20221015_100541110_PORTRAIT.jpg',
#    'IMG_20221015_100636289_PORTRAIT.jpg',
#    'IMG_20221015_100638834_PORTRAIT.jpg',
#    'IMG_20221015_100652874_PORTRAIT.jpg',
#    'IMG_20221015_100652874_PORTRAIT~2.jpg',
#    'PXL_20221015_100325400.PORTRAIT.jpg',
#    'PXL_20221015_100400600.PORTRAIT.jpg',
#    'IMG_20221026_025821230_HDR.jpg',
#    'IMG_20221107_183244782.jpg',
#    'IMG_20221107_183246679.jpg',
#    'IMG_20221107_183249282.jpg',
#    'IMG_20221107_183527416.jpg',
#    'PXL_20221108_124258781.jpg',
#    'PXL_20221128_185925940.jpg',
#    'PXL_20221128_185940691.jpg',
#    'PXL_20221201_170334935.jpg',
#    'PXL_20221201_170406851.jpg',
#    'PXL_20221202_120623966.PHOTOSPHERE.jpg',
#    'PXL_20221213_072845728.PORTRAIT.jpg',
#    'PXL_20221213_072845728.PORTRAIT~2.jpg',
#    'PXL_20221214_193845303.jpg',
#    'PXL_20221215_112248323.jpg',
#    'PXL_20221215_112307209.jpg',
#    'PXL_20221215_112445868.jpg',
#    'PXL_20221215_112445868~2.jpg',
#    'PXL_20221215_112702452.jpg',
#    'PXL_20221215_112724685.jpg',
#    'PXL_20221215_115931734.PHOTOSPHERE.jpg',
#    'PXL_20221215_120258346.PHOTOSPHERE.jpg',
#    'lv_0_20221216112535.mp4',
#    'lv_0_20221216114125.mp4',
#    'lv_0_20221216122315.mp4',
#    'lv_0_20221218124713.mp4',
#    'lv_0_20221218134026.mp4',
#    'IMG_20221219_112213072_HDR.jpg',
#    'IMG_20221220_091149194_HDR.jpg',
#    'IMG_20221220_152116612.jpg',
#    'IMG_20221220_213513541.jpg',
#    'lv_0_20221220123925.mp4',
#    'lv_0_20221220124235.mp4',
#    'lv_0_20221220152916.mp4',
#    'IMG_20221221_081222560_HDR.jpg',
#    'IMG_20221221_082413621_HDR.jpg',
#    'IMG_20221221_083616416_HDR.jpg',
#    'IMG_20221221_083616416_HDR~2.jpg',
#    'IMG_20221221_083645319_HDR.jpg',
#    'IMG_20221221_083645319_HDR~2.jpg',
#    'IMG_20221221_120646715.jpg',
#    'IMG_20221222_161419107.jpg',
#    'IMG_20221222_172730467.jpg',
#    'IMG_20221223_160150697.jpg',
#    'lv_0_20221223174147.mp4',
#    'IMG_20221224_160819770_BURST001.jpg',
#    'IMG_20221224_160821700_BURST001.jpg',
#    'IMG_20221224_215219441~2.jpg',
#    'IMG_20221224_215529247.jpg',
#    'IMG_20221225_155031825.dng',
#    'IMG_20221225_155031825.jpg',
#    'IMG_20221225_155121525.dng',
#    'IMG_20221225_155121525.jpg',
#    'IMG_20221225_155207059.dng',
#    'IMG_20221225_155207059.jpg',
#    'IMG_20221225_155758514.dng',
#    'IMG_20221225_155758514.jpg',
#    'IMG_20221225_160152124.jpg',
#    'IMG_20221225_160152124~2.jpg',
#    'IMG_20221225_162906046_HDR.jpg',
#    'IMG_20221225_164221271.jpg',
#    'IMG_20221225_164251971_HDR.jpg',
#    'IMG_20221226_081540727_BURST000_COVER_COMP.jpg',
#    'IMG_20221226_081540727_BURST001.jpg',
#    'IMG_20221226_081911355_HDR.jpg',
#    'IMG_20221226_085723039_HDR.jpg',
#    'IMG_20221226_085757505_HDR.jpg',
#    'IMG_20221226_090120519_HDR.jpg',
#    'lv_0_20221228001003.mp4',
#    'lv_0_20221229101751_exported_0.jpg',
#    'lv_0_20221229103102.mp4',
#    'lv_0_20221229160911.mp4',
#    'lv_0_20221229183826.mp4',
#    'lv_0_20221230082031.mp4',
#    'lv_0_20230101204031.mp4',
#    'PXL_20221108_124258781~2.jpg',
#    'lv_0_20230102210859.mp4',
#    'lv_0_20230103105528.mp4',
#    'lv_0_20230103205436.mp4',
#    'lv_0_20230106124841.mp4',
#    'lv_0_20230106125329.mp4',
#    'lv_0_20230106223727.mp4',
#    'lv_0_20230106224501.mp4',
#    'lv_0_20230108194824.mp4',
#    'IMG_20230120_212432679_MP.jpg',
#    'IMG_20230120_212436693_MP.jpg',
#    'IMG_20230120_212437974_MP.jpg',
#    'IMG_20230120_212438931_MP.jpg']})

# %%
#  done with out parser

import argparse
def file_sort(path,copy_path):
    import os
    import time
    import shutil
    import logging

    formatter = logging.Formatter('%(asctime)s %(name)s %(levelname)s %(message)s')
    def setup_logger(name, log_file, level=logging.INFO):
        """To set up as many loggers as you want"""
        handler = logging.FileHandler(log_file)
        handler.setFormatter(formatter)
        logger = logging.getLogger(name)
        logger.setLevel(level)
        if logger.handlers:
            logger.handlers = []
        logger.addHandler(handler)

        return logger

    dirs ={}
    def find_dirs(path):
        dirs[path] = []
        for i in os.listdir(path):
            if os.path.isdir(path+"\\"+i):
                dirs[path].append(path+"\\"+i)
            else:
                pass
        if path in dirs:
            for i in dirs[path]:
                find_dirs(i)
        else:
            pass
        
        return list(dirs.keys())
    all_dirs=find_dirs(path)
    log_file = open("log.log", "a")
    find_dirs_log = setup_logger("find_dirs",log_file= "log.log", level = logging.INFO)
    find_dirs_log.log(level=logging.INFO,msg="all Dirs Found")
    log_file.close()

    # Fuction to make dir with date and path 
    def mapping(path):
        file_location = []
        for j in all_dirs:
            a = os.listdir(j)
            for i in range(len(a)):
                if os.path.isdir(a[i]):
                    pass
                else:               
                    file_path = j + "\\" + a[i]
                    if os.path.isdir(file_path):
                        pass
                    else:
                        file_location.append(file_path)
        return(file_location)
    map = mapping(path)
    log_file = open("log.log", "a")
    mapping_log = setup_logger("mapping",log_file= "log.log", level = logging.INFO)
    mapping_log.log(level=logging.INFO,msg="all Files Found")
    log_file.close()

    # use the dir list to find dates of file in them
    def chr_date(path):
        cr_date = {}
        data = map
        for i in data:
            if os.path.isfile(i):
                cr_T=(os.path.getmtime(i))
                cr_time = time.ctime(cr_T)
                cr_t_obj = time.strptime(cr_time)
                date = time.strftime("%Y-%m-%d", cr_t_obj)
                file_path = i
                if date in cr_date.keys():
                    cr_date[date].append(file_path)
                else:
                    cr_date[date]=[file_path]
        return(cr_date)
    dates = chr_date(path)
    log_file = open("log.log", "a")
    chr_date_log = setup_logger("Chr_date",log_file= "log.log", level = logging.INFO)
    chr_date_log.log(level=logging.INFO,msg="all files Found with path and cr_dates")
    log_file.close()

    #  sorts the files by the data given by chr_date() fuction
    def copy_file(scr_path,copy_path):
        os.chdir(copy_path)
        cr_date = dates
        fol_name = list(cr_date.keys())
        for i in cr_date.keys():
            f_list = cr_date[i]
            # print(f_list)
            current_directory = os.getcwd()
            v_format=(
    '.264', '.3g2', '.3gp', '.3gp2', '.3gpp', '.3gpp2', '.3mm', '.3p2', '.60d', '.787', '.89', '.aaf', '.aec', '.aep', '.aepx',
    '.aet', '.aetx', '.ajp', '.ale', '.am', '.amc', '.amv', '.amx', '.anim', '.aqt', '.arcut', '.arf', '.asf', '.asx', '.avb',
    '.avc', '.avd', '.avi', '.avp', '.avs', '.avs', '.avv', '.axm', '.bdm', '.bdmv', '.bdt2', '.bdt3', '.bik', '.bin', '.bix',
    '.bmk', '.bnp', '.box', '.bs4', '.bsf', '.bvr', '.byu', '.camproj', '.camrec', '.camv', '.ced', '.cel', '.cine', '.cip',
    '.clpi', '.cmmp', '.cmmtpl', '.cmproj', '.cmrec', '.cpi', '.cst', '.cvc', '.cx3', '.d2v', '.d3v', '.dat', '.dav', '.dce',
    '.dck', '.dcr', '.dcr', '.ddat', '.dif', '.dir', '.divx', '.dlx', '.dmb', '.dmsd', '.dmsd3d', '.dmsm', '.dmsm3d', '.dmss',
    '.dmx', '.dnc', '.dpa', '.dpg', '.dream', '.dsy', '.dv', '.dv-avi', '.dv4', '.dvdmedia', '.dvr', '.dvr-ms', '.dvx', '.dxr',
    '.dzm', '.dzp', '.dzt', '.edl', '.evo', '.eye', '.ezt', '.f4p', '.f4v', '.fbr', '.fbr', '.fbz', '.fcp', '.fcproject',
    '.ffd', '.flc', '.flh', '.fli', '.flv', '.flx', '.gfp', '.gl', '.gom', '.grasp', '.gts', '.gvi', '.gvp', '.h264', '.hdmov',
    '.hkm', '.ifo', '.imovieproj', '.imovieproject', '.ircp', '.irf', '.ism', '.ismc', '.ismv', '.iva', '.ivf', '.ivr', '.ivs',
    '.izz', '.izzy', '.jss', '.jts', '.jtv', '.k3g', '.kmv', '.ktn', '.lrec', '.lsf', '.lsx', '.m15', '.m1pg', '.m1v', '.m21',
    '.m21', '.m2a', '.m2p', '.m2t', '.m2ts', '.m2v', '.m4e', '.m4u', '.m4v', '.m75', '.mani', '.meta', '.mgv', '.mj2', '.mjp',
    '.mjpg', '.mk3d', '.mkv', '.mmv', '.mnv', '.mob', '.mod', '.modd', '.moff', '.moi', '.moov', '.mov', '.movie', '.mp21',
    '.mp21', '.mp2v', '.mp4', '.mp4v', '.mpe', '.mpeg', '.mpeg1', '.mpeg4', '.mpf', '.mpg', '.mpg2', '.mpgindex', '.mpl',
    '.mpl', '.mpls', '.mpsub', '.mpv', '.mpv2', '.mqv', '.msdvd', '.mse', '.msh', '.mswmm', '.mts', '.mtv', '.mvb', '.mvc',
    '.mvd', '.mve', '.mvex', '.mvp', '.mvp', '.mvy', '.mxf', '.mxv', '.mys', '.ncor', '.nsv', '.nut', '.nuv', '.nvc', '.ogm',
    '.ogv', '.ogx', '.osp', '.otrkey', '.pac', '.par', '.pds', '.pgi', '.photoshow', '.piv', '.pjs', '.playlist', '.plproj',
    '.pmf', '.pmv', '.pns', '.ppj', '.prel', '.pro', '.prproj', '.prtl', '.psb', '.psh', '.pssd', '.pva', '.pvr', '.pxv',
    '.qt', '.qtch', '.qtindex', '.qtl', '.qtm', '.qtz', '.r3d', '.rcd', '.rcproject', '.rdb', '.rec', '.rm', '.rmd', '.rmd',
    '.rmp', '.rms', '.rmv', '.rmvb', '.roq', '.rp', '.rsx', '.rts', '.rts', '.rum', '.rv', '.rvid', '.rvl', '.sbk', '.sbt',
    '.scc', '.scm', '.scm', '.scn', '.screenflow', '.sec', '.sedprj', '.seq', '.sfd', '.sfvidcap', '.siv', '.smi', '.smi',
    '.smil', '.smk', '.sml', '.smv', '.spl', '.sqz', '.srt', '.ssf', '.ssm', '.stl', '.str', '.stx', '.svi', '.swf', '.swi',
    '.swt', '.tda3mt', '.tdx', '.thp', '.tivo', '.tix', '.tod', '.tp', '.tp0', '.tpd', '.tpr', '.trp', '.ts', '.tsp', '.ttxt',
    '.tvs', '.usf', '.usm', '.vc1', '.vcpf', '.vcr', '.vcv', '.vdo', '.vdr', '.vdx', '.veg','.vem', '.vep', '.vf', '.vft',
    '.vfw', '.vfz', '.vgz', '.vid', '.video', '.viewlet', '.viv', '.vivo', '.vlab', '.vob', '.vp3', '.vp6', '.vp7', '.vpj',
    '.vro', '.vs4', '.vse', '.vsp', '.w32', '.wcp', '.webm', '.wlmp', '.wm', '.wmd', '.wmmp', '.wmv', '.wmx', '.wot', '.wp3',
    '.wpl', '.wtv', '.wve', '.wvx', '.xej', '.xel', '.xesc', '.xfl', '.xlmv', '.xmv', '.xvid', '.y4m', '.yog', '.yuv', '.zeg',
    '.zm1', '.zm2', '.zm3', '.zmv'  )
            if fol_name in os.listdir():
                for j in range(len(f_list)):
                    file_name = f_list[j]
                    if os.path.isdir(file_name):
                        pass
                    else:
                        if file_name.endswith(v_format):
                            v_copy_path=copy_path + "\\"+ i+"\\video"
                            # if path exist copy the file
                            if v_copy_path in os.listdir:
                                shutil.copyfile(file_name,v_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="v_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                        # if path does not exist make the path then copy
                            else:
                                os.makedirs(i+"\\video")
                                shutil.copyfile(file_name,v_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="v_fol_made_&_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                        # move the file_name in fol_name\\video
                        else:
                            i_copy_path=copy_path + "\\"+ i+"\\img"
                            #  if path exist then copy
                            if i_copy_path in os.listdir:
                                shutil.copyfile(file_name,i_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="i_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                            #  if path do not exist then make path and them copy
                            else:
                                os.mkdir(i+"\\img")
                                shutil.copyfile(file_name,i_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="i_fol_made_&_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                            # move the file_name in fol_name\\img
            else:
                os.makedirs(i,exist_ok=True)
                log_file = open("log.log", "a")
                copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                copy_file_log.log(level=logging.INFO,msg="nw_fol"+i+" md")
                log_file.close()
                for j in range(len(f_list)):
                    file_name = f_list[j]
                    if os.path.isdir(file_name):
                        pass
                    else:    
                        if file_name.endswith(v_format):
                            v_copy_path=copy_path + "\\"+i+"\\video"
                            # if path exist copy the file
                            dir_list=os.listdir()
                            if v_copy_path in dir_list:
                                shutil.copyfile(file_name,v_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="v_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                        # if path does not exist make the path then copy
                            else:
                                os.makedirs(i+"\\video",exist_ok=True)
                                shutil.copy(file_name,v_copy_path)
                                if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="V_fol_made_&_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                            # move the file_name in fol_name\\video
                        else:
                            i_copy_path=copy_path + "\\"+i+"\\img"
                            #  if path exist then copy
                            if i_copy_path in os.listdir():
                                shutil.copyfile(file_name,i_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="i_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                            #  if path do not exist then make path and them copy
                            else:
                                os.makedirs(i+"\\img",exist_ok=True)
                                shutil.copy(file_name,i_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="i_fol_made_&_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                                # move the file_name in fol_name\\img
    copy_file(scr_path= path,copy_path=copy_path)
    log_file = open("log.log", "a")
    file_sort_log = setup_logger("File_sort",log_file= "log.log", level = logging.INFO)
    file_sort_log.log(level=logging.INFO,msg="all files from scr_path are moved and are sorted in copy_path")
    log_file.close()

# %%
# Working on parsing

import argparse
def file_sort(path,copy_path):
    import os
    import time
    import shutil
    import logging

    formatter = logging.Formatter('%(asctime)s %(name)s %(levelname)s %(message)s')
    def setup_logger(name, log_file, level=logging.INFO):
        """To set up as many loggers as you want"""
        handler = logging.FileHandler(log_file)
        handler.setFormatter(formatter)
        logger = logging.getLogger(name)
        logger.setLevel(level)
        if logger.handlers:
            logger.handlers = []
        logger.addHandler(handler)

        return logger

    dirs ={}
    def find_dirs(path):
        dirs[path] = []
        for i in os.listdir(path):
            if os.path.isdir(path+"\\"+i):
                dirs[path].append(path+"\\"+i)
            else:
                pass
        if path in dirs:
            for i in dirs[path]:
                find_dirs(i)
        else:
            pass
        
        return list(dirs.keys())
    all_dirs=find_dirs(path)
    log_file = open("log.log", "a")
    find_dirs_log = setup_logger("find_dirs",log_file= "log.log", level = logging.INFO)
    find_dirs_log.log(level=logging.INFO,msg="all Dirs Found")
    log_file.close()

    # Fuction to make dir with date and path 
    def mapping(path):
        file_location = []
        for j in all_dirs:
            a = os.listdir(j)
            for i in range(len(a)):
                if os.path.isdir(a[i]):
                    pass
                else:               
                    file_path = j + "\\" + a[i]
                    if os.path.isdir(file_path):
                        pass
                    else:
                        file_location.append(file_path)
        return(file_location)
    map = mapping(path)
    log_file = open("log.log", "a")
    mapping_log = setup_logger("mapping",log_file= "log.log", level = logging.INFO)
    mapping_log.log(level=logging.INFO,msg="all Files Found")
    log_file.close()

    # use the dir list to find dates of file in them
    def chr_date(path):
        cr_date = {}
        data = map
        for i in data:
            if os.path.isfile(i):
                cr_T=(os.path.getmtime(i))
                cr_time = time.ctime(cr_T)
                cr_t_obj = time.strptime(cr_time)
                date = time.strftime("%Y-%m-%d", cr_t_obj)
                file_path = i
                if date in cr_date.keys():
                    cr_date[date].append(file_path)
                else:
                    cr_date[date]=[file_path]
        return(cr_date)
    dates = chr_date(path)
    log_file = open("log.log", "a")
    chr_date_log = setup_logger("Chr_date",log_file= "log.log", level = logging.INFO)
    chr_date_log.log(level=logging.INFO,msg="all files Found with path and cr_dates")
    log_file.close()

    #  sorts the files by the data given by chr_date() fuction
    def copy_file(scr_path,copy_path):
        os.chdir(copy_path)
        cr_date = dates
        fol_name = list(cr_date.keys())
        for i in cr_date.keys():
            f_list = cr_date[i]
            # print(f_list)
            current_directory = os.getcwd()
            v_format=(
    '.264', '.3g2', '.3gp', '.3gp2', '.3gpp', '.3gpp2', '.3mm', '.3p2', '.60d', '.787', '.89', '.aaf', '.aec', '.aep', '.aepx',
    '.aet', '.aetx', '.ajp', '.ale', '.am', '.amc', '.amv', '.amx', '.anim', '.aqt', '.arcut', '.arf', '.asf', '.asx', '.avb',
    '.avc', '.avd', '.avi', '.avp', '.avs', '.avs', '.avv', '.axm', '.bdm', '.bdmv', '.bdt2', '.bdt3', '.bik', '.bin', '.bix',
    '.bmk', '.bnp', '.box', '.bs4', '.bsf', '.bvr', '.byu', '.camproj', '.camrec', '.camv', '.ced', '.cel', '.cine', '.cip',
    '.clpi', '.cmmp', '.cmmtpl', '.cmproj', '.cmrec', '.cpi', '.cst', '.cvc', '.cx3', '.d2v', '.d3v', '.dat', '.dav', '.dce',
    '.dck', '.dcr', '.dcr', '.ddat', '.dif', '.dir', '.divx', '.dlx', '.dmb', '.dmsd', '.dmsd3d', '.dmsm', '.dmsm3d', '.dmss',
    '.dmx', '.dnc', '.dpa', '.dpg', '.dream', '.dsy', '.dv', '.dv-avi', '.dv4', '.dvdmedia', '.dvr', '.dvr-ms', '.dvx', '.dxr',
    '.dzm', '.dzp', '.dzt', '.edl', '.evo', '.eye', '.ezt', '.f4p', '.f4v', '.fbr', '.fbr', '.fbz', '.fcp', '.fcproject',
    '.ffd', '.flc', '.flh', '.fli', '.flv', '.flx', '.gfp', '.gl', '.gom', '.grasp', '.gts', '.gvi', '.gvp', '.h264', '.hdmov',
    '.hkm', '.ifo', '.imovieproj', '.imovieproject', '.ircp', '.irf', '.ism', '.ismc', '.ismv', '.iva', '.ivf', '.ivr', '.ivs',
    '.izz', '.izzy', '.jss', '.jts', '.jtv', '.k3g', '.kmv', '.ktn', '.lrec', '.lsf', '.lsx', '.m15', '.m1pg', '.m1v', '.m21',
    '.m21', '.m2a', '.m2p', '.m2t', '.m2ts', '.m2v', '.m4e', '.m4u', '.m4v', '.m75', '.mani', '.meta', '.mgv', '.mj2', '.mjp',
    '.mjpg', '.mk3d', '.mkv', '.mmv', '.mnv', '.mob', '.mod', '.modd', '.moff', '.moi', '.moov', '.mov', '.movie', '.mp21',
    '.mp21', '.mp2v', '.mp4', '.mp4v', '.mpe', '.mpeg', '.mpeg1', '.mpeg4', '.mpf', '.mpg', '.mpg2', '.mpgindex', '.mpl',
    '.mpl', '.mpls', '.mpsub', '.mpv', '.mpv2', '.mqv', '.msdvd', '.mse', '.msh', '.mswmm', '.mts', '.mtv', '.mvb', '.mvc',
    '.mvd', '.mve', '.mvex', '.mvp', '.mvp', '.mvy', '.mxf', '.mxv', '.mys', '.ncor', '.nsv', '.nut', '.nuv', '.nvc', '.ogm',
    '.ogv', '.ogx', '.osp', '.otrkey', '.pac', '.par', '.pds', '.pgi', '.photoshow', '.piv', '.pjs', '.playlist', '.plproj',
    '.pmf', '.pmv', '.pns', '.ppj', '.prel', '.pro', '.prproj', '.prtl', '.psb', '.psh', '.pssd', '.pva', '.pvr', '.pxv',
    '.qt', '.qtch', '.qtindex', '.qtl', '.qtm', '.qtz', '.r3d', '.rcd', '.rcproject', '.rdb', '.rec', '.rm', '.rmd', '.rmd',
    '.rmp', '.rms', '.rmv', '.rmvb', '.roq', '.rp', '.rsx', '.rts', '.rts', '.rum', '.rv', '.rvid', '.rvl', '.sbk', '.sbt',
    '.scc', '.scm', '.scm', '.scn', '.screenflow', '.sec', '.sedprj', '.seq', '.sfd', '.sfvidcap', '.siv', '.smi', '.smi',
    '.smil', '.smk', '.sml', '.smv', '.spl', '.sqz', '.srt', '.ssf', '.ssm', '.stl', '.str', '.stx', '.svi', '.swf', '.swi',
    '.swt', '.tda3mt', '.tdx', '.thp', '.tivo', '.tix', '.tod', '.tp', '.tp0', '.tpd', '.tpr', '.trp', '.ts', '.tsp', '.ttxt',
    '.tvs', '.usf', '.usm', '.vc1', '.vcpf', '.vcr', '.vcv', '.vdo', '.vdr', '.vdx', '.veg','.vem', '.vep', '.vf', '.vft',
    '.vfw', '.vfz', '.vgz', '.vid', '.video', '.viewlet', '.viv', '.vivo', '.vlab', '.vob', '.vp3', '.vp6', '.vp7', '.vpj',
    '.vro', '.vs4', '.vse', '.vsp', '.w32', '.wcp', '.webm', '.wlmp', '.wm', '.wmd', '.wmmp', '.wmv', '.wmx', '.wot', '.wp3',
    '.wpl', '.wtv', '.wve', '.wvx', '.xej', '.xel', '.xesc', '.xfl', '.xlmv', '.xmv', '.xvid', '.y4m', '.yog', '.yuv', '.zeg',
    '.zm1', '.zm2', '.zm3', '.zmv'  )
            if fol_name in os.listdir():
                for j in range(len(f_list)):
                    file_name = f_list[j]
                    if os.path.isdir(file_name):
                        pass
                    else:
                        if file_name.endswith(v_format):
                            v_copy_path=copy_path + "\\"+ i+"\\video"
                            # if path exist copy the file
                            if v_copy_path in os.listdir:
                                shutil.copyfile(file_name,v_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="v_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                        # if path does not exist make the path then copy
                            else:
                                os.makedirs(i+"\\video")
                                shutil.copyfile(file_name,v_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="v_fol_made_&_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                        # move the file_name in fol_name\\video
                        else:
                            i_copy_path=copy_path + "\\"+ i+"\\img"
                            #  if path exist then copy
                            if i_copy_path in os.listdir:
                                shutil.copyfile(file_name,i_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="i_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                            #  if path do not exist then make path and them copy
                            else:
                                os.mkdir(i+"\\img")
                                shutil.copyfile(file_name,i_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="i_fol_made_&_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                            # move the file_name in fol_name\\img
            else:
                os.makedirs(i,exist_ok=True)
                log_file = open("log.log", "a")
                copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                copy_file_log.log(level=logging.INFO,msg="nw_fol"+i+" md")
                log_file.close()
                for j in range(len(f_list)):
                    file_name = f_list[j]
                    if os.path.isdir(file_name):
                        pass
                    else:    
                        if file_name.endswith(v_format):
                            v_copy_path=copy_path + "\\"+i+"\\video"
                            # if path exist copy the file
                            dir_list=os.listdir()
                            if v_copy_path in dir_list:
                                shutil.copyfile(file_name,v_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="v_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                        # if path does not exist make the path then copy
                            else:
                                os.makedirs(i+"\\video",exist_ok=True)
                                shutil.copy(file_name,v_copy_path)
                                if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="V_fol_made_&_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                            # move the file_name in fol_name\\video
                        else:
                            i_copy_path=copy_path + "\\"+i+"\\img"
                            #  if path exist then copy
                            if i_copy_path in os.listdir():
                                shutil.copyfile(file_name,i_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="i_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                            #  if path do not exist then make path and them copy
                            else:
                                os.makedirs(i+"\\img",exist_ok=True)
                                shutil.copy(file_name,i_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="i_fol_made_&_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                                # move the file_name in fol_name\\img
    copy_file(scr_path= path,copy_path=copy_path)
    log_file = open("log.log", "a")
    file_sort_log = setup_logger("File_sort",log_file= "log.log", level = logging.INFO)
    file_sort_log.log(level=logging.INFO,msg="all files from scr_path are moved and are sorted in copy_path")
    log_file.close()
pars = argparse.ArgumentParser()
pars.add_argument("-p" , "--path" , action='append', help="provide the absolute path of the source folder and copy folder in a list as [ SOURCE PATH , COPY PATH]")
args = pars.parse_args()
print(args)
scrpath = args.path[0]
copypath = args.path[1]

file_sort(path= str(scrpath),copy_path=str(copypath))

# command to run the program in cmd
# pushd <absuloute path of this file> & python file_sort.py -p "D:\test" -p "D:\copy path test"  (geralized)
# pushd D:\python scripts\.pyfiles & python file_sort.py -p "D:\test" -p "D:\copy path test" (personal)
# Out:
# usage: ipykernel_launcher.py [-h] [-p PATH]
# ipykernel_launcher.py: error: unrecognized arguments: --ip=127.0.0.1 --stdin=9003 --control=9001 --hb=9000 --Session.signature_scheme="hmac-sha256" --Session.key=b"701d9d90-1d3e-4100-84eb-3152c1e4c8f8" --shell=9002 --transport="tcp" --iopub=9004 --f=c:\Users\q\AppData\Roaming\jupyter\runtime\kernel-v2-2196zo45ohiDnWv9.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
