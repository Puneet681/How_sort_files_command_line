# %%
import os
import time
import pandas as pd
def cr_date(path):
    os.chdir(path)
    a = os.listdir()
    l=[]
    for i in range(len(a)-1):
        cr_T=(os.path.getctime(a[i]))
        cr_time = time.ctime(cr_T)
        cr_t_obj = time.strptime(cr_time)
        cr_date = time.strftime("%Y-%m-%d", cr_t_obj)
        l.append({cr_date:a[i]})
    return(l)

# %%
(cr_date("D:\\python scripts\\testing-codes"))

# %%
import os
import time
def cr_date(path):
    os.chdir(path)
    a = os.listdir()
    cr_date={}
    for i in range(len(a)-1):
        cr_T=(os.path.getctime(a[i]))
        cr_time = time.ctime(cr_T)
        cr_t_obj = time.strptime(cr_time)
        date = time.strftime("%Y-%m-%d", cr_t_obj)
        if date in cr_date.keys():
            cr_date[date].append(a[i])
        else:
            cr_date[date]=[a[i]]
    return(cr_date)

# %%
for i in cr_date.keys():
    f_list = cr_date[i]
    print(f_list)
    a =str(cr_date.keys()).strip("dict_keys(["")
    fol_name = a.rstrip(""])")
    print(fol_name)
    if fol_name in os.listdir():
        for j in range(len(f_list)-1):
            file_name = f_list[j]
            print(file_name)
        if file_name.endswith(".mp4"):
            pass
            # move the file_name in fol_name\\video
        else:
            pass
            # move the file_name in fol_name//img
    else:
        os.mkdir(fol_name)
        for j in range(len(f_list)-1):
            if file_name.endswith(".mp4"):
                pass
                # move the file_name in fol_name//video
            else:
                pass
                # move the file_name in fol_name//img

# %%
import shutil
for i in cr_date.keys():
    f_list = cr_date[i]
    print(f_list)
    a =str(cr_date.keys()).strip("dict_keys(["")
    fol_name = a.rstrip(""])")
    print(fol_name)
    if fol_name in os.listdir():
        for j in range(len(f_list)-1):
            file_name = f_list[j]
            print(file_name)
        if file_name.endswith(".mp4"):
            pass
            v_copy_path=fol_name+"//video"
            # if path exist copy the file
            if v_copy_path in os.listdir:
                shutil.copyfile(file_name,v_copy_path)
            # if path does not exist make the path then copy
            else:
                os.mkdir(fol_name+"//video")
                shutil.copyfile(file_name,v_copy_path)
            # move the file_name in fol_name//video
        else:
            pass
            i_copy_path=fol_name+"//img"
            #  if path exist then copy
            if i_copy_path in os.listdir:
                shutil.copyfile(file_name,i_copy_path)
            #  if path do not exist then make path and them copy
            else:
                os.mkdir(fol_name+"//img")
                shutil.copyfile(file_name,i_copy_path)
            # move the file_name in fol_name//img
    else:
        os.mkdir(fol_name)
        for j in range(len(f_list)-1):
            file_name = f_list[j]
            print(file_name)
        if file_name.endswith(".mp4"):
            pass
            v_copy_path=fol_name+"//video"
            # if path exist copy the file
            if v_copy_path in os.listdir:
                shutil.copyfile(file_name,v_copy_path)
            # if path does not exist make the path then copy
            else:
                os.mkdir(fol_name+"//video")
                shutil.copyfile(file_name,v_copy_path)
            # move the file_name in fol_name//video
        else:
            pass
            i_copy_path=fol_name+"//img"
            #  if path exist then copy
            if i_copy_path in os.listdir:
                shutil.copyfile(file_name,i_copy_path)
            #  if path do not exist then make path and them copy
            else:
                os.mkdir(fol_name+"//img")
                shutil.copyfile(file_name,i_copy_path)
            # move the file_name in fol_name//img

# %%
import os
import time
import shutil

def cr_date(path):
    os.chdir(path)
    a = os.listdir()
    cr_date={}
    for i in range(len(a)-1):
        cr_T=(os.path.getmtime(a[i]))
        cr_time = time.ctime(cr_T)
        cr_t_obj = time.strptime(cr_time)
        date = time.strftime("%Y-%m-%d", cr_t_obj)
        if date in cr_date.keys():
            cr_date[date].append(a[i])
        else:
            cr_date[date]=[a[i]]
    return(cr_date)

# %%
import os
import time
import shutil

def cr_date(path):
    os.chdir(path)
    a = os.listdir()
    cr_date={}
    for i in range(len(a)-1):
        cr_T=(os.path.getmtime(a[i]))
        cr_time = time.ctime(cr_T)
        cr_t_obj = time.strptime(cr_time)
        date = time.strftime("%Y-%m-%d", cr_t_obj)
        file_path = path + "//" + a[i]
        if date in cr_date.keys():
            cr_date[date].append(file_path)
        else:
            cr_date[date]=[file_path]
    return(cr_date)

# %%
# data = cr_date("path")
def copy_file(dictionery = data):
    cr_date = dictionery
    fol_name = list(cr_date.keys())
    for i in cr_date.keys():
        f_list = cr_date[i]
        # print(f_list)
        current_directory = os.getcwd()
        v_format=(
".264", ".3g2", ".3gp", ".3gp2", ".3gpp", ".3gpp2", ".3mm", ".3p2", ".60d", ".787", ".89", ".aaf", ".aec", ".aep", ".aepx",
".aet", ".aetx", ".ajp", ".ale", ".am", ".amc", ".amv", ".amx", ".anim", ".aqt", ".arcut", ".arf", ".asf", ".asx", ".avb",
".avc", ".avd", ".avi", ".avp", ".avs", ".avs", ".avv", ".axm", ".bdm", ".bdmv", ".bdt2", ".bdt3", ".bik", ".bin", ".bix",
".bmk", ".bnp", ".box", ".bs4", ".bsf", ".bvr", ".byu", ".camproj", ".camrec", ".camv", ".ced", ".cel", ".cine", ".cip",
".clpi", ".cmmp", ".cmmtpl", ".cmproj", ".cmrec", ".cpi", ".cst", ".cvc", ".cx3", ".d2v", ".d3v", ".dat", ".dav", ".dce",
".dck", ".dcr", ".dcr", ".ddat", ".dif", ".dir", ".divx", ".dlx", ".dmb", ".dmsd", ".dmsd3d", ".dmsm", ".dmsm3d", ".dmss",
".dmx", ".dnc", ".dpa", ".dpg", ".dream", ".dsy", ".dv", ".dv-avi", ".dv4", ".dvdmedia", ".dvr", ".dvr-ms", ".dvx", ".dxr",
".dzm", ".dzp", ".dzt", ".edl", ".evo", ".eye", ".ezt", ".f4p", ".f4v", ".fbr", ".fbr", ".fbz", ".fcp", ".fcproject",
".ffd", ".flc", ".flh", ".fli", ".flv", ".flx", ".gfp", ".gl", ".gom", ".grasp", ".gts", ".gvi", ".gvp", ".h264", ".hdmov",
".hkm", ".ifo", ".imovieproj", ".imovieproject", ".ircp", ".irf", ".ism", ".ismc", ".ismv", ".iva", ".ivf", ".ivr", ".ivs",
".izz", ".izzy", ".jss", ".jts", ".jtv", ".k3g", ".kmv", ".ktn", ".lrec", ".lsf", ".lsx", ".m15", ".m1pg", ".m1v", ".m21",
".m21", ".m2a", ".m2p", ".m2t", ".m2ts", ".m2v", ".m4e", ".m4u", ".m4v", ".m75", ".mani", ".meta", ".mgv", ".mj2", ".mjp",
".mjpg", ".mk3d", ".mkv", ".mmv", ".mnv", ".mob", ".mod", ".modd", ".moff", ".moi", ".moov", ".mov", ".movie", ".mp21",
".mp21", ".mp2v", ".mp4", ".mp4v", ".mpe", ".mpeg", ".mpeg1", ".mpeg4", ".mpf", ".mpg", ".mpg2", ".mpgindex", ".mpl",
".mpl", ".mpls", ".mpsub", ".mpv", ".mpv2", ".mqv", ".msdvd", ".mse", ".msh", ".mswmm", ".mts", ".mtv", ".mvb", ".mvc",
".mvd", ".mve", ".mvex", ".mvp", ".mvp", ".mvy", ".mxf", ".mxv", ".mys", ".ncor", ".nsv", ".nut", ".nuv", ".nvc", ".ogm",
".ogv", ".ogx", ".osp", ".otrkey", ".pac", ".par", ".pds", ".pgi", ".photoshow", ".piv", ".pjs", ".playlist", ".plproj",
".pmf", ".pmv", ".pns", ".ppj", ".prel", ".pro", ".prproj", ".prtl", ".psb", ".psh", ".pssd", ".pva", ".pvr", ".pxv",
".qt", ".qtch", ".qtindex", ".qtl", ".qtm", ".qtz", ".r3d", ".rcd", ".rcproject", ".rdb", ".rec", ".rm", ".rmd", ".rmd",
".rmp", ".rms", ".rmv", ".rmvb", ".roq", ".rp", ".rsx", ".rts", ".rts", ".rum", ".rv", ".rvid", ".rvl", ".sbk", ".sbt",
".scc", ".scm", ".scm", ".scn", ".screenflow", ".sec", ".sedprj", ".seq", ".sfd", ".sfvidcap", ".siv", ".smi", ".smi",
".smil", ".smk", ".sml", ".smv", ".spl", ".sqz", ".srt", ".ssf", ".ssm", ".stl", ".str", ".stx", ".svi", ".swf", ".swi",
".swt", ".tda3mt", ".tdx", ".thp", ".tivo", ".tix", ".tod", ".tp", ".tp0", ".tpd", ".tpr", ".trp", ".ts", ".tsp", ".ttxt",
".tvs", ".usf", ".usm", ".vc1", ".vcpf", ".vcr", ".vcv", ".vdo", ".vdr", ".vdx", ".veg",".vem", ".vep", ".vf", ".vft",
".vfw", ".vfz", ".vgz", ".vid", ".video", ".viewlet", ".viv", ".vivo", ".vlab", ".vob", ".vp3", ".vp6", ".vp7", ".vpj",
".vro", ".vs4", ".vse", ".vsp", ".w32", ".wcp", ".webm", ".wlmp", ".wm", ".wmd", ".wmmp", ".wmv", ".wmx", ".wot", ".wp3",
".wpl", ".wtv", ".wve", ".wvx", ".xej", ".xel", ".xesc", ".xfl", ".xlmv", ".xmv", ".xvid", ".y4m", ".yog", ".yuv", ".zeg",
".zm1", ".zm2", ".zm3", ".zmv"  )
        if fol_name in os.listdir():
            for j in range(len(f_list)-1):
                file_name = f_list[j]
                print(file_name)
                if file_name.endswith(v_format):
                    v_copy_path=i+"//video"
                    # if path exist copy the file
                    if v_copy_path in os.listdir:
                        shutil.copyfile(file_name,v_copy_path)
                        print("v_copy_done")
                # if path does not exist make the path then copy
                    else:
                        os.makedirs(i+"//video")
                        shutil.copyfile(file_name,v_copy_path)
                        print("v_fol_md_cpy_dn")
                        print("v_cpy_dn")
                # move the file_name in fol_name//video
                else:
                    i_copy_path=i+"//img"
                    #  if path exist then copy
                    if i_copy_path in os.listdir:
                        shutil.copyfile(file_name,i_copy_path)
                        print("i_cpy_dn")
                    #  if path do not exist then make path and them copy
                    else:
                        os.mkdir(i+"//img")
                        shutil.copyfile(file_name,i_copy_path)
                        print("i_fol_md_cpy_dn")
                        print("i_cpy_dn")
                    # move the file_name in fol_name//img
        else:
            print(i)
            os.makedirs(i,exist_ok=True)
            print("nw_fol", i, " md")
            for j in range(len(f_list)):
                print("in")
                file_name = f_list[j]
                print(file_name)
                if file_name.endswith(v_format):
                    v_copy_path=i+"//video"
                    # if path exist copy the file
                    dir_list=os.listdir()
                    if v_copy_path in dir_list:
                        shutil.copyfile(file_name,v_copy_path)
                        print("v_copy_done")
                # if path does not exist make the path then copy
                    else:
                        os.makedirs(i+"//video",exist_ok=True)
                        shutil.copy(file_name,v_copy_path)
                        print("v_fol_md_cpy_dn")
                        print("v_cpy_dn")
                    # move the file_name in fol_name//video
                else:
                    i_copy_path=i+"//img"
                    #  if path exist then copy
                    if i_copy_path in os.listdir():
                        shutil.copyfile(file_name,i_copy_path)
                        print("i_cpy_dn")
                    #  if path do not exist then make path and them copy
                    else:
                        os.makedirs(i+"//img",exist_ok=True)
                        shutil.copy(file_name,i_copy_path)
                        print("i_fol_md_cpy_dn")
                        print("i_cpy_dn")
                        # move the file_name in fol_name//img

# %%
copy_file()

# %%
def copy_file(data):
    cr_date = data
    fol_name = list(cr_date.keys())
    for i in cr_date.keys():
        f_list = cr_date[i]
        # print(f_list)
        current_directory = os.getcwd()
        v_format=(
".264", ".3g2", ".3gp", ".3gp2", ".3gpp", ".3gpp2", ".3mm", ".3p2", ".60d", ".787", ".89", ".aaf", ".aec", ".aep", ".aepx",
".aet", ".aetx", ".ajp", ".ale", ".am", ".amc", ".amv", ".amx", ".anim", ".aqt", ".arcut", ".arf", ".asf", ".asx", ".avb",
".avc", ".avd", ".avi", ".avp", ".avs", ".avs", ".avv", ".axm", ".bdm", ".bdmv", ".bdt2", ".bdt3", ".bik", ".bin", ".bix",
".bmk", ".bnp", ".box", ".bs4", ".bsf", ".bvr", ".byu", ".camproj", ".camrec", ".camv", ".ced", ".cel", ".cine", ".cip",
".clpi", ".cmmp", ".cmmtpl", ".cmproj", ".cmrec", ".cpi", ".cst", ".cvc", ".cx3", ".d2v", ".d3v", ".dat", ".dav", ".dce",
".dck", ".dcr", ".dcr", ".ddat", ".dif", ".dir", ".divx", ".dlx", ".dmb", ".dmsd", ".dmsd3d", ".dmsm", ".dmsm3d", ".dmss",
".dmx", ".dnc", ".dpa", ".dpg", ".dream", ".dsy", ".dv", ".dv-avi", ".dv4", ".dvdmedia", ".dvr", ".dvr-ms", ".dvx", ".dxr",
".dzm", ".dzp", ".dzt", ".edl", ".evo", ".eye", ".ezt", ".f4p", ".f4v", ".fbr", ".fbr", ".fbz", ".fcp", ".fcproject",
".ffd", ".flc", ".flh", ".fli", ".flv", ".flx", ".gfp", ".gl", ".gom", ".grasp", ".gts", ".gvi", ".gvp", ".h264", ".hdmov",
".hkm", ".ifo", ".imovieproj", ".imovieproject", ".ircp", ".irf", ".ism", ".ismc", ".ismv", ".iva", ".ivf", ".ivr", ".ivs",
".izz", ".izzy", ".jss", ".jts", ".jtv", ".k3g", ".kmv", ".ktn", ".lrec", ".lsf", ".lsx", ".m15", ".m1pg", ".m1v", ".m21",
".m21", ".m2a", ".m2p", ".m2t", ".m2ts", ".m2v", ".m4e", ".m4u", ".m4v", ".m75", ".mani", ".meta", ".mgv", ".mj2", ".mjp",
".mjpg", ".mk3d", ".mkv", ".mmv", ".mnv", ".mob", ".mod", ".modd", ".moff", ".moi", ".moov", ".mov", ".movie", ".mp21",
".mp21", ".mp2v", ".mp4", ".mp4v", ".mpe", ".mpeg", ".mpeg1", ".mpeg4", ".mpf", ".mpg", ".mpg2", ".mpgindex", ".mpl",
".mpl", ".mpls", ".mpsub", ".mpv", ".mpv2", ".mqv", ".msdvd", ".mse", ".msh", ".mswmm", ".mts", ".mtv", ".mvb", ".mvc",
".mvd", ".mve", ".mvex", ".mvp", ".mvp", ".mvy", ".mxf", ".mxv", ".mys", ".ncor", ".nsv", ".nut", ".nuv", ".nvc", ".ogm",
".ogv", ".ogx", ".osp", ".otrkey", ".pac", ".par", ".pds", ".pgi", ".photoshow", ".piv", ".pjs", ".playlist", ".plproj",
".pmf", ".pmv", ".pns", ".ppj", ".prel", ".pro", ".prproj", ".prtl", ".psb", ".psh", ".pssd", ".pva", ".pvr", ".pxv",
".qt", ".qtch", ".qtindex", ".qtl", ".qtm", ".qtz", ".r3d", ".rcd", ".rcproject", ".rdb", ".rec", ".rm", ".rmd", ".rmd",
".rmp", ".rms", ".rmv", ".rmvb", ".roq", ".rp", ".rsx", ".rts", ".rts", ".rum", ".rv", ".rvid", ".rvl", ".sbk", ".sbt",
".scc", ".scm", ".scm", ".scn", ".screenflow", ".sec", ".sedprj", ".seq", ".sfd", ".sfvidcap", ".siv", ".smi", ".smi",
".smil", ".smk", ".sml", ".smv", ".spl", ".sqz", ".srt", ".ssf", ".ssm", ".stl", ".str", ".stx", ".svi", ".swf", ".swi",
".swt", ".tda3mt", ".tdx", ".thp", ".tivo", ".tix", ".tod", ".tp", ".tp0", ".tpd", ".tpr", ".trp", ".ts", ".tsp", ".ttxt",
".tvs", ".usf", ".usm", ".vc1", ".vcpf", ".vcr", ".vcv", ".vdo", ".vdr", ".vdx", ".veg",".vem", ".vep", ".vf", ".vft",
".vfw", ".vfz", ".vgz", ".vid", ".video", ".viewlet", ".viv", ".vivo", ".vlab", ".vob", ".vp3", ".vp6", ".vp7", ".vpj",
".vro", ".vs4", ".vse", ".vsp", ".w32", ".wcp", ".webm", ".wlmp", ".wm", ".wmd", ".wmmp", ".wmv", ".wmx", ".wot", ".wp3",
".wpl", ".wtv", ".wve", ".wvx", ".xej", ".xel", ".xesc", ".xfl", ".xlmv", ".xmv", ".xvid", ".y4m", ".yog", ".yuv", ".zeg",
".zm1", ".zm2", ".zm3", ".zmv"  )
        if fol_name in os.listdir():
            for j in range(len(f_list)-1):
                file_name = f_list[j]
                print(file_name)
                if file_name.endswith(v_format):
                    v_copy_path=i+"//video"
                    # if path exist copy the file
                    if v_copy_path in os.listdir:
                        shutil.copyfile(file_name,v_copy_path)
                        print("v_copy_done")
                # if path does not exist make the path then copy
                    else:
                        os.makedirs(i+"//video")
                        shutil.copyfile(file_name,v_copy_path)
                        print("v_fol_md_cpy_dn")
                        print("v_cpy_dn")
                # move the file_name in fol_name//video
                else:
                    i_copy_path=i+"//img"
                    #  if path exist then copy
                    if i_copy_path in os.listdir:
                        shutil.copyfile(file_name,i_copy_path)
                        print("i_cpy_dn")
                    #  if path do not exist then make path and them copy
                    else:
                        os.mkdir(i+"//img")
                        shutil.copyfile(file_name,i_copy_path)
                        print("i_fol_md_cpy_dn")
                        print("i_cpy_dn")
                    # move the file_name in fol_name//img
        else:
            print(i)
            os.makedirs(i,exist_ok=True)
            print("nw_fol", i, " md")
            for j in range(len(f_list)):
                print("in")
                file_name = f_list[j]
                print(file_name)
                if file_name.endswith(v_format):
                    v_copy_path=i+"//video"
                    # if path exist copy the file
                    dir_list=os.listdir()
                    if v_copy_path in dir_list:
                        shutil.copyfile(file_name,v_copy_path)
                        print("v_copy_done")
                # if path does not exist make the path then copy
                    else:
                        os.makedirs(i+"//video",exist_ok=True)
                        shutil.copy(file_name,v_copy_path)
                        print("v_fol_md_cpy_dn")
                        print("v_cpy_dn")
                    # move the file_name in fol_name//video
                else:
                    i_copy_path=i+"//img"
                    #  if path exist then copy
                    if i_copy_path in os.listdir():
                        shutil.copyfile(file_name,i_copy_path)
                        print("i_cpy_dn")
                    #  if path do not exist then make path and them copy
                    else:
                        os.makedirs(i+"//img",exist_ok=True)
                        shutil.copy(file_name,i_copy_path)
                        print("i_fol_md_cpy_dn")
                        print("i_cpy_dn")
                        # move the file_name in fol_name//img
# Out:
# True

# %%
def file_sort(path):
    data = []
    dir_list = os.listdir(path)
    for i in range(len(dir_list)-1)
        if os.path.isdir(path+"\\"+i):
            new_path = path+"\\"+i
            data.append(cr_date(new_path))
        elif os.path.isfile(path+"\\"+i):
            data.append(cr_date(path))

    for i in range(len(data)-1):
        copy_file(data[i])

# %%
import os
import time
import shutil


# Fuction to make dir with date and file path 
def cr_date(path):
    os.chdir(path)
    a = os.listdir()
    cr_date={}
    for i in range(len(a)-1):
        cr_T=(os.path.getmtime(a[i]))
        cr_time = time.ctime(cr_T)
        cr_t_obj = time.strptime(cr_time)
        date = time.strftime("%Y-%m-%d", cr_t_obj)
        file_path = path + "//" + a[i]
        if date in cr_date.keys():
            cr_date[date].append(file_path)
        else:
            cr_date[date]=[file_path]
    return(cr_date)

#  Fuction to copy files in the proper place using dir made in cr_date Fuction
def copy_file(data):
    cr_date = data
    fol_name = list(cr_date.keys())
    for i in cr_date.keys():
        f_list = cr_date[i]
        # print(f_list)
        current_directory = os.getcwd()
        v_format=(
".264", ".3g2", ".3gp", ".3gp2", ".3gpp", ".3gpp2", ".3mm", ".3p2", ".60d", ".787", ".89", ".aaf", ".aec", ".aep", ".aepx",
".aet", ".aetx", ".ajp", ".ale", ".am", ".amc", ".amv", ".amx", ".anim", ".aqt", ".arcut", ".arf", ".asf", ".asx", ".avb",
".avc", ".avd", ".avi", ".avp", ".avs", ".avs", ".avv", ".axm", ".bdm", ".bdmv", ".bdt2", ".bdt3", ".bik", ".bin", ".bix",
".bmk", ".bnp", ".box", ".bs4", ".bsf", ".bvr", ".byu", ".camproj", ".camrec", ".camv", ".ced", ".cel", ".cine", ".cip",
".clpi", ".cmmp", ".cmmtpl", ".cmproj", ".cmrec", ".cpi", ".cst", ".cvc", ".cx3", ".d2v", ".d3v", ".dat", ".dav", ".dce",
".dck", ".dcr", ".dcr", ".ddat", ".dif", ".dir", ".divx", ".dlx", ".dmb", ".dmsd", ".dmsd3d", ".dmsm", ".dmsm3d", ".dmss",
".dmx", ".dnc", ".dpa", ".dpg", ".dream", ".dsy", ".dv", ".dv-avi", ".dv4", ".dvdmedia", ".dvr", ".dvr-ms", ".dvx", ".dxr",
".dzm", ".dzp", ".dzt", ".edl", ".evo", ".eye", ".ezt", ".f4p", ".f4v", ".fbr", ".fbr", ".fbz", ".fcp", ".fcproject",
".ffd", ".flc", ".flh", ".fli", ".flv", ".flx", ".gfp", ".gl", ".gom", ".grasp", ".gts", ".gvi", ".gvp", ".h264", ".hdmov",
".hkm", ".ifo", ".imovieproj", ".imovieproject", ".ircp", ".irf", ".ism", ".ismc", ".ismv", ".iva", ".ivf", ".ivr", ".ivs",
".izz", ".izzy", ".jss", ".jts", ".jtv", ".k3g", ".kmv", ".ktn", ".lrec", ".lsf", ".lsx", ".m15", ".m1pg", ".m1v", ".m21",
".m21", ".m2a", ".m2p", ".m2t", ".m2ts", ".m2v", ".m4e", ".m4u", ".m4v", ".m75", ".mani", ".meta", ".mgv", ".mj2", ".mjp",
".mjpg", ".mk3d", ".mkv", ".mmv", ".mnv", ".mob", ".mod", ".modd", ".moff", ".moi", ".moov", ".mov", ".movie", ".mp21",
".mp21", ".mp2v", ".mp4", ".mp4v", ".mpe", ".mpeg", ".mpeg1", ".mpeg4", ".mpf", ".mpg", ".mpg2", ".mpgindex", ".mpl",
".mpl", ".mpls", ".mpsub", ".mpv", ".mpv2", ".mqv", ".msdvd", ".mse", ".msh", ".mswmm", ".mts", ".mtv", ".mvb", ".mvc",
".mvd", ".mve", ".mvex", ".mvp", ".mvp", ".mvy", ".mxf", ".mxv", ".mys", ".ncor", ".nsv", ".nut", ".nuv", ".nvc", ".ogm",
".ogv", ".ogx", ".osp", ".otrkey", ".pac", ".par", ".pds", ".pgi", ".photoshow", ".piv", ".pjs", ".playlist", ".plproj",
".pmf", ".pmv", ".pns", ".ppj", ".prel", ".pro", ".prproj", ".prtl", ".psb", ".psh", ".pssd", ".pva", ".pvr", ".pxv",
".qt", ".qtch", ".qtindex", ".qtl", ".qtm", ".qtz", ".r3d", ".rcd", ".rcproject", ".rdb", ".rec", ".rm", ".rmd", ".rmd",
".rmp", ".rms", ".rmv", ".rmvb", ".roq", ".rp", ".rsx", ".rts", ".rts", ".rum", ".rv", ".rvid", ".rvl", ".sbk", ".sbt",
".scc", ".scm", ".scm", ".scn", ".screenflow", ".sec", ".sedprj", ".seq", ".sfd", ".sfvidcap", ".siv", ".smi", ".smi",
".smil", ".smk", ".sml", ".smv", ".spl", ".sqz", ".srt", ".ssf", ".ssm", ".stl", ".str", ".stx", ".svi", ".swf", ".swi",
".swt", ".tda3mt", ".tdx", ".thp", ".tivo", ".tix", ".tod", ".tp", ".tp0", ".tpd", ".tpr", ".trp", ".ts", ".tsp", ".ttxt",
".tvs", ".usf", ".usm", ".vc1", ".vcpf", ".vcr", ".vcv", ".vdo", ".vdr", ".vdx", ".veg",".vem", ".vep", ".vf", ".vft",
".vfw", ".vfz", ".vgz", ".vid", ".video", ".viewlet", ".viv", ".vivo", ".vlab", ".vob", ".vp3", ".vp6", ".vp7", ".vpj",
".vro", ".vs4", ".vse", ".vsp", ".w32", ".wcp", ".webm", ".wlmp", ".wm", ".wmd", ".wmmp", ".wmv", ".wmx", ".wot", ".wp3",
".wpl", ".wtv", ".wve", ".wvx", ".xej", ".xel", ".xesc", ".xfl", ".xlmv", ".xmv", ".xvid", ".y4m", ".yog", ".yuv", ".zeg",
".zm1", ".zm2", ".zm3", ".zmv"  )
        if fol_name in os.listdir():
            for j in range(len(f_list)-1):
                file_name = f_list[j]
                print(file_name)
                if os.path.isdir(file_name):
                    pass
                elif os.path.isfile(file_name):
                    if file_name.endswith(v_format):
                        v_copy_path=i+"//video"
                        # if path exist copy the file
                        if v_copy_path in os.listdir:
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_copy_done")
                    # if path does not exist make the path then copy
                        else:
                            os.makedirs(i+"//video")
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_fol_md_cpy_dn")
                            print("v_cpy_dn")
                    # move the file_name in fol_name//video
                    else:
                        i_copy_path=i+"//img"
                        #  if path exist then copy
                        if i_copy_path in os.listdir:
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_cpy_dn")
                        #  if path do not exist then make path and them copy
                        else:
                            os.mkdir(i+"//img")
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_fol_md_cpy_dn")
                            print("i_cpy_dn")
                        # move the file_name in fol_name//img
        else:
            print(i)
            os.makedirs(i,exist_ok=True)
            print("nw_fol", i, " md")
            for j in range(len(f_list)):
                print("in")
                file_name = f_list[j]
                print(file_name)
                if os.path.isdir(file_name):
                    pass
                else:    
                    if file_name.endswith(v_format):
                        v_copy_path=i+"//video"
                        # if path exist copy the file
                        dir_list=os.listdir()
                        if v_copy_path in dir_list:
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_copy_done")
                    # if path does not exist make the path then copy
                        else:
                            os.makedirs(i+"//video",exist_ok=True)
                            shutil.copy(file_name,v_copy_path)
                            print("v_fol_md_cpy_dn")
                            print("v_cpy_dn")
                        # move the file_name in fol_name//video
                    else:
                        i_copy_path=i+"//img"
                        #  if path exist then copy
                        if i_copy_path in os.listdir():
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_cpy_dn")
                        #  if path do not exist then make path and them copy
                        else:
                            os.makedirs(i+"//img",exist_ok=True)
                            shutil.copy(file_name,i_copy_path)
                            print("i_fol_md_cpy_dn")
                            print("i_cpy_dn")
                            # move the file_name in fol_name//img



# Fuction to call above both fuctions
def file_sort(path):
    data = []
    dir_list = os.listdir(path)
    for i in range(len(dir_list)-1):
        if os.path.isdir(path+"\\"+dir_list[i]):
            new_path = path+"\\"+dir_list[i]
            data.append(cr_date(new_path))
        elif os.path.isfile(path+"\\"+dir_list[i]):
            data.append(cr_date(path))

    print(data)
    # for i in range(len(data)-1):
    #     copy_file(data[i])

file_sort("D:\\test")

# %%
# Done

import os
import time
import shutil


# Fuction to make dir with date and file path 
def cr_date(path):
    os.chdir(path)
    a = os.listdir()
    cr_date={}
    for i in range(len(a)):
        cr_T=(os.path.getmtime(a[i]))
        cr_time = time.ctime(cr_T)
        cr_t_obj = time.strptime(cr_time)
        date = time.strftime("%Y-%m-%d", cr_t_obj)
        file_path = path + "\\" + a[i]
        if date in cr_date.keys():
            cr_date[date].append(file_path)
        else:
            cr_date[date]=[file_path]
    return(cr_date)

#  Fuction to copy files in the proper place using dir made in cr_date Fuction
def copy_file(data, copy_path):
    os.chdir(copy_path)
    cr_date = data
    fol_name = list(cr_date.keys())
    for i in cr_date.keys():
        f_list = cr_date[i]
        # print(f_list)
        current_directory = os.getcwd()
        v_format=(
".264", ".3g2", ".3gp", ".3gp2", ".3gpp", ".3gpp2", ".3mm", ".3p2", ".60d", ".787", ".89", ".aaf", ".aec", ".aep", ".aepx",
".aet", ".aetx", ".ajp", ".ale", ".am", ".amc", ".amv", ".amx", ".anim", ".aqt", ".arcut", ".arf", ".asf", ".asx", ".avb",
".avc", ".avd", ".avi", ".avp", ".avs", ".avs", ".avv", ".axm", ".bdm", ".bdmv", ".bdt2", ".bdt3", ".bik", ".bin", ".bix",
".bmk", ".bnp", ".box", ".bs4", ".bsf", ".bvr", ".byu", ".camproj", ".camrec", ".camv", ".ced", ".cel", ".cine", ".cip",
".clpi", ".cmmp", ".cmmtpl", ".cmproj", ".cmrec", ".cpi", ".cst", ".cvc", ".cx3", ".d2v", ".d3v", ".dat", ".dav", ".dce",
".dck", ".dcr", ".dcr", ".ddat", ".dif", ".dir", ".divx", ".dlx", ".dmb", ".dmsd", ".dmsd3d", ".dmsm", ".dmsm3d", ".dmss",
".dmx", ".dnc", ".dpa", ".dpg", ".dream", ".dsy", ".dv", ".dv-avi", ".dv4", ".dvdmedia", ".dvr", ".dvr-ms", ".dvx", ".dxr",
".dzm", ".dzp", ".dzt", ".edl", ".evo", ".eye", ".ezt", ".f4p", ".f4v", ".fbr", ".fbr", ".fbz", ".fcp", ".fcproject",
".ffd", ".flc", ".flh", ".fli", ".flv", ".flx", ".gfp", ".gl", ".gom", ".grasp", ".gts", ".gvi", ".gvp", ".h264", ".hdmov",
".hkm", ".ifo", ".imovieproj", ".imovieproject", ".ircp", ".irf", ".ism", ".ismc", ".ismv", ".iva", ".ivf", ".ivr", ".ivs",
".izz", ".izzy", ".jss", ".jts", ".jtv", ".k3g", ".kmv", ".ktn", ".lrec", ".lsf", ".lsx", ".m15", ".m1pg", ".m1v", ".m21",
".m21", ".m2a", ".m2p", ".m2t", ".m2ts", ".m2v", ".m4e", ".m4u", ".m4v", ".m75", ".mani", ".meta", ".mgv", ".mj2", ".mjp",
".mjpg", ".mk3d", ".mkv", ".mmv", ".mnv", ".mob", ".mod", ".modd", ".moff", ".moi", ".moov", ".mov", ".movie", ".mp21",
".mp21", ".mp2v", ".mp4", ".mp4v", ".mpe", ".mpeg", ".mpeg1", ".mpeg4", ".mpf", ".mpg", ".mpg2", ".mpgindex", ".mpl",
".mpl", ".mpls", ".mpsub", ".mpv", ".mpv2", ".mqv", ".msdvd", ".mse", ".msh", ".mswmm", ".mts", ".mtv", ".mvb", ".mvc",
".mvd", ".mve", ".mvex", ".mvp", ".mvp", ".mvy", ".mxf", ".mxv", ".mys", ".ncor", ".nsv", ".nut", ".nuv", ".nvc", ".ogm",
".ogv", ".ogx", ".osp", ".otrkey", ".pac", ".par", ".pds", ".pgi", ".photoshow", ".piv", ".pjs", ".playlist", ".plproj",
".pmf", ".pmv", ".pns", ".ppj", ".prel", ".pro", ".prproj", ".prtl", ".psb", ".psh", ".pssd", ".pva", ".pvr", ".pxv",
".qt", ".qtch", ".qtindex", ".qtl", ".qtm", ".qtz", ".r3d", ".rcd", ".rcproject", ".rdb", ".rec", ".rm", ".rmd", ".rmd",
".rmp", ".rms", ".rmv", ".rmvb", ".roq", ".rp", ".rsx", ".rts", ".rts", ".rum", ".rv", ".rvid", ".rvl", ".sbk", ".sbt",
".scc", ".scm", ".scm", ".scn", ".screenflow", ".sec", ".sedprj", ".seq", ".sfd", ".sfvidcap", ".siv", ".smi", ".smi",
".smil", ".smk", ".sml", ".smv", ".spl", ".sqz", ".srt", ".ssf", ".ssm", ".stl", ".str", ".stx", ".svi", ".swf", ".swi",
".swt", ".tda3mt", ".tdx", ".thp", ".tivo", ".tix", ".tod", ".tp", ".tp0", ".tpd", ".tpr", ".trp", ".ts", ".tsp", ".ttxt",
".tvs", ".usf", ".usm", ".vc1", ".vcpf", ".vcr", ".vcv", ".vdo", ".vdr", ".vdx", ".veg",".vem", ".vep", ".vf", ".vft",
".vfw", ".vfz", ".vgz", ".vid", ".video", ".viewlet", ".viv", ".vivo", ".vlab", ".vob", ".vp3", ".vp6", ".vp7", ".vpj",
".vro", ".vs4", ".vse", ".vsp", ".w32", ".wcp", ".webm", ".wlmp", ".wm", ".wmd", ".wmmp", ".wmv", ".wmx", ".wot", ".wp3",
".wpl", ".wtv", ".wve", ".wvx", ".xej", ".xel", ".xesc", ".xfl", ".xlmv", ".xmv", ".xvid", ".y4m", ".yog", ".yuv", ".zeg",
".zm1", ".zm2", ".zm3", ".zmv"  )
        if fol_name in os.listdir():
            for j in range(len(f_list)):
                file_name = f_list[j]
                print(file_name)
                if os.path.isdir(file_name):
                    pass
                else:
                    if file_name.endswith(v_format):
                        v_copy_path=copy_path + "\\"+ i+"\\video"
                        # if path exist copy the file
                        if v_copy_path in os.listdir:
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_copy_done")
                    # if path does not exist make the path then copy
                        else:
                            os.makedirs(i+"\\video")
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_fol_md_cpy_dn")
                            print("v_cpy_dn")
                    # move the file_name in fol_name\\video
                    else:
                        i_copy_path=copy_path + "\\"+ i+"\\img"
                        #  if path exist then copy
                        if i_copy_path in os.listdir:
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_cpy_dn")
                        #  if path do not exist then make path and them copy
                        else:
                            os.mkdir(i+"\\img")
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_fol_md_cpy_dn")
                            print("i_cpy_dn")
                        # move the file_name in fol_name\\img
        else:
            print(i)
            os.makedirs(i,exist_ok=True)
            print("nw_fol", i, " md")
            for j in range(len(f_list)):
                print("in")
                file_name = f_list[j]
                print(file_name)
                if os.path.isdir(file_name):
                    pass
                else:    
                    if file_name.endswith(v_format):
                        v_copy_path=copy_path + "\\"+i+"\\video"
                        # if path exist copy the file
                        dir_list=os.listdir()
                        if v_copy_path in dir_list:
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_copy_done")
                    # if path does not exist make the path then copy
                        else:
                            os.makedirs(i+"\\video",exist_ok=True)
                            shutil.copy(file_name,v_copy_path)
                            print("v_fol_md_cpy_dn")
                            print("v_cpy_dn")
                        # move the file_name in fol_name\\video
                    else:
                        i_copy_path=copy_path + "\\"+i+"\\img"
                        #  if path exist then copy
                        if i_copy_path in os.listdir():
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_cpy_dn")
                        #  if path do not exist then make path and them copy
                        else:
                            os.makedirs(i+"\\img",exist_ok=True)
                            shutil.copy(file_name,i_copy_path)
                            print("i_fol_md_cpy_dn")
                            print("i_cpy_dn")
                            # move the file_name in fol_name\\img



# Fuction to call above both fuctions
def file_sort(scr_path,copy_path):
    data = []
    dir_list = os.listdir(scr_path)
    for i in range(len(dir_list)):
        if os.path.isfile(scr_path+"\\"+dir_list[i]):
            pass
        if os.path.isdir(scr_path+"\\"+dir_list[i]):
            new_path = scr_path+"\\"+dir_list[i]
            data.append(cr_date(new_path))
    data.append(cr_date(scr_path))
    print("mapping done")
    print(data)
    for i in range(len(data)):
        print(i)
        copy_file(data[i],copy_path=copy_path)

file_sort(scr_path="D:\\test",copy_path="D:\\copy path test")

# %%
# Done

import os
import time
import shutil


# Fuction to make dir with date and file path 
def mapping(path):
    os.chdir(path)
    a = os.listdir()
    cr_date={}
    name = {}
    for i in range(len(a)):
        if os.path.isdir(a[i]):
            new_path = path+"\\"+a[i]
            mapping(new_path)
        else:
            os.chdir(path)
            cr_T=(os.path.getmtime(a[i]))
            cr_time = time.ctime(cr_T)
            cr_t_obj = time.strptime(cr_time)
            date = time.strftime("%Y-%m-%d", cr_t_obj)
            file_path = path + "\\" + a[i]
            if date in cr_date.keys():
                cr_date[date].append(file_path)
                name[date].append(a[i])
            else:
                cr_date[date]=[file_path]
                name[date]=[a[i]]
    return(cr_date,name)

#  Fuction to copy files in the proper place using dir made in cr_date Fuction
def copy_file(data, copy_path,name):
    os.chdir(copy_path)
    cr_date = data
    fol_name = list(cr_date.keys())
    for i in cr_date.keys():
        f_list = cr_date[i]
        # print(f_list)
        current_directory = os.getcwd()
        v_format=(
".264", ".3g2", ".3gp", ".3gp2", ".3gpp", ".3gpp2", ".3mm", ".3p2", ".60d", ".787", ".89", ".aaf", ".aec", ".aep", ".aepx",
".aet", ".aetx", ".ajp", ".ale", ".am", ".amc", ".amv", ".amx", ".anim", ".aqt", ".arcut", ".arf", ".asf", ".asx", ".avb",
".avc", ".avd", ".avi", ".avp", ".avs", ".avs", ".avv", ".axm", ".bdm", ".bdmv", ".bdt2", ".bdt3", ".bik", ".bin", ".bix",
".bmk", ".bnp", ".box", ".bs4", ".bsf", ".bvr", ".byu", ".camproj", ".camrec", ".camv", ".ced", ".cel", ".cine", ".cip",
".clpi", ".cmmp", ".cmmtpl", ".cmproj", ".cmrec", ".cpi", ".cst", ".cvc", ".cx3", ".d2v", ".d3v", ".dat", ".dav", ".dce",
".dck", ".dcr", ".dcr", ".ddat", ".dif", ".dir", ".divx", ".dlx", ".dmb", ".dmsd", ".dmsd3d", ".dmsm", ".dmsm3d", ".dmss",
".dmx", ".dnc", ".dpa", ".dpg", ".dream", ".dsy", ".dv", ".dv-avi", ".dv4", ".dvdmedia", ".dvr", ".dvr-ms", ".dvx", ".dxr",
".dzm", ".dzp", ".dzt", ".edl", ".evo", ".eye", ".ezt", ".f4p", ".f4v", ".fbr", ".fbr", ".fbz", ".fcp", ".fcproject",
".ffd", ".flc", ".flh", ".fli", ".flv", ".flx", ".gfp", ".gl", ".gom", ".grasp", ".gts", ".gvi", ".gvp", ".h264", ".hdmov",
".hkm", ".ifo", ".imovieproj", ".imovieproject", ".ircp", ".irf", ".ism", ".ismc", ".ismv", ".iva", ".ivf", ".ivr", ".ivs",
".izz", ".izzy", ".jss", ".jts", ".jtv", ".k3g", ".kmv", ".ktn", ".lrec", ".lsf", ".lsx", ".m15", ".m1pg", ".m1v", ".m21",
".m21", ".m2a", ".m2p", ".m2t", ".m2ts", ".m2v", ".m4e", ".m4u", ".m4v", ".m75", ".mani", ".meta", ".mgv", ".mj2", ".mjp",
".mjpg", ".mk3d", ".mkv", ".mmv", ".mnv", ".mob", ".mod", ".modd", ".moff", ".moi", ".moov", ".mov", ".movie", ".mp21",
".mp21", ".mp2v", ".mp4", ".mp4v", ".mpe", ".mpeg", ".mpeg1", ".mpeg4", ".mpf", ".mpg", ".mpg2", ".mpgindex", ".mpl",
".mpl", ".mpls", ".mpsub", ".mpv", ".mpv2", ".mqv", ".msdvd", ".mse", ".msh", ".mswmm", ".mts", ".mtv", ".mvb", ".mvc",
".mvd", ".mve", ".mvex", ".mvp", ".mvp", ".mvy", ".mxf", ".mxv", ".mys", ".ncor", ".nsv", ".nut", ".nuv", ".nvc", ".ogm",
".ogv", ".ogx", ".osp", ".otrkey", ".pac", ".par", ".pds", ".pgi", ".photoshow", ".piv", ".pjs", ".playlist", ".plproj",
".pmf", ".pmv", ".pns", ".ppj", ".prel", ".pro", ".prproj", ".prtl", ".psb", ".psh", ".pssd", ".pva", ".pvr", ".pxv",
".qt", ".qtch", ".qtindex", ".qtl", ".qtm", ".qtz", ".r3d", ".rcd", ".rcproject", ".rdb", ".rec", ".rm", ".rmd", ".rmd",
".rmp", ".rms", ".rmv", ".rmvb", ".roq", ".rp", ".rsx", ".rts", ".rts", ".rum", ".rv", ".rvid", ".rvl", ".sbk", ".sbt",
".scc", ".scm", ".scm", ".scn", ".screenflow", ".sec", ".sedprj", ".seq", ".sfd", ".sfvidcap", ".siv", ".smi", ".smi",
".smil", ".smk", ".sml", ".smv", ".spl", ".sqz", ".srt", ".ssf", ".ssm", ".stl", ".str", ".stx", ".svi", ".swf", ".swi",
".swt", ".tda3mt", ".tdx", ".thp", ".tivo", ".tix", ".tod", ".tp", ".tp0", ".tpd", ".tpr", ".trp", ".ts", ".tsp", ".ttxt",
".tvs", ".usf", ".usm", ".vc1", ".vcpf", ".vcr", ".vcv", ".vdo", ".vdr", ".vdx", ".veg",".vem", ".vep", ".vf", ".vft",
".vfw", ".vfz", ".vgz", ".vid", ".video", ".viewlet", ".viv", ".vivo", ".vlab", ".vob", ".vp3", ".vp6", ".vp7", ".vpj",
".vro", ".vs4", ".vse", ".vsp", ".w32", ".wcp", ".webm", ".wlmp", ".wm", ".wmd", ".wmmp", ".wmv", ".wmx", ".wot", ".wp3",
".wpl", ".wtv", ".wve", ".wvx", ".xej", ".xel", ".xesc", ".xfl", ".xlmv", ".xmv", ".xvid", ".y4m", ".yog", ".yuv", ".zeg",
".zm1", ".zm2", ".zm3", ".zmv"  )
        if fol_name in os.listdir():
            for j in range(len(f_list)):
                file_name = f_list[j]
                print(file_name)
                if os.path.isdir(file_name):
                    pass
                else:
                    if file_name.endswith(v_format):
                        v_copy_path=copy_path + "\\"+ i+"\\video"
                        # if path exist copy the file
                        if v_copy_path in os.listdir:
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_copy_done")
                            if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+name[i][j]).st_size:
                                print(True)
                    # if path does not exist make the path then copy
                        else:
                            os.makedirs(i+"\\video")
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_fol_md_cpy_dn")
                            print("v_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+name[i][j]).st_size:
                                print(True)
                    # move the file_name in fol_name\\video
                    else:
                        i_copy_path=copy_path + "\\"+ i+"\\img"
                        #  if path exist then copy
                        if i_copy_path in os.listdir:
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+name[i][j]).st_size:
                                print(True)
                        #  if path do not exist then make path and them copy
                        else:
                            os.mkdir(i+"\\img")
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_fol_md_cpy_dn")
                            print("i_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+name[i][j]).st_size:
                                print(True)
                        # move the file_name in fol_name\\img
        else:
            print(i)
            os.makedirs(i,exist_ok=True)
            print("nw_fol", i, " md")
            for j in range(len(f_list)):
                print("in")
                file_name = f_list[j]
                print(file_name)
                if os.path.isdir(file_name):
                    pass
                else:    
                    if file_name.endswith(v_format):
                        v_copy_path=copy_path + "\\"+i+"\\video"
                        # if path exist copy the file
                        dir_list=os.listdir()
                        if v_copy_path in dir_list:
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_copy_done")
                            if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+name[i][j]).st_size:
                                print(True)
                    # if path does not exist make the path then copy
                        else:
                            os.makedirs(i+"\\video",exist_ok=True)
                            shutil.copy(file_name,v_copy_path)
                            print("v_fol_md_cpy_dn")
                            print("v_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+name[i][j]).st_size:
                                print(True)
                        # move the file_name in fol_name\\video
                    else:
                        i_copy_path=copy_path + "\\"+i+"\\img"
                        #  if path exist then copy
                        if i_copy_path in os.listdir():
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+name[i][j]).st_size:
                                print(True)
                        #  if path do not exist then make path and them copy
                        else:
                            os.makedirs(i+"\\img",exist_ok=True)
                            shutil.copy(file_name,i_copy_path)
                            print("i_fol_md_cpy_dn")
                            print("i_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+name[i][j]).st_size:
                                print(True)
                            # move the file_name in fol_name\\img



# Fuction to call above both fuctions
# def file_sort(scr_path,copy_path):
#     data = []
#     dir_list = os.listdir(scr_path)
#     for i in range(len(dir_list)):
#         if os.path.isdir(scr_path+"\\"+dir_list[i]):
#             new_path = scr_path+"\\"+dir_list[i]
#             data.append(mapping(new_path))
#     data.append(mapping(scr_path))
#     print("mapping done")
#     print(data)
#     for i in range(len(data)):
#         print(i)
#         copy_file(data[i][0],copy_path=copy_path,name=data[i][1])
# file_sort(scr_path="D:\\test",copy_path="D:\\copy path test")
mapping("D:\\test")

# %%
import os
os.stat("D:\\backup\\VID_20221231_160153410.mp4")

# %%
# Done

import os
import time
import shutil


# Fuction to make dir with date and file path 
def cr_date(path):
    os.chdir(path)
    a = os.listdir()
    cr_date={}
    name = {}
    for i in range(len(a)):
        cr_T=(os.path.getmtime(a[i]))
        cr_time = time.ctime(cr_T)
        cr_t_obj = time.strptime(cr_time)
        date = time.strftime("%Y-%m-%d", cr_t_obj)
        file_path = path + "\\" + a[i]
        if date in cr_date.keys():
            cr_date[date].append(file_path)
            name[date].append(a[i])
        else:
            cr_date[date]=[file_path]
            name[date]=[a[i]]
    return(cr_date,name)

#  Fuction to copy files in the proper place using dir made in cr_date Fuction
def copy_file(data, copy_path,name):
    os.chdir(copy_path)
    cr_date = data
    fol_name = list(cr_date.keys())
    for i in cr_date.keys():
        f_list = cr_date[i]
        # print(f_list)
        current_directory = os.getcwd()
        v_format=(
".264", ".3g2", ".3gp", ".3gp2", ".3gpp", ".3gpp2", ".3mm", ".3p2", ".60d", ".787", ".89", ".aaf", ".aec", ".aep", ".aepx",
".aet", ".aetx", ".ajp", ".ale", ".am", ".amc", ".amv", ".amx", ".anim", ".aqt", ".arcut", ".arf", ".asf", ".asx", ".avb",
".avc", ".avd", ".avi", ".avp", ".avs", ".avs", ".avv", ".axm", ".bdm", ".bdmv", ".bdt2", ".bdt3", ".bik", ".bin", ".bix",
".bmk", ".bnp", ".box", ".bs4", ".bsf", ".bvr", ".byu", ".camproj", ".camrec", ".camv", ".ced", ".cel", ".cine", ".cip",
".clpi", ".cmmp", ".cmmtpl", ".cmproj", ".cmrec", ".cpi", ".cst", ".cvc", ".cx3", ".d2v", ".d3v", ".dat", ".dav", ".dce",
".dck", ".dcr", ".dcr", ".ddat", ".dif", ".dir", ".divx", ".dlx", ".dmb", ".dmsd", ".dmsd3d", ".dmsm", ".dmsm3d", ".dmss",
".dmx", ".dnc", ".dpa", ".dpg", ".dream", ".dsy", ".dv", ".dv-avi", ".dv4", ".dvdmedia", ".dvr", ".dvr-ms", ".dvx", ".dxr",
".dzm", ".dzp", ".dzt", ".edl", ".evo", ".eye", ".ezt", ".f4p", ".f4v", ".fbr", ".fbr", ".fbz", ".fcp", ".fcproject",
".ffd", ".flc", ".flh", ".fli", ".flv", ".flx", ".gfp", ".gl", ".gom", ".grasp", ".gts", ".gvi", ".gvp", ".h264", ".hdmov",
".hkm", ".ifo", ".imovieproj", ".imovieproject", ".ircp", ".irf", ".ism", ".ismc", ".ismv", ".iva", ".ivf", ".ivr", ".ivs",
".izz", ".izzy", ".jss", ".jts", ".jtv", ".k3g", ".kmv", ".ktn", ".lrec", ".lsf", ".lsx", ".m15", ".m1pg", ".m1v", ".m21",
".m21", ".m2a", ".m2p", ".m2t", ".m2ts", ".m2v", ".m4e", ".m4u", ".m4v", ".m75", ".mani", ".meta", ".mgv", ".mj2", ".mjp",
".mjpg", ".mk3d", ".mkv", ".mmv", ".mnv", ".mob", ".mod", ".modd", ".moff", ".moi", ".moov", ".mov", ".movie", ".mp21",
".mp21", ".mp2v", ".mp4", ".mp4v", ".mpe", ".mpeg", ".mpeg1", ".mpeg4", ".mpf", ".mpg", ".mpg2", ".mpgindex", ".mpl",
".mpl", ".mpls", ".mpsub", ".mpv", ".mpv2", ".mqv", ".msdvd", ".mse", ".msh", ".mswmm", ".mts", ".mtv", ".mvb", ".mvc",
".mvd", ".mve", ".mvex", ".mvp", ".mvp", ".mvy", ".mxf", ".mxv", ".mys", ".ncor", ".nsv", ".nut", ".nuv", ".nvc", ".ogm",
".ogv", ".ogx", ".osp", ".otrkey", ".pac", ".par", ".pds", ".pgi", ".photoshow", ".piv", ".pjs", ".playlist", ".plproj",
".pmf", ".pmv", ".pns", ".ppj", ".prel", ".pro", ".prproj", ".prtl", ".psb", ".psh", ".pssd", ".pva", ".pvr", ".pxv",
".qt", ".qtch", ".qtindex", ".qtl", ".qtm", ".qtz", ".r3d", ".rcd", ".rcproject", ".rdb", ".rec", ".rm", ".rmd", ".rmd",
".rmp", ".rms", ".rmv", ".rmvb", ".roq", ".rp", ".rsx", ".rts", ".rts", ".rum", ".rv", ".rvid", ".rvl", ".sbk", ".sbt",
".scc", ".scm", ".scm", ".scn", ".screenflow", ".sec", ".sedprj", ".seq", ".sfd", ".sfvidcap", ".siv", ".smi", ".smi",
".smil", ".smk", ".sml", ".smv", ".spl", ".sqz", ".srt", ".ssf", ".ssm", ".stl", ".str", ".stx", ".svi", ".swf", ".swi",
".swt", ".tda3mt", ".tdx", ".thp", ".tivo", ".tix", ".tod", ".tp", ".tp0", ".tpd", ".tpr", ".trp", ".ts", ".tsp", ".ttxt",
".tvs", ".usf", ".usm", ".vc1", ".vcpf", ".vcr", ".vcv", ".vdo", ".vdr", ".vdx", ".veg",".vem", ".vep", ".vf", ".vft",
".vfw", ".vfz", ".vgz", ".vid", ".video", ".viewlet", ".viv", ".vivo", ".vlab", ".vob", ".vp3", ".vp6", ".vp7", ".vpj",
".vro", ".vs4", ".vse", ".vsp", ".w32", ".wcp", ".webm", ".wlmp", ".wm", ".wmd", ".wmmp", ".wmv", ".wmx", ".wot", ".wp3",
".wpl", ".wtv", ".wve", ".wvx", ".xej", ".xel", ".xesc", ".xfl", ".xlmv", ".xmv", ".xvid", ".y4m", ".yog", ".yuv", ".zeg",
".zm1", ".zm2", ".zm3", ".zmv"  )
        if fol_name in os.listdir():
            for j in range(len(f_list)):
                file_name = f_list[j]
                print(file_name)
                if os.path.isdir(file_name):
                    pass
                else:
                    if file_name.endswith(v_format):
                        v_copy_path=copy_path + "\\"+ i+"\\video"
                        # if path exist copy the file
                        if v_copy_path in os.listdir:
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_copy_done")
                            if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                    # if path does not exist make the path then copy
                        else:
                            os.makedirs(i+"\\video")
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_fol_md_cpy_dn")
                            print("v_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                    # move the file_name in fol_name\\video
                    else:
                        i_copy_path=copy_path + "\\"+ i+"\\img"
                        #  if path exist then copy
                        if i_copy_path in os.listdir:
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                        #  if path do not exist then make path and them copy
                        else:
                            os.mkdir(i+"\\img")
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_fol_md_cpy_dn")
                            print("i_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                        # move the file_name in fol_name\\img
        else:
            print(i)
            os.makedirs(i,exist_ok=True)
            print("nw_fol", i, " md")
            for j in range(len(f_list)):
                print("in")
                file_name = f_list[j]
                print(file_name)
                if os.path.isdir(file_name):
                    pass
                else:    
                    if file_name.endswith(v_format):
                        v_copy_path=copy_path + "\\"+i+"\\video"
                        # if path exist copy the file
                        dir_list=os.listdir()
                        if v_copy_path in dir_list:
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_copy_done")
                            if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                    # if path does not exist make the path then copy
                        else:
                            os.makedirs(i+"\\video",exist_ok=True)
                            shutil.copy(file_name,v_copy_path)
                            print("v_fol_md_cpy_dn")
                            print("v_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                        # move the file_name in fol_name\\video
                    else:
                        i_copy_path=copy_path + "\\"+i+"\\img"
                        #  if path exist then copy
                        if i_copy_path in os.listdir():
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                        #  if path do not exist then make path and them copy
                        else:
                            os.makedirs(i+"\\img",exist_ok=True)
                            shutil.copy(file_name,i_copy_path)
                            print("i_fol_md_cpy_dn")
                            print("i_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                            # move the file_name in fol_name\\img



# Fuction to call above both fuctions
def file_sort(scr_path,copy_path):
    data = []
    dir_list = os.listdir(scr_path)
    for i in range(len(dir_list)):
        if os.path.isfile(scr_path+"\\"+dir_list[i]):
            pass
        if os.path.isdir(scr_path+"\\"+dir_list[i]):
            new_path = scr_path+"\\"+dir_list[i]
            data.append(cr_date(new_path))
    data.append(cr_date(scr_path))
    print("mapping done")
    print(data)
    for i in range(len(data)):
        print(i)
        copy_file(data[i][0],copy_path=copy_path,name=data[i][1])

file_sort(scr_path="D:\\test",copy_path="D:\\copy path test")

# %%
dirs ={}
def find_dirs(path):
    dirs[path] = []
    for i in os.listdir(path):
        if os.path.isdir(path+"\\"+i):
            dirs[path].append(path+"\\"+i)
        else:
            pass
    if path in dirs:
        for i in dirs[path]:
            find_dirs(i)
    else:
        pass
    return list(dirs.keys())

find_dirs("D:\\test")

# %%
import os
import time
import shutil


dirs ={}
def find_dirs(path):
    dirs[path] = []
    for i in os.listdir(path):
        if os.path.isdir(path+"\\"+i):
            dirs[path].append(path+"\\"+i)
        else:
            pass
    if path in dirs:
        for i in dirs[path]:
            find_dirs(i)
    else:
        pass
    return list(dirs.keys())

# Fuction to make dir with date and file path 
def mapping(path):
    cr_date={}
    name = {}
    for i in find_dirs(path):
        os.chdir(i)
        a = os.listdir()
        for i in range(len(a)):
            if os.path.isfile(a[i]):
                cr_T=(os.path.getmtime(a[i]))
                cr_time = time.ctime(cr_T)
                cr_t_obj = time.strptime(cr_time)
                date = time.strftime("%Y-%m-%d", cr_t_obj)
                file_path = path + "\\" + a[i]
                if date in cr_date.keys():
                    cr_date[date].append(file_path)
                    name[date].append(a[i])
                else:
                    cr_date[date]=[file_path]
                    name[date]=[a[i]]
    return(cr_date,name)

mapping("D:\\test")


# fuction to copy files


def copy_file(data, copy_path,name):
    os.chdir(copy_path)
    cr_date = data
    fol_name = list(cr_date.keys())
    for i in cr_date.keys():
        f_list = cr_date[i]
        # print(f_list)
        current_directory = os.getcwd()
        v_format=(
".264", ".3g2", ".3gp", ".3gp2", ".3gpp", ".3gpp2", ".3mm", ".3p2", ".60d", ".787", ".89", ".aaf", ".aec", ".aep", ".aepx",
".aet", ".aetx", ".ajp", ".ale", ".am", ".amc", ".amv", ".amx", ".anim", ".aqt", ".arcut", ".arf", ".asf", ".asx", ".avb",
".avc", ".avd", ".avi", ".avp", ".avs", ".avs", ".avv", ".axm", ".bdm", ".bdmv", ".bdt2", ".bdt3", ".bik", ".bin", ".bix",
".bmk", ".bnp", ".box", ".bs4", ".bsf", ".bvr", ".byu", ".camproj", ".camrec", ".camv", ".ced", ".cel", ".cine", ".cip",
".clpi", ".cmmp", ".cmmtpl", ".cmproj", ".cmrec", ".cpi", ".cst", ".cvc", ".cx3", ".d2v", ".d3v", ".dat", ".dav", ".dce",
".dck", ".dcr", ".dcr", ".ddat", ".dif", ".dir", ".divx", ".dlx", ".dmb", ".dmsd", ".dmsd3d", ".dmsm", ".dmsm3d", ".dmss",
".dmx", ".dnc", ".dpa", ".dpg", ".dream", ".dsy", ".dv", ".dv-avi", ".dv4", ".dvdmedia", ".dvr", ".dvr-ms", ".dvx", ".dxr",
".dzm", ".dzp", ".dzt", ".edl", ".evo", ".eye", ".ezt", ".f4p", ".f4v", ".fbr", ".fbr", ".fbz", ".fcp", ".fcproject",
".ffd", ".flc", ".flh", ".fli", ".flv", ".flx", ".gfp", ".gl", ".gom", ".grasp", ".gts", ".gvi", ".gvp", ".h264", ".hdmov",
".hkm", ".ifo", ".imovieproj", ".imovieproject", ".ircp", ".irf", ".ism", ".ismc", ".ismv", ".iva", ".ivf", ".ivr", ".ivs",
".izz", ".izzy", ".jss", ".jts", ".jtv", ".k3g", ".kmv", ".ktn", ".lrec", ".lsf", ".lsx", ".m15", ".m1pg", ".m1v", ".m21",
".m21", ".m2a", ".m2p", ".m2t", ".m2ts", ".m2v", ".m4e", ".m4u", ".m4v", ".m75", ".mani", ".meta", ".mgv", ".mj2", ".mjp",
".mjpg", ".mk3d", ".mkv", ".mmv", ".mnv", ".mob", ".mod", ".modd", ".moff", ".moi", ".moov", ".mov", ".movie", ".mp21",
".mp21", ".mp2v", ".mp4", ".mp4v", ".mpe", ".mpeg", ".mpeg1", ".mpeg4", ".mpf", ".mpg", ".mpg2", ".mpgindex", ".mpl",
".mpl", ".mpls", ".mpsub", ".mpv", ".mpv2", ".mqv", ".msdvd", ".mse", ".msh", ".mswmm", ".mts", ".mtv", ".mvb", ".mvc",
".mvd", ".mve", ".mvex", ".mvp", ".mvp", ".mvy", ".mxf", ".mxv", ".mys", ".ncor", ".nsv", ".nut", ".nuv", ".nvc", ".ogm",
".ogv", ".ogx", ".osp", ".otrkey", ".pac", ".par", ".pds", ".pgi", ".photoshow", ".piv", ".pjs", ".playlist", ".plproj",
".pmf", ".pmv", ".pns", ".ppj", ".prel", ".pro", ".prproj", ".prtl", ".psb", ".psh", ".pssd", ".pva", ".pvr", ".pxv",
".qt", ".qtch", ".qtindex", ".qtl", ".qtm", ".qtz", ".r3d", ".rcd", ".rcproject", ".rdb", ".rec", ".rm", ".rmd", ".rmd",
".rmp", ".rms", ".rmv", ".rmvb", ".roq", ".rp", ".rsx", ".rts", ".rts", ".rum", ".rv", ".rvid", ".rvl", ".sbk", ".sbt",
".scc", ".scm", ".scm", ".scn", ".screenflow", ".sec", ".sedprj", ".seq", ".sfd", ".sfvidcap", ".siv", ".smi", ".smi",
".smil", ".smk", ".sml", ".smv", ".spl", ".sqz", ".srt", ".ssf", ".ssm", ".stl", ".str", ".stx", ".svi", ".swf", ".swi",
".swt", ".tda3mt", ".tdx", ".thp", ".tivo", ".tix", ".tod", ".tp", ".tp0", ".tpd", ".tpr", ".trp", ".ts", ".tsp", ".ttxt",
".tvs", ".usf", ".usm", ".vc1", ".vcpf", ".vcr", ".vcv", ".vdo", ".vdr", ".vdx", ".veg",".vem", ".vep", ".vf", ".vft",
".vfw", ".vfz", ".vgz", ".vid", ".video", ".viewlet", ".viv", ".vivo", ".vlab", ".vob", ".vp3", ".vp6", ".vp7", ".vpj",
".vro", ".vs4", ".vse", ".vsp", ".w32", ".wcp", ".webm", ".wlmp", ".wm", ".wmd", ".wmmp", ".wmv", ".wmx", ".wot", ".wp3",
".wpl", ".wtv", ".wve", ".wvx", ".xej", ".xel", ".xesc", ".xfl", ".xlmv", ".xmv", ".xvid", ".y4m", ".yog", ".yuv", ".zeg",
".zm1", ".zm2", ".zm3", ".zmv"  )
        if fol_name in os.listdir():
            for j in range(len(f_list)):
                file_name = f_list[j]
                print(file_name)
                if os.path.isdir(file_name):
                    pass
                else:
                    if file_name.endswith(v_format):
                        v_copy_path=copy_path + "\\"+ i+"\\video"
                        # if path exist copy the file
                        if v_copy_path in os.listdir:
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_copy_done")
                            if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                    # if path does not exist make the path then copy
                        else:
                            os.makedirs(i+"\\video")
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_fol_md_cpy_dn")
                            print("v_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                    # move the file_name in fol_name\\video
                    else:
                        i_copy_path=copy_path + "\\"+ i+"\\img"
                        #  if path exist then copy
                        if i_copy_path in os.listdir:
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                        #  if path do not exist then make path and them copy
                        else:
                            os.mkdir(i+"\\img")
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_fol_md_cpy_dn")
                            print("i_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                        # move the file_name in fol_name\\img
        else:
            print(i)
            os.makedirs(i,exist_ok=True)
            print("nw_fol", i, " md")
            for j in range(len(f_list)):
                print("in")
                file_name = f_list[j]
                print(file_name)
                if os.path.isdir(file_name):
                    pass
                else:    
                    if file_name.endswith(v_format):
                        v_copy_path=copy_path + "\\"+i+"\\video"
                        # if path exist copy the file
                        dir_list=os.listdir()
                        if v_copy_path in dir_list:
                            shutil.copyfile(file_name,v_copy_path)
                            print("v_copy_done")
                            if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                    # if path does not exist make the path then copy
                        else:
                            os.makedirs(i+"\\video",exist_ok=True)
                            shutil.copy(file_name,v_copy_path)
                            print("v_fol_md_cpy_dn")
                            print("v_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                        # move the file_name in fol_name\\video
                    else:
                        i_copy_path=copy_path + "\\"+i+"\\img"
                        #  if path exist then copy
                        if i_copy_path in os.listdir():
                            shutil.copyfile(file_name,i_copy_path)
                            print("i_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                        #  if path do not exist then make path and them copy
                        else:
                            os.makedirs(i+"\\img",exist_ok=True)
                            shutil.copy(file_name,i_copy_path)
                            print("i_fol_md_cpy_dn")
                            print("i_cpy_dn")
                            if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+name[i][j]).st_size:
                                os.remove(file_name)
                            # move the file_name in fol_name\\img



# Fuction to call above both fuctions
def file_sort(scr_path,copy_path):
    data = []
    dir_list = os.listdir(scr_path)
    for i in range(len(dir_list)):
        if os.path.isfile(scr_path+"\\"+dir_list[i]):
            pass
        if os.path.isdir(scr_path+"\\"+dir_list[i]):
            new_path = scr_path+"\\"+dir_list[i]
            data.append(mapping(new_path))
    data.append(mapping(scr_path))
    print("mapping done")
    print(data)
    for i in range(len(data)):
        print(i)
        copy_file(data[i][0],copy_path=copy_path,name=data[i][1])

file_sort(scr_path="D:\\test",copy_path="D:\\copy path test")

# %%
# current version V1

import argparse
def file_sort(path,copy_path):
    import os
    import time
    import shutil
    import logging

    formatter = logging.Formatter("%(asctime)s %(name)s %(levelname)s %(message)s")
    def setup_logger(name, log_file, level=logging.INFO):
        """To set up as many loggers as you want"""
        handler = logging.FileHandler(log_file)
        handler.setFormatter(formatter)
        logger = logging.getLogger(name)
        logger.setLevel(level)
        if logger.handlers:
            logger.handlers = []
        logger.addHandler(handler)

        return logger

    dirs ={}
    def find_dirs(path):
        dirs[path] = []
        for i in os.listdir(path):
            if os.path.isdir(path+"\\"+i):
                dirs[path].append(path+"\\"+i)
            else:
                pass
        if path in dirs:
            for i in dirs[path]:
                find_dirs(i)
        else:
            pass
        
        return list(dirs.keys())
    all_dirs=find_dirs(path)
    log_file = open("log.log", "a")
    find_dirs_log = setup_logger("find_dirs",log_file= "log.log", level = logging.INFO)
    find_dirs_log.log(level=logging.INFO,msg="all Dirs Found")
    log_file.close()

    # Fuction to make dir with date and path 
    def mapping(path):
        file_location = []
        for j in all_dirs:
            a = os.listdir(j)
            for i in range(len(a)):
                if os.path.isdir(a[i]):
                    pass
                else:               
                    file_path = j + "\\" + a[i]
                    if os.path.isdir(file_path):
                        pass
                    else:
                        file_location.append(file_path)
        return(file_location)
    map = mapping(path)
    log_file = open("log.log", "a")
    mapping_log = setup_logger("mapping",log_file= "log.log", level = logging.INFO)
    mapping_log.log(level=logging.INFO,msg="all Files Found")
    log_file.close()

    # use the dir list to find dates of file in them
    def chr_date(path):
        cr_date = {}
        data = map
        for i in data:
            if os.path.isfile(i):
                cr_T=(os.path.getmtime(i))
                cr_time = time.ctime(cr_T)
                cr_t_obj = time.strptime(cr_time)
                date = time.strftime("%Y-%m-%d", cr_t_obj)
                file_path = i
                if date in cr_date.keys():
                    cr_date[date].append(file_path)
                else:
                    cr_date[date]=[file_path]
        return(cr_date)
    dates = chr_date(path)
    log_file = open("log.log", "a")
    chr_date_log = setup_logger("Chr_date",log_file= "log.log", level = logging.INFO)
    chr_date_log.log(level=logging.INFO,msg="all files Found with path and cr_dates")
    log_file.close()

    #  sorts the files by the data given by chr_date() fuction
    def copy_file(scr_path,copy_path):
        os.chdir(copy_path)
        cr_date = dates
        fol_name = list(cr_date.keys())
        for i in cr_date.keys():
            f_list = cr_date[i]
            # print(f_list)
            current_directory = os.getcwd()
            v_format=(
    ".264", ".3g2", ".3gp", ".3gp2", ".3gpp", ".3gpp2", ".3mm", ".3p2", ".60d", ".787", ".89", ".aaf", ".aec", ".aep", ".aepx",
    ".aet", ".aetx", ".ajp", ".ale", ".am", ".amc", ".amv", ".amx", ".anim", ".aqt", ".arcut", ".arf", ".asf", ".asx", ".avb",
    ".avc", ".avd", ".avi", ".avp", ".avs", ".avs", ".avv", ".axm", ".bdm", ".bdmv", ".bdt2", ".bdt3", ".bik", ".bin", ".bix",
    ".bmk", ".bnp", ".box", ".bs4", ".bsf", ".bvr", ".byu", ".camproj", ".camrec", ".camv", ".ced", ".cel", ".cine", ".cip",
    ".clpi", ".cmmp", ".cmmtpl", ".cmproj", ".cmrec", ".cpi", ".cst", ".cvc", ".cx3", ".d2v", ".d3v", ".dat", ".dav", ".dce",
    ".dck", ".dcr", ".dcr", ".ddat", ".dif", ".dir", ".divx", ".dlx", ".dmb", ".dmsd", ".dmsd3d", ".dmsm", ".dmsm3d", ".dmss",
    ".dmx", ".dnc", ".dpa", ".dpg", ".dream", ".dsy", ".dv", ".dv-avi", ".dv4", ".dvdmedia", ".dvr", ".dvr-ms", ".dvx", ".dxr",
    ".dzm", ".dzp", ".dzt", ".edl", ".evo", ".eye", ".ezt", ".f4p", ".f4v", ".fbr", ".fbr", ".fbz", ".fcp", ".fcproject",
    ".ffd", ".flc", ".flh", ".fli", ".flv", ".flx", ".gfp", ".gl", ".gom", ".grasp", ".gts", ".gvi", ".gvp", ".h264", ".hdmov",
    ".hkm", ".ifo", ".imovieproj", ".imovieproject", ".ircp", ".irf", ".ism", ".ismc", ".ismv", ".iva", ".ivf", ".ivr", ".ivs",
    ".izz", ".izzy", ".jss", ".jts", ".jtv", ".k3g", ".kmv", ".ktn", ".lrec", ".lsf", ".lsx", ".m15", ".m1pg", ".m1v", ".m21",
    ".m21", ".m2a", ".m2p", ".m2t", ".m2ts", ".m2v", ".m4e", ".m4u", ".m4v", ".m75", ".mani", ".meta", ".mgv", ".mj2", ".mjp",
    ".mjpg", ".mk3d", ".mkv", ".mmv", ".mnv", ".mob", ".mod", ".modd", ".moff", ".moi", ".moov", ".mov", ".movie", ".mp21",
    ".mp21", ".mp2v", ".mp4", ".mp4v", ".mpe", ".mpeg", ".mpeg1", ".mpeg4", ".mpf", ".mpg", ".mpg2", ".mpgindex", ".mpl",
    ".mpl", ".mpls", ".mpsub", ".mpv", ".mpv2", ".mqv", ".msdvd", ".mse", ".msh", ".mswmm", ".mts", ".mtv", ".mvb", ".mvc",
    ".mvd", ".mve", ".mvex", ".mvp", ".mvp", ".mvy", ".mxf", ".mxv", ".mys", ".ncor", ".nsv", ".nut", ".nuv", ".nvc", ".ogm",
    ".ogv", ".ogx", ".osp", ".otrkey", ".pac", ".par", ".pds", ".pgi", ".photoshow", ".piv", ".pjs", ".playlist", ".plproj",
    ".pmf", ".pmv", ".pns", ".ppj", ".prel", ".pro", ".prproj", ".prtl", ".psb", ".psh", ".pssd", ".pva", ".pvr", ".pxv",
    ".qt", ".qtch", ".qtindex", ".qtl", ".qtm", ".qtz", ".r3d", ".rcd", ".rcproject", ".rdb", ".rec", ".rm", ".rmd", ".rmd",
    ".rmp", ".rms", ".rmv", ".rmvb", ".roq", ".rp", ".rsx", ".rts", ".rts", ".rum", ".rv", ".rvid", ".rvl", ".sbk", ".sbt",
    ".scc", ".scm", ".scm", ".scn", ".screenflow", ".sec", ".sedprj", ".seq", ".sfd", ".sfvidcap", ".siv", ".smi", ".smi",
    ".smil", ".smk", ".sml", ".smv", ".spl", ".sqz", ".srt", ".ssf", ".ssm", ".stl", ".str", ".stx", ".svi", ".swf", ".swi",
    ".swt", ".tda3mt", ".tdx", ".thp", ".tivo", ".tix", ".tod", ".tp", ".tp0", ".tpd", ".tpr", ".trp", ".ts", ".tsp", ".ttxt",
    ".tvs", ".usf", ".usm", ".vc1", ".vcpf", ".vcr", ".vcv", ".vdo", ".vdr", ".vdx", ".veg",".vem", ".vep", ".vf", ".vft",
    ".vfw", ".vfz", ".vgz", ".vid", ".video", ".viewlet", ".viv", ".vivo", ".vlab", ".vob", ".vp3", ".vp6", ".vp7", ".vpj",
    ".vro", ".vs4", ".vse", ".vsp", ".w32", ".wcp", ".webm", ".wlmp", ".wm", ".wmd", ".wmmp", ".wmv", ".wmx", ".wot", ".wp3",
    ".wpl", ".wtv", ".wve", ".wvx", ".xej", ".xel", ".xesc", ".xfl", ".xlmv", ".xmv", ".xvid", ".y4m", ".yog", ".yuv", ".zeg",
    ".zm1", ".zm2", ".zm3", ".zmv"  )
            if fol_name in os.listdir():
                for j in range(len(f_list)):
                    file_name = f_list[j]
                    if os.path.isdir(file_name):
                        pass
                    else:
                        if file_name.endswith(v_format):
                            v_copy_path=copy_path + "\\"+ i+"\\video"
                            # if path exist copy the file
                            if v_copy_path in os.listdir:
                                shutil.copyfile(file_name,v_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="v_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                        # if path does not exist make the path then copy
                            else:
                                os.makedirs(i+"\\video")
                                shutil.copyfile(file_name,v_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="v_fol_made_&_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                        # move the file_name in fol_name\\video
                        else:
                            i_copy_path=copy_path + "\\"+ i+"\\img"
                            #  if path exist then copy
                            if i_copy_path in os.listdir:
                                shutil.copyfile(file_name,i_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="i_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                            #  if path do not exist then make path and them copy
                            else:
                                os.mkdir(i+"\\img")
                                shutil.copyfile(file_name,i_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="i_fol_made_&_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                            # move the file_name in fol_name\\img
            else:
                os.makedirs(i,exist_ok=True)
                log_file = open("log.log", "a")
                copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                copy_file_log.log(level=logging.INFO,msg="nw_fol"+i+" md")
                log_file.close()
                for j in range(len(f_list)):
                    file_name = f_list[j]
                    if os.path.isdir(file_name):
                        pass
                    else:    
                        if file_name.endswith(v_format):
                            v_copy_path=copy_path + "\\"+i+"\\video"
                            # if path exist copy the file
                            dir_list=os.listdir()
                            if v_copy_path in dir_list:
                                shutil.copyfile(file_name,v_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="v_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                        # if path does not exist make the path then copy
                            else:
                                os.makedirs(i+"\\video",exist_ok=True)
                                shutil.copy(file_name,v_copy_path)
                                if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="V_fol_made_&_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                            # move the file_name in fol_name\\video
                        else:
                            i_copy_path=copy_path + "\\"+i+"\\img"
                            #  if path exist then copy
                            if i_copy_path in os.listdir():
                                shutil.copyfile(file_name,i_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="i_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                            #  if path do not exist then make path and them copy
                            else:
                                os.makedirs(i+"\\img",exist_ok=True)
                                shutil.copy(file_name,i_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="i_fol_made_&_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                                # move the file_name in fol_name\\img
    copy_file(scr_path= path,copy_path=copy_path)
    log_file = open("log.log", "a")
    file_sort_log = setup_logger("File_sort",log_file= "log.log", level = logging.INFO)
    file_sort_log.log(level=logging.INFO,msg="all files from scr_path are moved and are sorted in copy_path")
    log_file.close()
pars = argparse.ArgumentParser()
pars.add_argument("-p" , "--path" , action="append", help="provide the absolute path of the source folder and copy folder in a list as -p "SOURCE PATH" -p "COPY PATH"")
args = pars.parse_args()
print(args)
scrpath = args.path[0]
copypath = args.path[1]

file_sort(path= str(scrpath),copy_path=str(copypath))

# command to run the program in cmd
# pushd <absuloute path of this file> & python file_sort.py -p "D:\test" -p "D:\copy path test"  (geralized)
# pushd D:\python scripts\.pyfiles & python file_sort.py -p "D:\test" -p "D:\copy path test" (personal)

# %%
# Working on Version V2

import argparse
def file_sort(path,copy_path):
    import os
    import time
    import shutil
    import logging

    formatter = logging.Formatter("%(asctime)s %(name)s %(levelname)s %(message)s")
    def setup_logger(name, log_file, level=logging.INFO):
        """To set up as many loggers as you want"""
        handler = logging.FileHandler(log_file)
        handler.setFormatter(formatter)
        logger = logging.getLogger(name)
        logger.setLevel(level)
        if logger.handlers:
            logger.handlers = []
        logger.addHandler(handler)

        return logger

    dirs ={}
    def find_dirs(path):
        dirs[path] = []
        for i in os.listdir(path):
            if os.path.isdir(path+"\\"+i):
                dirs[path].append(path+"\\"+i)
            else:
                pass
        if path in dirs:
            for i in dirs[path]:
                find_dirs(i)
        else:
            pass
        
        return list(dirs.keys())
    all_dirs=find_dirs(path)
    log_file = open("log.log", "a")
    find_dirs_log = setup_logger("find_dirs",log_file= "log.log", level = logging.INFO)
    find_dirs_log.log(level=logging.INFO,msg="all Dirs Found")
    log_file.close()

    # Fuction to make dir with date and path 
    def mapping(path):
        file_location = []
        for j in all_dirs:
            a = os.listdir(j)
            for i in range(len(a)):
                if os.path.isdir(a[i]):
                    pass
                else:               
                    file_path = j + "\\" + a[i]
                    if os.path.isdir(file_path):
                        pass
                    else:
                        file_location.append(file_path)
        return(file_location)
    map = mapping(path)
    log_file = open("log.log", "a")
    mapping_log = setup_logger("mapping",log_file= "log.log", level = logging.INFO)
    mapping_log.log(level=logging.INFO,msg="all Files Found")
    log_file.close()

    # use the dir list to find dates of file in them
    def chr_date(path):
        cr_date = {}
        data = map
        for i in data:
            if os.path.isfile(i):
                cr_T=(os.path.getmtime(i))
                cr_time = time.ctime(cr_T)
                cr_t_obj = time.strptime(cr_time)
                date = time.strftime("%Y-%m-%d", cr_t_obj)
                file_path = i
                if date in cr_date.keys():
                    cr_date[date].append(file_path)
                else:
                    cr_date[date]=[file_path]
        return(cr_date)
    dates = chr_date(path)
    log_file = open("log.log", "a")
    chr_date_log = setup_logger("Chr_date",log_file= "log.log", level = logging.INFO)
    chr_date_log.log(level=logging.INFO,msg="all files Found with path and cr_dates")
    log_file.close()

    #  sorts the files by the data given by chr_date() fuction
    def copy_file(scr_path,copy_path):
        os.chdir(copy_path)
        cr_date = dates
        fol_name = list(cr_date.keys())
        for i in cr_date.keys():
            f_list = cr_date[i]
            # print(f_list)
            current_directory = os.getcwd()
            v_format=(
                    ".264", ".3g2", ".3gp", ".3gp2", ".3gpp", ".3gpp2", ".3mm", ".3p2", ".60d", ".787", ".89", ".aaf", ".aec", ".aep", ".aepx",
                    ".aet", ".aetx", ".ajp", ".ale", ".am", ".amc", ".amv", ".amx", ".anim", ".aqt", ".arcut", ".arf", ".asf", ".asx", ".avb",
                    ".avc", ".avd", ".avi", ".avp", ".avs", ".avs", ".avv", ".axm", ".bdm", ".bdmv", ".bdt2", ".bdt3", ".bik", ".bin", ".bix",
                    ".bmk", ".bnp", ".box", ".bs4", ".bsf", ".bvr", ".byu", ".camproj", ".camrec", ".camv", ".ced", ".cel", ".cine", ".cip",
                    ".clpi", ".cmmp", ".cmmtpl", ".cmproj", ".cmrec", ".cpi", ".cst", ".cvc", ".cx3", ".d2v", ".d3v", ".dat", ".dav", ".dce",
                    ".dck", ".dcr", ".dcr", ".ddat", ".dif", ".dir", ".divx", ".dlx", ".dmb", ".dmsd", ".dmsd3d", ".dmsm", ".dmsm3d", ".dmss",
                    ".dmx", ".dnc", ".dpa", ".dpg", ".dream", ".dsy", ".dv", ".dv-avi", ".dv4", ".dvdmedia", ".dvr", ".dvr-ms", ".dvx", ".dxr",
                    ".dzm", ".dzp", ".dzt", ".edl", ".evo", ".eye", ".ezt", ".f4p", ".f4v", ".fbr", ".fbr", ".fbz", ".fcp", ".fcproject",
                    ".ffd", ".flc", ".flh", ".fli", ".flv", ".flx", ".gfp", ".gl", ".gom", ".grasp", ".gts", ".gvi", ".gvp", ".h264", ".hdmov",
                    ".hkm", ".ifo", ".imovieproj", ".imovieproject", ".ircp", ".irf", ".ism", ".ismc", ".ismv", ".iva", ".ivf", ".ivr", ".ivs",
                    ".izz", ".izzy", ".jss", ".jts", ".jtv", ".k3g", ".kmv", ".ktn", ".lrec", ".lsf", ".lsx", ".m15", ".m1pg", ".m1v", ".m21",
                    ".m21", ".m2a", ".m2p", ".m2t", ".m2ts", ".m2v", ".m4e", ".m4u", ".m4v", ".m75", ".mani", ".meta", ".mgv", ".mj2", ".mjp",
                    ".mjpg", ".mk3d", ".mkv", ".mmv", ".mnv", ".mob", ".mod", ".modd", ".moff", ".moi", ".moov", ".mov", ".movie", ".mp21",
                    ".mp21", ".mp2v", ".mp4", ".mp4v", ".mpe", ".mpeg", ".mpeg1", ".mpeg4", ".mpf", ".mpg", ".mpg2", ".mpgindex", ".mpl",
                    ".mpl", ".mpls", ".mpsub", ".mpv", ".mpv2", ".mqv", ".msdvd", ".mse", ".msh", ".mswmm", ".mts", ".mtv", ".mvb", ".mvc",
                    ".mvd", ".mve", ".mvex", ".mvp", ".mvp", ".mvy", ".mxf", ".mxv", ".mys", ".ncor", ".nsv", ".nut", ".nuv", ".nvc", ".ogm",
                    ".ogv", ".ogx", ".osp", ".otrkey", ".pac", ".par", ".pds", ".pgi", ".photoshow", ".piv", ".pjs", ".playlist", ".plproj",
                    ".pmf", ".pmv", ".pns", ".ppj", ".prel", ".pro", ".prproj", ".prtl", ".psb", ".psh", ".pssd", ".pva", ".pvr", ".pxv",
                    ".qt", ".qtch", ".qtindex", ".qtl", ".qtm", ".qtz", ".r3d", ".rcd", ".rcproject", ".rdb", ".rec", ".rm", ".rmd", ".rmd",
                    ".rmp", ".rms", ".rmv", ".rmvb", ".roq", ".rp", ".rsx", ".rts", ".rts", ".rum", ".rv", ".rvid", ".rvl", ".sbk", ".sbt",
                    ".scc", ".scm", ".scm", ".scn", ".screenflow", ".sec", ".sedprj", ".seq", ".sfd", ".sfvidcap", ".siv", ".smi", ".smi",
                    ".smil", ".smk", ".sml", ".smv", ".spl", ".sqz", ".srt", ".ssf", ".ssm", ".stl", ".str", ".stx", ".svi", ".swf", ".swi",
                    ".swt", ".tda3mt", ".tdx", ".thp", ".tivo", ".tix", ".tod", ".tp", ".tp0", ".tpd", ".tpr", ".trp", ".ts", ".tsp", ".ttxt",
                    ".tvs", ".usf", ".usm", ".vc1", ".vcpf", ".vcr", ".vcv", ".vdo", ".vdr", ".vdx", ".veg",".vem", ".vep", ".vf", ".vft",
                    ".vfw", ".vfz", ".vgz", ".vid", ".video", ".viewlet", ".viv", ".vivo", ".vlab", ".vob", ".vp3", ".vp6", ".vp7", ".vpj",
                    ".vro", ".vs4", ".vse", ".vsp", ".w32", ".wcp", ".webm", ".wlmp", ".wm", ".wmd", ".wmmp", ".wmv", ".wmx", ".wot", ".wp3",
                    ".wpl", ".wtv", ".wve", ".wvx", ".xej", ".xel", ".xesc", ".xfl", ".xlmv", ".xmv", ".xvid", ".y4m", ".yog", ".yuv", ".zeg",
                    ".zm1", ".zm2", ".zm3", ".zmv"  )
            img_format = (".apng","	.avif",".gif",".jpg",".jpeg",".jfif",".pjpeg",".pjp",".png",".svg",".webp",".bmp",".ico",".cur")
            doc_format = ()
            if fol_name in os.listdir():
                for j in range(len(f_list)):
                    file_name = f_list[j]
                    if os.path.isdir(file_name):
                        pass
                    else:
                        if file_name.endswith(v_format):
                            v_copy_path=copy_path + "\\"+ i+"\\video"
                            # if path exist copy the file
                            if v_copy_path in os.listdir:
                                shutil.copyfile(file_name,v_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="v_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                        # if path does not exist make the path then copy
                            else:
                                os.makedirs(i+"\\video")
                                shutil.copyfile(file_name,v_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="v_fol_made_&_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                        # move the file_name in fol_name\\video
                        else:
                            i_copy_path=copy_path + "\\"+ i+"\\img"
                            #  if path exist then copy
                            if i_copy_path in os.listdir:
                                shutil.copyfile(file_name,i_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="i_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                            #  if path do not exist then make path and them copy
                            else:
                                os.mkdir(i+"\\img")
                                shutil.copyfile(file_name,i_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="i_fol_made_&_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                            # move the file_name in fol_name\\img
            else:
                os.makedirs(i,exist_ok=True)
                log_file = open("log.log", "a")
                copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                copy_file_log.log(level=logging.INFO,msg="nw_fol"+i+" md")
                log_file.close()
                for j in range(len(f_list)):
                    file_name = f_list[j]
                    if os.path.isdir(file_name):
                        pass
                    else:    
                        if file_name.endswith(v_format):
                            v_copy_path=copy_path + "\\"+i+"\\video"
                            # if path exist copy the file
                            dir_list=os.listdir()
                            if v_copy_path in dir_list:
                                shutil.copyfile(file_name,v_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="v_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                        # if path does not exist make the path then copy
                            else:
                                os.makedirs(i+"\\video",exist_ok=True)
                                shutil.copy(file_name,v_copy_path)
                                if os.stat(file_name).st_size == os.stat(v_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="V_fol_made_&_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                            # move the file_name in fol_name\\video
                        else:
                            i_copy_path=copy_path + "\\"+i+"\\img"
                            #  if path exist then copy
                            if i_copy_path in os.listdir():
                                shutil.copyfile(file_name,i_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="i_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                            #  if path do not exist then make path and them copy
                            else:
                                os.makedirs(i+"\\img",exist_ok=True)
                                shutil.copy(file_name,i_copy_path)
                                if os.stat(file_name).st_size == os.stat(i_copy_path+"\\"+os.path.basename(cr_date[i][j])).st_size:
                                    # os.remove(file_name)
                                    log_file = open("log.log", "a")
                                    copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                                    copy_file_log.log(level=logging.INFO,msg="i_fol_made_&_copy_done and Scr_file removed")
                                    log_file.close()
                                    print(True)
                                # move the file_name in fol_name\\img
    copy_file(scr_path= path,copy_path=copy_path)
    log_file = open("log.log", "a")
    file_sort_log = setup_logger("File_sort",log_file= "log.log", level = logging.INFO)
    file_sort_log.log(level=logging.INFO,msg="all files from scr_path are moved and are sorted in copy_path")
    log_file.close()
pars = argparse.ArgumentParser()
pars.add_argument("-p" , "--path" , action="append", help="provide the absolute path of the source folder and copy folder in a list as -p "SOURCE PATH" -p "COPY PATH"")
args = pars.parse_args()
print(args)
scrpath = args.path[0]
copypath = args.path[1]

file_sort(path= str(scrpath),copy_path=str(copypath))

# command to run the program in cmd
# pushd <absuloute path of this file> & python file_sort.py -p "D:\test" -p "D:\copy path test"  (geralized)
# pushd D:\python scripts\.pyfiles & python file_sort.py -p "D:\test" -p "D:\copy path test" (personal)

# %% [markdown]
# ## __Spliting code for easier inprovmet process__

# %%
s_path = "D:\\test"
c_path="D:\\copy path test"

file_sort(path=s_path ,copy_path=c_path)

# %%
def check_format():
    ext = ""
    output = 0
    while True:
        for i in formats:
            for j in formats[i]:
                if str(ext) in j:
                    if output == 1:
                        break
                    print(i)
                    output = output+1
        break

# %%
import os
split_tup = os.path.splitext('my_file.mp4')
file_extension = split_tup[1]

print("File Extension: ", file_extension)
# Out:
# File Extension:  .mp4

# %%
# working on version 3 (have a bug)

import argparse
import os
import time
import shutil
import logging
import sys

formatter = logging.Formatter('%(asctime)s %(name)s %(levelname)s %(message)s')
def setup_logger(name, log_file, level=logging.INFO):
    """To set up as many loggers as you want"""
    handler = logging.FileHandler(log_file)
    handler.setFormatter(formatter)
    logger = logging.getLogger(name)
    logger.setLevel(level)
    if logger.handlers:
        logger.handlers = []
    logger.addHandler(handler)

    return logger


def find_dirs(path):
    
    dirs[path] = []
    for i in os.listdir(path):
        if os.path.isdir(path+"\\"+i):
            dirs[path].append(path+"\\"+i)
        else:
            pass
    if path in dirs:
        for i in dirs[path]:
            find_dirs(i)
    else:
        pass
    log_file = open("log.log", "a")
    find_dirs_log = setup_logger("find_dirs",log_file= "log.log", level = logging.INFO)
    find_dirs_log.log(level=logging.INFO,msg="all Dirs Found")
    log_file.close()
    return list(dirs.keys())


# Fuction to make dir with date and path 
def mapping(all_dirs):
    # flat_list = []

    # for sublist in all_dirs:
    #     for item in sublist:
    #         flat_list.append(item)

    file_location = []
    for j in all_dirs:
        a = os.listdir(j)
        for i in range(len(a)):
            if os.path.isdir(a[i]):
                pass
            else:               
                file_path = j + "\\" + a[i]
                if os.path.isdir(file_path):
                    pass
                else:
                    file_location.append(file_path)
    log_file = open("log.log", "a")
    mapping_log = setup_logger("mapping",log_file= "log.log", level = logging.INFO)
    mapping_log.log(level=logging.INFO,msg="all Files Found")
    log_file.close()
    return(file_location)


# use the dir list to find dates of file in them
def chr_date(map):
    cr_date = {}
    data = map
    for i in data:
        if os.path.isfile(i):
            cr_T=(os.path.getmtime(i))
            cr_time = time.ctime(cr_T)
            cr_t_obj = time.strptime(cr_time)
            date = time.strftime("%Y-%m-%d", cr_t_obj)
            file_path = i
            if date in cr_date.keys():
                cr_date[date].append(file_path)
            else:
                cr_date[date]=[file_path]
    log_file = open("log.log", "a")
    chr_date_log = setup_logger("Chr_date",log_file= "log.log", level = logging.INFO)
    chr_date_log.log(level=logging.INFO,msg="all files Found with path and cr_dates")
    log_file.close()
    return(cr_date)

## Following Fuction have Bug (MUST FIX)
def file_scr_copy_path(copy_path, cr_date):
    new_copy_path = {}
    file_name_list = []
    file_name_ext = []
    formats ={"Video" : [
    ".264", ".3g2", ".3gp", ".3gp2", ".3gpp", ".3gpp2", ".3mm", ".3p2", ".60d", ".787", ".89", ".aaf", ".aec", ".aep", ".aepx",
    ".aet", ".aetx", ".ajp", ".ale", ".am", ".amc", ".amv", ".amx", ".anim", ".aqt", ".arcut", ".arf", ".asf", ".asx", ".avb",
    ".avc", ".avd", ".avi", ".avp", ".avs", ".avs", ".avv", ".axm", ".bdm", ".bdmv", ".bdt2", ".bdt3", ".bik", ".bin", ".bix",
    ".bmk", ".bnp", ".box", ".bs4", ".bsf", ".bvr", ".byu", ".camproj", ".camrec", ".camv", ".ced", ".cel", ".cine", ".cip",
    ".clpi", ".cmmp", ".cmmtpl", ".cmproj", ".cmrec", ".cpi", ".cst", ".cvc", ".cx3", ".d2v", ".d3v", ".dat", ".dav", ".dce",
    ".dck", ".dcr", ".dcr", ".ddat", ".dif", ".dir", ".divx", ".dlx", ".dmb", ".dmsd", ".dmsd3d", ".dmsm", ".dmsm3d", ".dmss",
    ".dmx", ".dnc", ".dpa", ".dpg", ".dream", ".dsy", ".dv", ".dv-avi", ".dv4", ".dvdmedia", ".dvr", ".dvr-ms", ".dvx", ".dxr",
    ".dzm", ".dzp", ".dzt", ".edl", ".evo", ".eye", ".ezt", ".f4p", ".f4v", ".fbr", ".fbr", ".fbz", ".fcp", ".fcproject",
    ".ffd", ".flc", ".flh", ".fli", ".flv", ".flx", ".gfp", ".gl", ".gom", ".grasp", ".gts", ".gvi", ".gvp", ".h264", ".hdmov",
    ".hkm", ".ifo", ".imovieproj", ".imovieproject", ".ircp", ".irf", ".ism", ".ismc", ".ismv", ".iva", ".ivf", ".ivr", ".ivs",
    ".izz", ".izzy", ".jss", ".jts", ".jtv", ".k3g", ".kmv", ".ktn", ".lrec", ".lsf", ".lsx", ".m15", ".m1pg", ".m1v", ".m21",
    ".m21", ".m2a", ".m2p", ".m2t", ".m2ts", ".m2v", ".m4e", ".m4u", ".m4v", ".m75", ".mani", ".meta", ".mgv", ".mj2", ".mjp",
    ".mjpg", ".mk3d", ".mkv", ".mmv", ".mnv", ".mob", ".mod", ".modd", ".moff", ".moi", ".moov", ".mov", ".movie", ".mp21",
    ".mp21", ".mp2v", ".mp4", ".mp4v", ".mpe", ".mpeg", ".mpeg1", ".mpeg4", ".mpf", ".mpg", ".mpg2", ".mpgindex", ".mpl",
    ".mpl", ".mpls", ".mpsub", ".mpv", ".mpv2", ".mqv", ".msdvd", ".mse", ".msh", ".mswmm", ".mts", ".mtv", ".mvb", ".mvc",
    ".mvd", ".mve", ".mvex", ".mvp", ".mvp", ".mvy", ".mxf", ".mxv", ".mys", ".ncor", ".nsv", ".nut", ".nuv", ".nvc", ".ogm",
    ".ogv", ".ogx", ".osp", ".otrkey", ".pac", ".par", ".pds", ".pgi", ".photoshow", ".piv", ".pjs", ".playlist", ".plproj",
    ".pmf", ".pmv", ".pns", ".ppj", ".prel", ".pro", ".prproj", ".prtl", ".psb", ".psh", ".pssd", ".pva", ".pvr", ".pxv",
    ".qt", ".qtch", ".qtindex", ".qtl", ".qtm", ".qtz", ".r3d", ".rcd", ".rcproject", ".rdb", ".rec", ".rm", ".rmd", ".rmd",
    ".rmp", ".rms", ".rmv", ".rmvb", ".roq", ".rp", ".rsx", ".rts", ".rts", ".rum", ".rv", ".rvid", ".rvl", ".sbk", ".sbt",
    ".scc", ".scm", ".scm", ".scn", ".screenflow", ".sec", ".sedprj", ".seq", ".sfd", ".sfvidcap", ".siv", ".smi", ".smi",
    ".smil", ".smk", ".sml", ".smv", ".spl", ".sqz", ".srt", ".ssf", ".ssm", ".stl", ".str", ".stx", ".svi", ".swf", ".swi",
    ".swt", ".tda3mt", ".tdx", ".thp", ".tivo", ".tix", ".tod", ".tp", ".tp0", ".tpd", ".tpr", ".trp", ".ts", ".tsp", ".ttxt",
    ".tvs", ".usf", ".usm", ".vc1", ".vcpf", ".vcr", ".vcv", ".vdo", ".vdr", ".vdx", ".veg",".vem", ".vep", ".vf", ".vft",
    ".vfw", ".vfz", ".vgz", ".vid", ".video", ".viewlet", ".viv", ".vivo", ".vlab", ".vob", ".vp3", ".vp6", ".vp7", ".vpj",
    ".vro", ".vs4", ".vse", ".vsp", ".w32", ".wcp", ".webm", ".wlmp", ".wm", ".wmd", ".wmmp", ".wmv", ".wmx", ".wot", ".wp3",
    ".wpl", ".wtv", ".wve", ".wvx", ".xej", ".xel", ".xesc", ".xfl", ".xlmv", ".xmv", ".xvid", ".y4m", ".yog", ".yuv", ".zeg",
    ".zm1", ".zm2", ".zm3", ".zmv"  ],
    "Images" :  [".jpg",".jpeg",".png",".gif",".bmp",".tiff",".tif",".svg",".ico"],
    "Audio" : [".ape",".wv",".m4a",".wav",".aiff",".3gp",".aa",".aac",".aax",".act",".aiff",".alac",".amr",".ape",".au",".awb",
               ".dss",".dvf",".flac",".gsm",".iklax",".ivs",".m4a",".m4b",".m4p",".mmf",".mp3",".mpc",".msv",".nmf",".ogg",".oga",
               ".mogg",".oups",".ra",".rm",".raw",".rf64",".sln",".tta",".voc",".vox",".wav",".wma",".wv",".webm",".8svx",".cds"],
    "Basic_documents": [".pdf",".doc",".docx",".odt",".msg",".rtf",".tex",".txt",".csv",".wks",".wps",".wpd",".ods",".xlr",".xls",
                        ".xlsx",".key",".odp",".pps",".ppt",".pptx",".bak",".cab",".cfg",".cpl",".cur",".dll",".dmp",".drv",".icns",
                        ".ico",".ini",".ink",".msi",".sys",".tmp",".zip"]}
    for c,i in enumerate(cr_date.keys()):
        print(cr_date)
        f_list = cr_date[i]
        for j in range(len(f_list)):
            file_name = f_list[j]
            file_name_list.append(str(file_name))
        
        
        
    for i in range(len(file_name_list)):
        # print(i)
        file = file_name_list[i]
        new_copy_path[file]=[]
        if os.path.isdir(file):
            pass
        else:    
            split_tup = os.path.splitext(file)
            ext = str(split_tup[1])
            file_name_ext.append(str(ext))
            for key, value in formats.items():
                if isinstance(value, list) and ext in [i for i in value if i==str(ext)]:
                    path =copy_path+"\\"+([i for i in cr_date.keys()][c])+"\\"+key
                    new_copy_path[file]=path
            
    log_file = open("log.log", "a")
    file_sort_log = setup_logger("File_sort",log_file= "log.log", level = logging.INFO)
    file_sort_log.log(level=logging.INFO,msg="files sorted by file type with requred copy path")
    log_file.close()
    return new_copy_path
                        

#  sorts the files by the data given by chr_date() fuction
def copy_file(n_scr_copy_path=dict,main_copy_path=str):
    for scr_file , copy_file in n_scr_copy_path.items():

        
        if copy_file==[]:
            empty_copy_path = main_copy_path+"\\Uncertain"
            os.makedirs(empty_copy_path,exist_ok=True)
            log_file = open("log.log", "a")
            copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
            copy_file_log.log(level=logging.INFO,msg="nw_fol md")
            log_file.close()
            shutil.copy((scr_file),str(empty_copy_path))
            if os.stat(scr_file).st_size == os.stat(empty_copy_path).st_size:
                # os.remove(scr_file)
                log_file = open("log.log", "a")
                copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                copy_file_log.log(level=logging.INFO,msg="copy_done ")
                log_file.close()
                print(True)
        else:
            os.makedirs(copy_file,exist_ok=True)
            log_file = open("log.log", "a")
            copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
            copy_file_log.log(level=logging.INFO,msg="nw_fol md")
            log_file.close()
            shutil.copy(str(scr_file),str(copy_file))
            if os.stat(scr_file).st_size == os.stat(copy_file).st_size:
                # os.remove(scr_file)
                log_file = open("log.log", "a")
                copy_file_log = setup_logger("copy_file",log_file= "log.log", level = logging.INFO)
                copy_file_log.log(level=logging.INFO,msg="copy_done")
                log_file.close()
                print(True)

def main(path,main_copy_path):
    dirs ={}
    all_dirs=find_dirs(path)
    maped = mapping(all_dirs=all_dirs)
    cr_date = chr_date(maped)
    n_scr_copy_path = file_scr_copy_path(copy_path=main_copy_path, cr_date=cr_date)
    # print(n_scr_copy_path)
    copy_file(n_scr_copy_path,main_copy_path)
    # log_file = open("log.log", "a")
    # file_sort_log = setup_logger("File_sort",log_file= "log.log", level = logging.INFO)
    # file_sort_log.log(level=logging.INFO,msg="all files from scr_path are moved and are sorted in copy_path")
    # log_file.close()

if __name__ =='__main__':
    s_path = "d:\\test"
    c_path="d:\\copy_path_test"
    main(path=s_path ,main_copy_path=c_path)

# pars = argparse.ArgumentParser()
# pars.add_argument("-p" , "--path" , action='append', help='provide the absolute path of the source folder and copy folder in a list as -p "SOURCE PATH" -p "COPY PATH"')
# args = pars.parse_args()
# print(args)
# scrpath = args.path[0]
# copypath = args.path[1]
